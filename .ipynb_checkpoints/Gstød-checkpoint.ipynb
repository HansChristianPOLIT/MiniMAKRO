# %%
# %load_ext autoreload
# %autoreload 2

import time
import pickle
import numpy as np
from scipy import optimize

import matplotlib.pyplot as plt   
plt.style.use('seaborn-whitegrid')
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

from BabyMAKROModel import BabyMAKROModelClass
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Setup

# %%
model = BabyMAKROModelClass(name='Extended') # create an instance of the model

# %%
par = model.par
ss = model.ss
sol = model.sol

# %% [markdown]
# # Find steady state

# %%
model.find_ss(do_print=True)
# Out:
# Labor supply and search and matching:
# ss.S = 7.44,  ss.L = 56.28,  ss.delta_L = 0.07,  ss.v = 16.52,  ss.m_v = 0.23
# Capital agency FOC:
# ss.r_K = 0.14
# Production firm pricing:
# ss.r_ell = 2.71
# Labor agency:
# ss.ell = 55.87,  ss.w = 2.68
# Government:
# ss.B_G = 0.10,  ss.G = 0.00,  ss.tau = 0.00
# Households:
# solving for household behavior: result.converged = True
# ss.C = 169.40,  ss.B = 464.96
# Production firm FOCs:
# ss.K = 557.43
# Capital accumulation equation:
# ss.I = 55.74
# Output in production firm:
# ss.Y = 229.56
# Market clearing:
# ss.C_Y = 118.58,  ss.G_Y = 0.00,  ss.I_Y = 36.23,  ss.X_Y = 74.75
# [ ss.C_M = 50.82,  ss.G_M = 0.00,  ss.I_M = 19.51,  ss.X_M = 49.83 ] = ss.M = 120.16
# ss.X = 124.58
# Bargaining:
# par.phi = 0.988

# %% [markdown]
# **Household behavior:**

# %%
fig = plt.figure(figsize=(3*6,3*6/2.5))

ax = fig.add_subplot(2,4,1)
ax.plot(model.par.delta_L_a*100)
ax.set_ylabel('%')
ax.set_title('$\delta^L_a$')

ax = fig.add_subplot(2,4,2)
ax.plot(model.ss.S_a)
ax.set_title('$S_a$')

ax = fig.add_subplot(2,4,3)
ax.plot(model.ss.L_a)
ax.set_title('$L_a$')

ax = fig.add_subplot(2,4,4)
ax.plot(model.ss.L_ubar_a)
ax.set_title(r'$L\underbar_a$')

ax = fig.add_subplot(2,4,5)
ax.plot(model.ss.B_a)
ax.set_ylabel('')
ax.set_title('$B_a$')

ax = fig.add_subplot(2,4,6)
ax.plot(model.ss.C_a)
ax.set_ylabel('')
ax.set_title('$C_a$')

ax = fig.add_subplot(2,4,7)
ax.plot(model.ss.C_R)
ax.set_ylabel('')
ax.set_title('$C^R_a$')

ax = fig.add_subplot(2,4,8)
ax.plot(model.ss.C_HTM)
ax.set_ylabel('')
ax.set_title('$C^{HTM}_a$');

# %% [markdown]
# # Speed and error tests

# %%
model.set_exo_ss()
model.set_unknowns_ss()

# %% [markdown]
# **Python evaluation:**

# %%
# %time model.evaluate_blocks(py=True)
# Out:
# CPU times: total: 219 ms
# Wall time: 210 ms

# %% [markdown]
# **Check errors:**

# %%
errors = model.get_errors(do_print=True)
# Out:
# bargaining_cond     : abs. max = 0.00e+00
# Bq_match            : abs. max = 3.40e-02
# FOC_capital_agency  : abs. max = 0.00e+00
# FOC_K_ell           : abs. max = 7.11e-15
# mkt_clearing        : abs. max = 2.84e-14

# %% [markdown]
# **First numba evaluation:**

# %%
# %time model.evaluate_blocks()
# Out:
# CPU times: total: 15.6 ms
# Wall time: 6.07 ms

# %% [markdown]
# **Time:**

# %%
# %timeit model.evaluate_blocks()
# %timeit model.get_errors()
# Out:
# 3.69 ms ± 33.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 17.6 µs ± 868 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit model.evaluate_blocks(py=True)
# Out:
# 214 ms ± 11.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# # Find an impulse-response

# %% [markdown]
# **Calculate Jacobian:**

# %%
model.calc_jac(do_print=True)
# Out:
# Jacobian calculated in 9.9 secs secs

# %% [markdown]
# Only needs to be calculated once.

# %% [markdown]
# **Set exogenous variables:**

# %%
model.set_exo_ss()

# %% [markdown]
# Here we shock export demand:

# %%
Tshock = 50
shock = 0.01*ss.chi
persistence = 0.8**np.arange(Tshock)
sol.chi[:Tshock] = ss.chi + shock*persistence

# %% [markdown]
# Check errors when guessing at steady state -> excess demand

# %%
model.set_unknowns_ss()
model.evaluate_blocks()
errors = model.get_errors(do_print=True)
# Out:
# bargaining_cond     : abs. max = 0.00e+00
# Bq_match            : abs. max = 3.40e-02
# FOC_capital_agency  : abs. max = 0.00e+00
# FOC_K_ell           : abs. max = 8.88e-15
# mkt_clearing        : abs. max = 7.47e-01

# %% [markdown]
# **Find IRF:**

# %%
model.find_IRF()
# Out:
# initial:
#    max. abs. error = 7.47e-01
#     0.00e+00 in bargaining_cond
#     3.40e-02 in Bq_match
#     0.00e+00 in FOC_capital_agency
#     8.88e-15 in FOC_K_ell
#     7.47e-01 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 7.47e-01
#     1.41e-05 in bargaining_cond
#     1.82e-03 in Bq_match
#     8.18e-06 in FOC_capital_agency
#     2.55e-04 in FOC_K_ell
#     6.67e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.67e-03
#     5.56e-07 in bargaining_cond
#     4.63e-05 in Bq_match
#     3.65e-07 in FOC_capital_agency
#     9.92e-06 in FOC_K_ell
#     2.05e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.05e-04
#     1.60e-08 in bargaining_cond
#     1.41e-06 in Bq_match
#     1.09e-08 in FOC_capital_agency
#     2.82e-07 in FOC_K_ell
#     5.77e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.77e-06
#     4.72e-11 in bargaining_cond
#     9.67e-09 in Bq_match
#     2.91e-11 in FOC_capital_agency
#     8.66e-10 in FOC_K_ell
#     1.73e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.73e-08
#     2.11e-12 in bargaining_cond
#     1.52e-10 in Bq_match
#     1.44e-12 in FOC_capital_agency
#     3.75e-11 in FOC_K_ell
#     7.43e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 7.43e-10
#     3.29e-14 in bargaining_cond
#     1.33e-11 in Bq_match
#     3.26e-14 in FOC_capital_agency
#     1.01e-13 in FOC_K_ell
#     1.22e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.33e-11
#     3.20e-14 in bargaining_cond
#     1.10e-11 in Bq_match
#     2.20e-14 in FOC_capital_agency
#     1.05e-13 in FOC_K_ell
#     1.16e-11 in mkt_clearing

# %% [markdown]
# **Plot:**

# %%
T_IRF = 500

fig = plt.figure(figsize=(3*6,3*6/1.5))

ax = fig.add_subplot(4,4,1)
ax.plot((sol.chi[:T_IRF]/ss.chi-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Export demand, $\chi_t$')

ax = fig.add_subplot(4,4,2)
ax.plot((sol.Y[:T_IRF]/ss.Y-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Production, $Y_t$')

ax = fig.add_subplot(4,4,3)
ax.plot((sol.X[:T_IRF]/(ss.X)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Export, $X_t$')

ax = fig.add_subplot(4,4,4)
ax.plot((sol.M[:T_IRF]/(ss.M)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Import, $M_t$')

ax = fig.add_subplot(4,4,5)
ax.plot((sol.L[:T_IRF]/ss.L-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Employment, $L_t$')

ax = fig.add_subplot(4,4,6)
ax.plot((sol.ell[:T_IRF]/(ss.ell)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$\ell_t$')

ax = fig.add_subplot(4,4,7)
ax.plot((sol.w[:T_IRF]/(ss.w)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$w_t$')

ax = fig.add_subplot(4,4,8)
ax.plot((sol.r_ell[:T_IRF]/(ss.r_ell)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$r^{\ell}_t$')

ax = fig.add_subplot(4,4,9)
ax.plot((sol.m_s[:T_IRF]/(ss.m_s)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$m_s$')

ax = fig.add_subplot(4,4,10)
ax.plot((sol.S[:T_IRF]/(ss.S)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$S_t$')

ax = fig.add_subplot(4,4,11)
ax.plot((sol.v[:T_IRF]/(ss.v)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$v_t$')

ax = fig.add_subplot(4,4,12)
ax.plot((sol.K[:T_IRF]/ss.K-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Capital, $K_t$')

ax = fig.add_subplot(4,4,13)
ax.plot((sol.I[:T_IRF]/(ss.I)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Investments, $I^R_t$')

ax = fig.add_subplot(4,4,14)
ax.plot((sol.C[:T_IRF]/ss.C-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Consumption, $C_t$')

ax = fig.add_subplot(4,4,15)
ax.plot((sol.Bq[:T_IRF]/(ss.Bq)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Inheritance, $B^q_t$')

ax = fig.add_subplot(4,4,16)
ax.plot((sol.B[:T_IRF]/(ss.B)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('End-of-period savings, $B^R_t$');

print('Note: resultater')
# Out:
# Note: resultater

# %%
Periods = [0,1,20,40,80,100]

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(2,2,1)
for t in Periods:
    L_a = np.zeros(par.A)
    for a in range(par.A):
        L_a[a] = sol.L_a[a,t+a]
    ax.plot(L_a-ss.L_a,label=f'{t = }')
ax.set_ylabel('% of s.s.')
ax.set_title('$L_{a,t}$')

ax = fig.add_subplot(2,2,2)
for t in Periods:
    S_a = np.zeros(par.A)
    for a in range(par.A):
        S_a[a] = sol.S_a[a,t+a]
    ax.plot(S_a-ss.S_a,label=f'{t = }')
ax.set_ylabel('% of s.s.')
ax.set_title('$S_{a,t}$')

ax = fig.add_subplot(2,2,3)
for t in Periods:
    C_a = np.zeros(par.A)
    for a in range(par.A):
        C_a[a] = sol.C_a[a,t+a]
    ax.plot(C_a-ss.C_a,label=f'{t = }')
ax.set_ylabel('% of s.s.')
ax.set_title('$C_{a,t}$')

ax = fig.add_subplot(2,2,4)
for t in Periods:
    B_a = np.zeros(par.A)
    for a in range(par.A):
        B_a[a] = sol.B_a[a,t+a]
    ax.plot(B_a-ss.B_a,label=f'{t = }')
ax.legend(frameon=True)
ax.set_ylabel('% of s.s.')
ax.set_title('$B_{a,t}$');

# %%
fig = plt.figure(figsize=(12,8))

ax = fig.add_subplot(2,2,1)
ax.plot((sol.P_Y[:T_IRF]/ss.P_Y-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$P^Y_t$')

ax = fig.add_subplot(2,2,2)
ax.plot((sol.P_C[:T_IRF]/ss.P_C-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$P^C_t$')

ax = fig.add_subplot(2,2,3)
ax.plot((sol.P_I[:T_IRF]/(ss.P_I)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$P^I_t$')

ax = fig.add_subplot(2,2,4)
ax.plot((sol.P_X[:T_IRF]/(ss.P_X)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$P^X_t$');

# %% [markdown]
# # Comparison

# %%
model_copy = model.copy()
model_copy.par.Lambda = 0.01
model_copy.find_ss(0.50)
model_copy.calc_jac(do_print=True)
# Out:
# Labor supply and search and matching:
# ss.S = 7.44,  ss.L = 56.28,  ss.delta_L = 0.07,  ss.v = 16.52,  ss.m_v = 0.23
# Capital agency FOC:
# ss.r_K = 0.14
# Production firm pricing:
# ss.r_ell = 2.71
# Labor agency:
# ss.ell = 55.87,  ss.w = 2.68
# Government:
# ss.B_G = 0.10,  ss.G = 0.00,  ss.tau = 0.00
# Households:
# solving for household behavior: result.converged = True
# ss.C = 166.03,  ss.B = 460.37
# Production firm FOCs:
# ss.K = 557.43
# Capital accumulation equation:
# ss.I = 55.74
# Output in production firm:
# ss.Y = 229.56
# Market clearing:
# ss.C_Y = 116.22,  ss.G_Y = 0.00,  ss.I_Y = 36.23,  ss.X_Y = 77.11
# [ ss.C_M = 49.81,  ss.G_M = 0.00,  ss.I_M = 19.51,  ss.X_M = 51.41 ] = ss.M = 120.73
# ss.X = 128.52
# Bargaining:
# par.phi = 0.988
# Jacobian calculated in 10.2 secs secs

# %%
Tshock = 50
shock = 0.01*ss.chi
persistence = 0.8**np.arange(Tshock)
model_copy.sol.chi[:Tshock] = model_copy.ss.chi + shock*persistence

# %%
model_copy.find_IRF()
# Out:
# initial:
#    max. abs. error = 7.47e-01
#     0.00e+00 in bargaining_cond
#     3.36e-02 in Bq_match
#     0.00e+00 in FOC_capital_agency
#     8.88e-15 in FOC_K_ell
#     7.47e-01 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 7.47e-01
#     1.38e-05 in bargaining_cond
#     1.78e-03 in Bq_match
#     8.02e-06 in FOC_capital_agency
#     2.49e-04 in FOC_K_ell
#     6.59e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.59e-03
#     5.34e-07 in bargaining_cond
#     4.33e-05 in Bq_match
#     3.53e-07 in FOC_capital_agency
#     9.54e-06 in FOC_K_ell
#     2.00e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.00e-04
#     1.55e-08 in bargaining_cond
#     1.33e-06 in Bq_match
#     1.06e-08 in FOC_capital_agency
#     2.73e-07 in FOC_K_ell
#     5.64e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.64e-06
#     3.75e-11 in bargaining_cond
#     9.32e-09 in Bq_match
#     2.30e-11 in FOC_capital_agency
#     6.96e-10 in FOC_K_ell
#     1.39e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.39e-08
#     2.01e-12 in bargaining_cond
#     1.59e-10 in Bq_match
#     1.38e-12 in FOC_capital_agency
#     3.58e-11 in FOC_K_ell
#     7.16e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 7.16e-10
#     3.11e-14 in bargaining_cond
#     1.31e-11 in Bq_match
#     2.40e-14 in FOC_capital_agency
#     2.18e-13 in FOC_K_ell
#     1.13e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.31e-11
#     3.24e-14 in bargaining_cond
#     1.28e-11 in Bq_match
#     2.44e-14 in FOC_capital_agency
#     9.77e-14 in FOC_K_ell
#     1.21e-11 in mkt_clearing

# %%
T_IRF = 500

fig = plt.figure(figsize=(3*6,3*6/1.5))

ax = fig.add_subplot(3,4,1)
ax.plot((sol.chi[:T_IRF]/ss.chi-1)*100)
ax.plot((model_copy.sol.chi[:T_IRF]/model_copy.ss.chi-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Export demand (the shock-variable), $\chi_t$')
ax.legend(frameon=True)

ax = fig.add_subplot(3,4,2)
ax.plot((sol.Y[:T_IRF]/ss.Y-1)*100)
ax.plot((model_copy.sol.Y[:T_IRF]/model_copy.ss.Y-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Production, $Y_t$')
# Out:
# Text(0.5, 1.0, 'Production, $Y_t$')

# %%
T_IRF = 200

fig = plt.figure(figsize=(3*6,3*6/1.5))

ax = fig.add_subplot(3,4,1)
ax.plot((sol.chi[:T_IRF]/ss.chi-1)*100)
ax.plot((model_copy.sol.chi[:T_IRF]/model_copy.ss.chi-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Export demand (the shock-variable), $\chi_t$')
ax.legend(frameon=True)

ax = fig.add_subplot(3,4,2)
ax.plot((sol.Y[:T_IRF]/ss.Y-1)*100)
ax.plot((model_copy.sol.Y[:T_IRF]/model_copy.ss.Y-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Production, $Y_t$')

ax = fig.add_subplot(3,4,3)
ax.plot((sol.M[:T_IRF]/ss.M-1)*100)
ax.plot((model_copy.sol.M[:T_IRF]/model_copy.ss.M-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Imports, $M_t$')

ax = fig.add_subplot(3,4,4)
ax.plot((sol.tau[:T_IRF]/ss.tau-1)*100)
ax.plot((model_copy.sol.tau[:T_IRF]/model_copy.ss.tau-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Tax-rate, $tau_t$')

ax = fig.add_subplot(3,4,5)
ax.plot((sol.K[:T_IRF]/ss.K-1)*100)
ax.plot((model_copy.sol.K[:T_IRF]/model_copy.ss.K-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Capital, $K_t$')

ax = fig.add_subplot(3,4,6)
ax.plot((sol.I[:T_IRF]/ss.I-1)*100)
ax.plot((model_copy.sol.I[:T_IRF]/model_copy.ss.I-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Investments, $I_t$')

ax = fig.add_subplot(3,4,7)
ax.plot((sol.C[:T_IRF]/ss.C-1)*100)
ax.plot((model_copy.sol.C[:T_IRF]/model_copy.ss.C-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Consumption, $C_t$')

ax = fig.add_subplot(3,4,8)
ax.plot((sol.X[:T_IRF]/ss.X-1)*100)
ax.plot((model_copy.sol.X[:T_IRF]/model_copy.ss.X-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Exports, $X_t$')

ax = fig.add_subplot(3,4,9)
ax.plot((sol.v[:T_IRF]/ss.v-1)*100)
ax.plot((model_copy.sol.v[:T_IRF]/model_copy.ss.v-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Vacancies, $v_t$')

ax = fig.add_subplot(3,4,10)
ax.plot((sol.L[:T_IRF]/ss.L-1)*100)
ax.plot((model_copy.sol.L[:T_IRF]/model_copy.ss.L-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Labour supply, $L_t$')

ax = fig.add_subplot(3,4,11)
ax.plot((sol.MPL[:T_IRF]/ss.MPL-1)*100)
ax.plot((model_copy.sol.MPL[:T_IRF]/model_copy.ss.MPL-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('MPL, $MPL_t$')

ax = fig.add_subplot(3,4,12)
ax.plot((sol.w[:T_IRF]/ss.w-1)*100)
ax.plot((model_copy.sol.w[:T_IRF]/model_copy.ss.w-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('wage, $w_t$')
# Out:
# Text(0.5, 1.0, 'wage, $w_t$')

# %%
T_IRF = 200

fig = plt.figure(figsize=(3*6,3*6/1.5))


ax = fig.add_subplot(3,4,1)
ax.plot((sol.chi[:T_IRF]/ss.chi-1)*100)
ax.plot((model_copy.sol.chi[:T_IRF]/model_copy.ss.chi-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Export demand (the shock-variable), $\chi_t$')
ax.legend(frameon=True)

ax = fig.add_subplot(3,4,2)
ax.plot((sol.P_C[:T_IRF]/ss.P_C-1)*100)
ax.plot((model_copy.sol.P_C[:T_IRF]/model_copy.ss.P_C-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Price of consumption good, $P^C_t$')

ax = fig.add_subplot(3,4,3)
ax.plot((sol.P_I[:T_IRF]/ss.P_I-1)*100)
ax.plot((model_copy.sol.P_I[:T_IRF]/model_copy.ss.P_I-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Price of investment good, $P^I_t$')

ax = fig.add_subplot(3,4,4)
ax.plot((sol.P_X[:T_IRF]/ss.P_X-1)*100)
ax.plot((model_copy.sol.P_X[:T_IRF]/model_copy.ss.P_X-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Price of export good, $P^X_t$')

ax = fig.add_subplot(3,4,5)
ax.plot((sol.B[:T_IRF]/ss.B-1)*100)
ax.plot((model_copy.sol.B[:T_IRF]/model_copy.ss.B-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('End of period savings, $B_t$')
# Out:
# Text(0.5, 1.0, 'End of period savings, $B_t$')

# %%
Tshock = 50
shock = 0.01*ss.G
persistence = 0.8**np.arange(Tshock)
model_copy.sol.G[:Tshock] = model_copy.ss.G + shock*persistence

# %%
T_IRF = 200

fig = plt.figure(figsize=(3*6,3*6/1.5))

ax = fig.add_subplot(3,4,2)
ax.plot((sol.Y[:T_IRF]/ss.Y-1)*100)
ax.plot((model_copy.sol.Y[:T_IRF]/model_copy.ss.Y-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Production, $Y_t$')

ax = fig.add_subplot(3,4,3)
ax.plot((sol.M[:T_IRF]/ss.M-1)*100)
ax.plot((model_copy.sol.M[:T_IRF]/model_copy.ss.M-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Imports, $M_t$')

ax = fig.add_subplot(3,4,4)
ax.plot((sol.tau[:T_IRF]/ss.tau-1)*100)
ax.plot((model_copy.sol.tau[:T_IRF]/model_copy.ss.tau-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Tax-rate, $tau_t$')

ax = fig.add_subplot(3,4,5)
ax.plot((sol.K[:T_IRF]/ss.K-1)*100)
ax.plot((model_copy.sol.K[:T_IRF]/model_copy.ss.K-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Capital, $K_t$')
# Out:
# Text(0.5, 1.0, 'Capital, $K_t$')

# %%
model.calc_jac(do_print=True)
# Out:
# Jacobian calculated in 10.4 secs secs

# %%
model.set_exo_ss()

# %%
Tshock = 50
shock = 0.01*ss.G
persistence = 0.8**np.arange(Tshock)
model_copy.sol.G[:Tshock] = model_copy.ss.G + shock*persistence

# %%
T_IRF = 200

fig = plt.figure(figsize=(3*6,3*6/1.5))

ax = fig.add_subplot(3,4,1)
ax.plot((sol.G[:T_IRF]/ss.G-1)*100)
ax.plot((model_copy.sol.G[:T_IRF]/model_copy.ss.G-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Government spending (the shock-variable), $\G_t$')
ax.legend(frameon=True)

ax = fig.add_subplot(3,4,2)
ax.plot((sol.Y[:T_IRF]/ss.Y-1)*100)
ax.plot((model_copy.sol.Y[:T_IRF]/model_copy.ss.Y-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Production, $Y_t$')

ax = fig.add_subplot(3,4,3)
ax.plot((sol.M[:T_IRF]/ss.M-1)*100)
ax.plot((model_copy.sol.M[:T_IRF]/model_copy.ss.M-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Imports, $M_t$')

ax = fig.add_subplot(3,4,4)
ax.plot((sol.tau[:T_IRF]/ss.tau-1)*100)
ax.plot((model_copy.sol.tau[:T_IRF]/model_copy.ss.tau-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Tax-rate, $tau_t$')

ax = fig.add_subplot(3,4,5)
ax.plot((sol.K[:T_IRF]/ss.K-1)*100)
ax.plot((model_copy.sol.K[:T_IRF]/model_copy.ss.K-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Capital, $K_t$')
# Out:
# Text(0.5, 1.0, 'Capital, $K_t$')
