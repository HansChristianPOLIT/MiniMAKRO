# %% [markdown]
# # Noget Vi Måske Skal Bruge

# %%
# %load_ext autoreload
# %autoreload 2

import time
import pickle
import numpy as np
from scipy import optimize

import matplotlib.pyplot as plt   
plt.style.use('seaborn-whitegrid')
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

from BabyMAKROModel import BabyMAKROModelClass

# %% [markdown]
# # Setup

# %%
model = BabyMAKROModelClass(name='Extended') # create an instance of the model

# %%
par = model.par
ss = model.ss
sol = model.sol

# %% [markdown]
# # Find steady state

# %%
model.find_ss(do_print=True)
# Out:
# Labor supply and search and matching:
# ss.S = 7.44,  ss.L = 56.28,  ss.delta_L = 0.07,  ss.v = 16.52,  ss.m_v = 0.23
# Capital agency FOC:
# ss.r_K = 0.14
# Production firm pricing:
# ss.r_ell = 2.71
# Labor agency:
# ss.ell = 55.46,  ss.W = 2.65
# Government:
# ss.B_G = 150.00,  ss.G = 50.00,  ss.tau = 0.38
# Households:
# solving for household behavior: result.converged = True
# ss.C = 82.12,  ss.B = 168.84
# Production firm FOCs:
# ss.K = 553.31
# Capital accumulation equation:
# ss.I = 55.33
# Output in production firm:
# ss.Y = 227.87
# Market clearing:
# ss.C_Y = 57.48,  ss.G_Y = 45.00,  ss.I_Y = 35.97,  ss.X_Y = 89.42
# [ ss.C_M = 24.64,  ss.G_M = 5.00,  ss.I_M = 19.37,  ss.X_M = 59.61 ] = ss.M = 108.61
# ss.X = 149.03
# Bargaining:
# par.phi = 0.968

# %% [markdown]
# # Find an impulse-response

# %% [markdown]
# **Calculate Jacobian:**

# %%
model.calc_jac(do_print=True)
# Out:
# Jacobian calculated in 16.0 secs secs

# %% [markdown]
# Only needs to be calculated once.

# %% [markdown]
# **Set exogenous variables:**

# %%
Tshock = 50
shock = 0.01*ss.chi
persistence = 0.8**np.arange(Tshock)
sol.chi[:Tshock] = ss.chi + shock*persistence

Tshock = 50
shock = 0.03*ss.P_F
persistence = 0.80**np.arange(Tshock)
sol.P_F[:Tshock] = ss.P_F + shock*persistence

# %% [markdown]
# Check errors when guessing at steady state -> excess demand

# %%
model.set_unknowns_ss()
model.evaluate_blocks()
errors = model.get_errors(do_print=True)
# Out:
# bargaining_cond     : abs. max = 0.00e+00
# Bq_match            : abs. max = 2.80e+01
# FOC_capital_agency  : abs. max = 0.00e+00
# FOC_K_ell           : abs. max = 1.95e-14
# mkt_clearing        : abs. max = 1.40e+01

# %% [markdown]
# **Find IRF:**

# %%
model.find_IRF()
# Out:
# initial:
#    max. abs. error = 2.80e+01
#     0.00e+00 in bargaining_cond
#     2.80e+01 in Bq_match
#     0.00e+00 in FOC_capital_agency
#     1.95e-14 in FOC_K_ell
#     1.40e+01 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 2.80e+01
#     1.01e-02 in bargaining_cond
#     8.20e-01 in Bq_match
#     7.01e-03 in FOC_capital_agency
#     2.34e-01 in FOC_K_ell
#     3.34e+00 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 3.34e+00
#     5.88e-03 in bargaining_cond
#     3.00e-01 in Bq_match
#     4.69e-03 in FOC_capital_agency
#     1.24e-01 in FOC_K_ell
#     1.80e+00 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 1.80e+00
#     1.24e-03 in bargaining_cond
#     6.43e-02 in Bq_match
#     9.49e-04 in FOC_capital_agency
#     2.76e-02 in FOC_K_ell
#     3.69e-01 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 3.69e-01
#     6.36e-05 in bargaining_cond
#     2.75e-03 in Bq_match
#     5.16e-05 in FOC_capital_agency
#     1.42e-03 in FOC_K_ell
#     2.01e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 2.01e-02
#     6.74e-06 in bargaining_cond
#     2.53e-04 in Bq_match
#     5.75e-06 in FOC_capital_agency
#     1.55e-04 in FOC_K_ell
#     2.15e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 2.15e-03
#     8.85e-07 in bargaining_cond
#     1.31e-05 in Bq_match
#     1.03e-06 in FOC_capital_agency
#     1.97e-05 in FOC_K_ell
#     2.95e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 2.95e-04
#     2.86e-07 in bargaining_cond
#     7.27e-06 in Bq_match
#     3.44e-07 in FOC_capital_agency
#     6.58e-06 in FOC_K_ell
#     9.41e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 9.41e-05
#     1.41e-08 in bargaining_cond
#     3.95e-07 in Bq_match
#     2.10e-08 in FOC_capital_agency
#     3.31e-07 in FOC_K_ell
#     5.17e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 5.17e-06
#     7.53e-09 in bargaining_cond
#     7.68e-08 in Bq_match
#     1.37e-08 in FOC_capital_agency
#     1.80e-07 in FOC_K_ell
#     2.61e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.61e-06
#     2.97e-09 in bargaining_cond
#     3.71e-08 in Bq_match
#     5.19e-09 in FOC_capital_agency
#     7.05e-08 in FOC_K_ell
#     1.02e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 10
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 1.02e-06
#     1.19e-11 in bargaining_cond
#     1.58e-10 in Bq_match
#     1.79e-11 in FOC_capital_agency
#     2.69e-10 in FOC_K_ell
#     4.15e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 11
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 4.15e-09
#     1.69e-11 in bargaining_cond
#     3.00e-10 in Bq_match
#     2.50e-11 in FOC_capital_agency
#     3.93e-10 in FOC_K_ell
#     5.69e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 12
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 5.69e-09
#     9.49e-13 in bargaining_cond
#     2.41e-11 in Bq_match
#     8.82e-13 in FOC_capital_agency
#     2.14e-11 in FOC_K_ell
#     3.03e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 13
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 3.03e-10
#     6.62e-14 in bargaining_cond
#     7.11e-12 in Bq_match
#     1.08e-13 in FOC_capital_agency
#     1.66e-12 in FOC_K_ell
#     2.33e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 14
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 2.33e-11
#     3.06e-14 in bargaining_cond
#     5.62e-12 in Bq_match
#     3.41e-14 in FOC_capital_agency
#     5.83e-13 in FOC_K_ell
#     1.34e-11 in mkt_clearing

# %% [markdown]
# **Plot:**

# %%
T_IRF = 200

fig = plt.figure(figsize=(3*6,3*6/1.5))

ax = fig.add_subplot(4,4,1)
ax.plot((sol.chi[:T_IRF]/ss.chi-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Export demand, $\chi_t$')

ax = fig.add_subplot(4,4,2)
ax.plot((sol.Y[:T_IRF]/ss.Y-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Production, $Y_t$')

ax = fig.add_subplot(4,4,3)
ax.plot((sol.X[:T_IRF]/(ss.X)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Export, $X_t$')

ax = fig.add_subplot(4,4,4)
ax.plot((sol.M[:T_IRF]/(ss.M)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Import, $M_t$')

ax = fig.add_subplot(4,4,5)
ax.plot((sol.L[:T_IRF]/ss.L-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Employment, $L_t$')

ax = fig.add_subplot(4,4,6)
ax.plot((sol.ell[:T_IRF]/(ss.ell)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$\ell_t$')

ax = fig.add_subplot(4,4,7)
ax.plot((sol.W[:T_IRF]/(ss.W)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$w_t$')

ax = fig.add_subplot(4,4,8)
ax.plot((sol.r_ell[:T_IRF]/(ss.r_ell)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$r^{\ell}_t$')

ax = fig.add_subplot(4,4,9)
ax.plot((sol.m_s[:T_IRF]/(ss.m_s)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$m_s$')

ax = fig.add_subplot(4,4,10)
ax.plot((sol.S[:T_IRF]/(ss.S)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$S_t$')

ax = fig.add_subplot(4,4,11)
ax.plot((sol.v[:T_IRF]/(ss.v)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$v_t$')

ax = fig.add_subplot(4,4,12)
ax.plot((sol.K[:T_IRF]/ss.K-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Capital, $K_t$')

ax = fig.add_subplot(4,4,13)
ax.plot((sol.I[:T_IRF]/(ss.I)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Investments, $I^R_t$')

ax = fig.add_subplot(4,4,14)
ax.plot((sol.C[:T_IRF]/ss.C-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Consumption, $C_t$')

ax = fig.add_subplot(4,4,15)
ax.plot((sol.P_F[:T_IRF]/(ss.P_F)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Inheritance, $B^q_t$')

ax = fig.add_subplot(4,4,16)
ax.plot((sol.P_X[:T_IRF]/(ss.P_X)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('tau, $B^R_t$');

print('Note: resultater')
# Out:
# Note: resultater

# %%
Periods = [0,1,20,40,80,100]

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(2,2,1)
for t in Periods:
    L_a = np.zeros(par.A)
    for a in range(par.A):
        L_a[a] = sol.L_a[a,t+a]
    ax.plot(L_a-ss.L_a,label=f'{t = }')
ax.set_ylabel('% of s.s.')
ax.set_title('$L_{a,t}$')

ax = fig.add_subplot(2,2,2)
for t in Periods:
    S_a = np.zeros(par.A)
    for a in range(par.A):
        S_a[a] = sol.S_a[a,t+a]
    ax.plot(S_a-ss.S_a,label=f'{t = }')
ax.set_ylabel('% of s.s.')
ax.set_title('$S_{a,t}$')

ax = fig.add_subplot(2,2,3)
for t in Periods:
    C_a = np.zeros(par.A)
    for a in range(par.A):
        C_a[a] = sol.C_a[a,t+a]
    ax.plot(C_a-ss.C_a,label=f'{t = }')
ax.set_ylabel('% of s.s.')
ax.set_title('$C_{a,t}$')

ax = fig.add_subplot(2,2,4)
for t in Periods:
    B_a = np.zeros(par.A)
    for a in range(par.A):
        B_a[a] = sol.B_a[a,t+a]
    ax.plot(B_a-ss.B_a,label=f'{t = }')
ax.legend(frameon=True)
ax.set_ylabel('% of s.s.')
ax.set_title('$B_{a,t}$');

# %%
fig = plt.figure(figsize=(12,8))

ax = fig.add_subplot(2,2,1)
ax.plot((sol.P_Y[:T_IRF]/ss.P_Y-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$P^Y_t$')

ax = fig.add_subplot(2,2,2)
ax.plot((sol.P_C[:T_IRF]/ss.P_C-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$P^C_t$')

ax = fig.add_subplot(2,2,3)
ax.plot((sol.P_I[:T_IRF]/(ss.P_I)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$P^I_t$')

ax = fig.add_subplot(2,2,4)
ax.plot((sol.P_X[:T_IRF]/(ss.P_X)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$P^X_t$');

# %% [markdown]
# # Comparison

# %%
model_copy = model.copy()
model_copy.par.Lambda = 0.15
model_copy.find_ss(0.50)
model_copy.calc_jac(do_print=True)
# Out:
# Labor supply and search and matching:
# ss.S = 7.44,  ss.L = 56.28,  ss.delta_L = 0.07,  ss.v = 16.52,  ss.m_v = 0.23
# Capital agency FOC:
# ss.r_K = 0.14
# Production firm pricing:
# ss.r_ell = 2.71
# Labor agency:
# ss.ell = 55.46,  ss.W = 2.65
# Government:
# ss.B_G = 150.00,  ss.G = 50.00,  ss.tau = 0.38
# Households:
# solving for household behavior: result.converged = True
# ss.C = 89.54,  ss.B = 212.48
# Production firm FOCs:
# ss.K = 553.31
# Capital accumulation equation:
# ss.I = 55.33
# Output in production firm:
# ss.Y = 227.87
# Market clearing:
# ss.C_Y = 62.68,  ss.G_Y = 45.00,  ss.I_Y = 35.97,  ss.X_Y = 84.22
# [ ss.C_M = 26.86,  ss.G_M = 5.00,  ss.I_M = 19.37,  ss.X_M = 56.15 ] = ss.M = 107.38
# ss.X = 140.37
# Bargaining:
# par.phi = 0.968
# Jacobian calculated in 15.3 secs secs

# %%
Tshock = 50
shock = 0.01*ss.chi
persistence = 0.8**np.arange(Tshock)
model_copy.sol.chi[:Tshock] = model_copy.ss.chi + shock*persistence

# %%
model_copy.find_IRF()
# Out:
# initial:
#    max. abs. error = 3.64e+01
#     0.00e+00 in bargaining_cond
#     3.64e+01 in Bq_match
#     0.00e+00 in FOC_capital_agency
#     1.95e-14 in FOC_K_ell
#     5.15e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.64e+01
#     3.15e-03 in bargaining_cond
#     8.05e-01 in Bq_match
#     1.82e-03 in FOC_capital_agency
#     6.71e-02 in FOC_K_ell
#     6.93e-01 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 8.05e-01
#     9.81e-04 in bargaining_cond
#     1.49e-01 in Bq_match
#     5.80e-04 in FOC_capital_agency
#     1.79e-02 in FOC_K_ell
#     2.55e-01 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.55e-01
#     5.59e-05 in bargaining_cond
#     7.24e-03 in Bq_match
#     4.10e-05 in FOC_capital_agency
#     1.12e-03 in FOC_K_ell
#     1.71e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.71e-02
#     1.01e-05 in bargaining_cond
#     9.63e-04 in Bq_match
#     8.97e-06 in FOC_capital_agency
#     2.18e-04 in FOC_K_ell
#     2.83e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.83e-03
#     1.70e-06 in bargaining_cond
#     7.89e-05 in Bq_match
#     1.90e-06 in FOC_capital_agency
#     3.92e-05 in FOC_K_ell
#     5.25e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.25e-04
#     4.46e-07 in bargaining_cond
#     2.23e-05 in Bq_match
#     5.03e-07 in FOC_capital_agency
#     1.03e-05 in FOC_K_ell
#     1.37e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.37e-04
#     2.15e-08 in bargaining_cond
#     4.42e-07 in Bq_match
#     2.95e-08 in FOC_capital_agency
#     5.33e-07 in FOC_K_ell
#     7.08e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 7.08e-06
#     7.74e-09 in bargaining_cond
#     1.98e-07 in Bq_match
#     9.77e-09 in FOC_capital_agency
#     1.86e-07 in FOC_K_ell
#     2.49e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.49e-06
#     1.03e-09 in bargaining_cond
#     2.93e-08 in Bq_match
#     1.26e-09 in FOC_capital_agency
#     2.47e-08 in FOC_K_ell
#     3.30e-07 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 3.30e-07
#     5.76e-11 in bargaining_cond
#     1.40e-09 in Bq_match
#     8.25e-11 in FOC_capital_agency
#     1.41e-09 in FOC_K_ell
#     1.89e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 10
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.89e-08
#     8.81e-12 in bargaining_cond
#     1.83e-10 in Bq_match
#     1.45e-11 in FOC_capital_agency
#     2.19e-10 in FOC_K_ell
#     2.94e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 11
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.94e-09
#     6.92e-13 in bargaining_cond
#     1.02e-11 in Bq_match
#     1.07e-12 in FOC_capital_agency
#     1.76e-11 in FOC_K_ell
#     2.43e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 12
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.43e-10
#     4.01e-13 in bargaining_cond
#     9.91e-12 in Bq_match
#     7.01e-13 in FOC_capital_agency
#     1.01e-11 in FOC_K_ell
#     1.37e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 13
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 1.37e-10
#     1.19e-13 in bargaining_cond
#     9.05e-12 in Bq_match
#     2.16e-13 in FOC_capital_agency
#     2.85e-12 in FOC_K_ell
#     4.07e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 14
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.07e-11
#     4.00e-14 in bargaining_cond
#     7.86e-12 in Bq_match
#     3.25e-14 in FOC_capital_agency
#     8.01e-13 in FOC_K_ell
#     1.20e-11 in mkt_clearing

# %%
T_IRF = 500

fig = plt.figure(figsize=(3*6,3*6/1.5))

ax = fig.add_subplot(3,4,1)
ax.plot((sol.chi[:T_IRF]/ss.chi-1)*100)
ax.plot((model_copy.sol.chi[:T_IRF]/model_copy.ss.chi-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Export demand (the shock-variable), $\chi_t$')
ax.legend(frameon=True)

ax = fig.add_subplot(3,4,2)
ax.plot((sol.Y[:T_IRF]/ss.Y-1)*100)
ax.plot((model_copy.sol.Y[:T_IRF]/model_copy.ss.Y-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Production, $Y_t$')
# Out:
# Text(0.5, 1.0, 'Production, $Y_t$')

# %%
T_IRF = 200

fig = plt.figure(figsize=(3*6,3*6/1.5))

ax = fig.add_subplot(3,4,1)
ax.plot((sol.chi[:T_IRF]/ss.chi-1)*100)
ax.plot((model_copy.sol.chi[:T_IRF]/model_copy.ss.chi-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Export demand (the shock-variable), $\chi_t$')
ax.legend(frameon=True)

ax = fig.add_subplot(3,4,2)
ax.plot((sol.Y[:T_IRF]/ss.Y-1)*100)
ax.plot((model_copy.sol.Y[:T_IRF]/model_copy.ss.Y-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Production, $Y_t$')

ax = fig.add_subplot(3,4,3)
ax.plot((sol.M[:T_IRF]/ss.M-1)*100)
ax.plot((model_copy.sol.M[:T_IRF]/model_copy.ss.M-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Imports, $M_t$')

ax = fig.add_subplot(3,4,4)
ax.plot((sol.tau[:T_IRF]/ss.tau-1)*100)
ax.plot((model_copy.sol.tau[:T_IRF]/model_copy.ss.tau-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Tax-rate, $tau_t$')

ax = fig.add_subplot(3,4,5)
ax.plot((sol.K[:T_IRF]/ss.K-1)*100)
ax.plot((model_copy.sol.K[:T_IRF]/model_copy.ss.K-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Capital, $K_t$')

ax = fig.add_subplot(3,4,6)
ax.plot((sol.I[:T_IRF]/ss.I-1)*100)
ax.plot((model_copy.sol.I[:T_IRF]/model_copy.ss.I-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Investments, $I_t$')

ax = fig.add_subplot(3,4,7)
ax.plot((sol.C[:T_IRF]/ss.C-1)*100)
ax.plot((model_copy.sol.C[:T_IRF]/model_copy.ss.C-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Consumption, $C_t$')

ax = fig.add_subplot(3,4,8)
ax.plot((sol.X[:T_IRF]/ss.X-1)*100)
ax.plot((model_copy.sol.X[:T_IRF]/model_copy.ss.X-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Exports, $X_t$')

ax = fig.add_subplot(3,4,9)
ax.plot((sol.v[:T_IRF]/ss.v-1)*100)
ax.plot((model_copy.sol.v[:T_IRF]/model_copy.ss.v-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Vacancies, $v_t$')

ax = fig.add_subplot(3,4,10)
ax.plot((sol.L[:T_IRF]/ss.L-1)*100)
ax.plot((model_copy.sol.L[:T_IRF]/model_copy.ss.L-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Labour supply, $L_t$')

ax = fig.add_subplot(3,4,11)
ax.plot((sol.real_W[:T_IRF]/ss.real_W-1)*100)
ax.plot((model_copy.sol.real_W[:T_IRF]/model_copy.ss.real_W-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Real wage')

ax = fig.add_subplot(3,4,12)
ax.plot((sol.W[:T_IRF]/ss.W-1)*100)
ax.plot((model_copy.sol.W[:T_IRF]/model_copy.ss.W-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('wage, $w_t$')
# Out:
# Text(0.5, 1.0, 'wage, $w_t$')
