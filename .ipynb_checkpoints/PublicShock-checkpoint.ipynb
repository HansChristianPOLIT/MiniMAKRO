# %% [markdown]
# # Government Demand Shock

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt   
plt.style.use('seaborn-whitegrid')
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

from BabyMAKROModel import BabyMAKROModelClass

# %% [markdown]
# # Setup

# %%
model = BabyMAKROModelClass(name='Extended')

# %%
par = model.par
ss = model.ss
sol = model.sol

# %% [markdown]
# # Find steady state and Jacobian

# %%
model.find_ss(do_print=True)
# Out:
# Labor supply and search and matching:
# ss.S = 4.24,  ss.L = 57.88,  ss.delta_L = 0.04,  ss.v = 9.41,  ss.m_v = 0.23
# Capital agency FOC:
# ss.r_K = 0.14
# Production firm pricing:
# ss.r_ell = 2.71
# Labor agency:
# ss.ell = 57.51,  ss.W = 2.68
# Government:
# ss.B_G = 100.00,  ss.G = 61.82,  ss.tau = 0.42
# Households:
# solving for household behavior: result.converged = True
# ss.C = 98.26,  ss.B = 215.09
# Production firm FOCs:
# ss.K = 573.77
# Capital accumulation equation:
# ss.I = 57.38
# Output in production firm:
# ss.Y = 236.29
# Market clearing:
# ss.C_Y = 68.78,  ss.G_Y = 55.64,  ss.I_Y = 37.29,  ss.X_Y = 74.57
# [ ss.C_M = 29.48,  ss.G_M = 6.18,  ss.I_M = 20.08,  ss.X_M = 49.72 ] = ss.M = 105.46
# ss.X = 124.29
# Bargaining:
# par.phi = 0.981

# %%
model.calc_jac(do_print=True)
# Out:
# Jacobian calculated in 34.8 secs secs

# %% [markdown]
# # Find IRF

# %% [markdown]
# **Set Exogenous variables to steady state:**

# %%
model.set_exo_ss()

# %% [markdown]
# **Introduce shock:**

# %%
Gshock = 50
shock = 0.01*ss.G
persistence = 0.80**np.arange(Gshock)
sol.G[:Gshock] = ss.G + shock*persistence

# %%
model.find_IRF()
# Out:
# initial:
#    max. abs. error = 7.11e-01
#     0.00e+00 in bargaining_cond
#     7.11e-01 in Bq_match
#     3.33e-16 in FOC_capital_agency
#     2.49e-14 in FOC_K_ell
#     5.56e-01 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 7.11e-01
#     7.36e-06 in bargaining_cond
#     2.99e-03 in Bq_match
#     9.83e-06 in FOC_capital_agency
#     1.81e-04 in FOC_K_ell
#     2.20e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.99e-03
#     1.74e-07 in bargaining_cond
#     5.90e-05 in Bq_match
#     1.68e-07 in FOC_capital_agency
#     5.30e-06 in FOC_K_ell
#     6.05e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.05e-05
#     5.36e-09 in bargaining_cond
#     1.19e-06 in Bq_match
#     4.59e-09 in FOC_capital_agency
#     1.69e-07 in FOC_K_ell
#     1.97e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.97e-06
#     1.88e-10 in bargaining_cond
#     4.64e-08 in Bq_match
#     1.44e-10 in FOC_capital_agency
#     5.90e-09 in FOC_K_ell
#     6.74e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.74e-08
#     2.97e-12 in bargaining_cond
#     6.30e-10 in Bq_match
#     3.91e-12 in FOC_capital_agency
#     9.30e-11 in FOC_K_ell
#     1.07e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.07e-09
#     7.82e-14 in bargaining_cond
#     1.28e-11 in Bq_match
#     8.66e-14 in FOC_capital_agency
#     2.17e-12 in FOC_K_ell
#     2.35e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.35e-11
#     3.06e-14 in bargaining_cond
#     7.70e-12 in Bq_match
#     4.33e-14 in FOC_capital_agency
#     3.07e-13 in FOC_K_ell
#     1.17e-11 in mkt_clearing

# %% [markdown]
# # Impulse Response Figures

# %% [markdown]
# ## Longview - To Check Convergence

# %%
model.plot_IRF(varlist=['G','C','Y','K'],T_IRF=par.T,ncol=2)

# %% [markdown]
# ## National Accouting - Quantities

# %%
model.plot_IRF(varlist=['Y','C','G','I','X','M'])

# %% [markdown]
# ## National Accouting - Prices

# %%
model.plot_IRF(varlist=['P_Y','P_C','P_G','P_I','P_X','P_F'])

# %% [markdown]
# ## Labor Market

# %%
model.plot_IRF(varlist=['S','v','curlyM','m_v','m_s','delta_L','W','real_W','W_bar','MPL'],abs=['m_v','m_s'])

# %% [markdown]
# ## Capital Accumulation

# %%
model.plot_IRF(varlist=['K','I','r_K','P_I'],ncol=2)

# %% [markdown]
# ## Production Firms

# %%
model.plot_IRF(varlist=['K','ell','Y','r_K','r_ell'],ncol=2)

# %% [markdown]
# ## Government

# %%
model.plot_IRF(varlist=['G','B_G','tau'],abs=['tau'],Y_share=['B_G'])

# %% [markdown]
# ## Households - Aggregate

# %%
model.plot_IRF(varlist=['L','inc','W','real_W','C','B','Bq'],ncol=3, T_IRF = 150)

# %%
model.plot_IRF(varlist=['C_HtM','C_R'],ncol=2)

# %% [markdown]
# ## Households - Life-cycle

# %%
model.plot_IRF_hh(varlist=['L_a','inc_a','C_a','B_a'],t0_list=[-20,-10,0,10,20])

# %% [markdown]
# # Sensitivity Analysis

# %% [markdown]
# ## Change in HtM-share

# %%
model = BabyMAKROModelClass(name='Extended') # create an instance of the model
par = model.par
ss = model.ss
sol = model.sol
model1 = model.copy()
model2 = model.copy()
model3 = model.copy()

# %%
Models = [model, model1, model2, model3] #Create list of the models
Lambdas = [0.0, 0.1, 0.25, 0.4] #Create list of Lambda values
    
for i in range(len(Models)):
    Models[i].par.Lambda = Lambdas[i]
    Models[i].find_ss()
    Models[i].calc_jac()
    Gshock = 50
    shock_G = 0.01*Models[i].ss.G
    persistence_G = 0.80**np.arange(Gshock)
    Models[i].sol.G[:Gshock] = Models[i].ss.G + shock_G*persistence_G
    Models[i].find_IRF()
# Out:
# initial:
#    max. abs. error = 9.48e-01
#     0.00e+00 in bargaining_cond
#     9.48e-01 in Bq_match
#     3.33e-16 in FOC_capital_agency
#     2.49e-14 in FOC_K_ell
#     5.56e-01 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 9.48e-01
#     7.69e-06 in bargaining_cond
#     3.65e-03 in Bq_match
#     9.14e-06 in FOC_capital_agency
#     1.90e-04 in FOC_K_ell
#     1.89e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.65e-03
#     1.36e-07 in bargaining_cond
#     6.41e-05 in Bq_match
#     1.94e-07 in FOC_capital_agency
#     4.19e-06 in FOC_K_ell
#     4.50e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.41e-05
#     4.54e-09 in bargaining_cond
#     1.53e-06 in Bq_match
#     4.08e-09 in FOC_capital_agency
#     1.48e-07 in FOC_K_ell
#     1.65e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.65e-06
#     1.42e-10 in bargaining_cond
#     5.45e-08 in Bq_match
#     9.99e-11 in FOC_capital_agency
#     4.62e-09 in FOC_K_ell
#     5.11e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.45e-08
#     3.25e-12 in bargaining_cond
#     8.88e-10 in Bq_match
#     2.94e-12 in FOC_capital_agency
#     8.76e-11 in FOC_K_ell
#     9.62e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 9.62e-10
#     5.95e-14 in bargaining_cond
#     1.59e-11 in Bq_match
#     6.57e-14 in FOC_capital_agency
#     1.50e-12 in FOC_K_ell
#     1.89e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.89e-11
#     3.46e-14 in bargaining_cond
#     1.18e-11 in Bq_match
#     4.44e-14 in FOC_capital_agency
#     2.98e-13 in FOC_K_ell
#     1.30e-11 in mkt_clearing
# initial:
#    max. abs. error = 8.53e-01
#     0.00e+00 in bargaining_cond
#     8.53e-01 in Bq_match
#     3.33e-16 in FOC_capital_agency
#     2.49e-14 in FOC_K_ell
#     5.56e-01 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 8.53e-01
#     7.57e-06 in bargaining_cond
#     3.41e-03 in Bq_match
#     9.42e-06 in FOC_capital_agency
#     1.87e-04 in FOC_K_ell
#     2.01e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.41e-03
#     1.48e-07 in bargaining_cond
#     6.22e-05 in Bq_match
#     1.85e-07 in FOC_capital_agency
#     4.65e-06 in FOC_K_ell
#     5.12e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.22e-05
#     4.71e-09 in bargaining_cond
#     1.37e-06 in Bq_match
#     4.33e-09 in FOC_capital_agency
#     1.55e-07 in FOC_K_ell
#     1.75e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.75e-06
#     1.51e-10 in bargaining_cond
#     5.15e-08 in Bq_match
#     1.08e-10 in FOC_capital_agency
#     4.88e-09 in FOC_K_ell
#     5.50e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.50e-08
#     3.03e-12 in bargaining_cond
#     7.87e-10 in Bq_match
#     3.35e-12 in FOC_capital_agency
#     9.08e-11 in FOC_K_ell
#     1.01e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.01e-09
#     6.26e-14 in bargaining_cond
#     1.32e-11 in Bq_match
#     5.64e-14 in FOC_capital_agency
#     1.90e-12 in FOC_K_ell
#     1.93e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.93e-11
#     3.55e-14 in bargaining_cond
#     9.54e-12 in Bq_match
#     3.89e-14 in FOC_capital_agency
#     3.30e-13 in FOC_K_ell
#     1.43e-11 in mkt_clearing
# initial:
#    max. abs. error = 7.11e-01
#     0.00e+00 in bargaining_cond
#     7.11e-01 in Bq_match
#     3.33e-16 in FOC_capital_agency
#     2.49e-14 in FOC_K_ell
#     5.56e-01 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 7.11e-01
#     7.36e-06 in bargaining_cond
#     2.99e-03 in Bq_match
#     9.83e-06 in FOC_capital_agency
#     1.81e-04 in FOC_K_ell
#     2.20e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 2.99e-03
#     1.74e-07 in bargaining_cond
#     5.90e-05 in Bq_match
#     1.68e-07 in FOC_capital_agency
#     5.30e-06 in FOC_K_ell
#     6.05e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.05e-05
#     5.36e-09 in bargaining_cond
#     1.19e-06 in Bq_match
#     4.59e-09 in FOC_capital_agency
#     1.69e-07 in FOC_K_ell
#     1.97e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.97e-06
#     1.88e-10 in bargaining_cond
#     4.64e-08 in Bq_match
#     1.44e-10 in FOC_capital_agency
#     5.90e-09 in FOC_K_ell
#     6.74e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.74e-08
#     2.97e-12 in bargaining_cond
#     6.30e-10 in Bq_match
#     3.91e-12 in FOC_capital_agency
#     9.30e-11 in FOC_K_ell
#     1.07e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.07e-09
#     7.82e-14 in bargaining_cond
#     1.28e-11 in Bq_match
#     8.66e-14 in FOC_capital_agency
#     2.17e-12 in FOC_K_ell
#     2.35e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.35e-11
#     3.06e-14 in bargaining_cond
#     7.70e-12 in Bq_match
#     4.33e-14 in FOC_capital_agency
#     3.07e-13 in FOC_K_ell
#     1.17e-11 in mkt_clearing
# initial:
#    max. abs. error = 5.69e-01
#     0.00e+00 in bargaining_cond
#     5.69e-01 in Bq_match
#     3.33e-16 in FOC_capital_agency
#     2.49e-14 in FOC_K_ell
#     5.56e-01 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.69e-01
#     7.10e-06 in bargaining_cond
#     2.52e-03 in Bq_match
#     1.02e-05 in FOC_capital_agency
#     1.96e-04 in FOC_K_ell
#     2.49e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.52e-03
#     2.07e-07 in bargaining_cond
#     5.46e-05 in Bq_match
#     1.75e-07 in FOC_capital_agency
#     6.39e-06 in FOC_K_ell
#     7.37e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 7.37e-05
#     6.37e-09 in bargaining_cond
#     1.03e-06 in Bq_match
#     5.66e-09 in FOC_capital_agency
#     2.01e-07 in FOC_K_ell
#     2.37e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.37e-06
#     2.24e-10 in bargaining_cond
#     3.94e-08 in Bq_match
#     1.84e-10 in FOC_capital_agency
#     7.09e-09 in FOC_K_ell
#     8.30e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 8.30e-08
#     3.80e-12 in bargaining_cond
#     5.24e-10 in Bq_match
#     4.43e-12 in FOC_capital_agency
#     1.19e-10 in FOC_K_ell
#     1.38e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.38e-09
#     1.08e-13 in bargaining_cond
#     1.45e-11 in Bq_match
#     1.08e-13 in FOC_capital_agency
#     2.88e-12 in FOC_K_ell
#     3.48e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.48e-11
#     3.06e-14 in bargaining_cond
#     6.36e-12 in Bq_match
#     4.30e-14 in FOC_capital_agency
#     3.00e-13 in FOC_K_ell
#     1.19e-11 in mkt_clearing

# %%
T_IRF = 150

fig = plt.figure(figsize=(3*6,3*6/1.5))

ax = fig.add_subplot(3,3,1)
ax.plot((Models[0].sol.G[:T_IRF]/Models[0].ss.G-1)*100,label=f'Baseline: $\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.G[:T_IRF]/Models[1].ss.G-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.G[:T_IRF]/Models[2].ss.G-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.G[:T_IRF]/Models[3].ss.G-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Government Spending ($G_t$)')
ax.legend(frameon=True)

ax = fig.add_subplot(3,3,2)
ax.plot((Models[0].sol.X[:T_IRF]/Models[0].ss.X-1)*100,label=f'Baseline: $\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.X[:T_IRF]/Models[1].ss.X-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.X[:T_IRF]/Models[2].ss.X-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.X[:T_IRF]/Models[3].ss.X-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Export ($X_t$)')

ax = fig.add_subplot(3,3,3)
ax.plot((Models[0].sol.Y[:T_IRF]/Models[0].ss.Y-1)*100,label=f'$Baseline:\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.Y[:T_IRF]/Models[1].ss.Y-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.Y[:T_IRF]/Models[2].ss.Y-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.Y[:T_IRF]/Models[3].ss.Y-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Production ($Y_t$)')

ax = fig.add_subplot(3,3,4)
ax.plot((Models[0].sol.K[:T_IRF]/Models[0].ss.K-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.K[:T_IRF]/Models[1].ss.K-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.K[:T_IRF]/Models[2].ss.K-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.K[:T_IRF]/Models[2].ss.K-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Capital ($K_t$)')

ax = fig.add_subplot(3,3,5)
ax.plot((Models[0].sol.L[:T_IRF]/Models[0].ss.L-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.L[:T_IRF]/Models[1].ss.L-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.L[:T_IRF]/Models[2].ss.L-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.L[:T_IRF]/Models[3].ss.L-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Employment ($L_{t}$)')

ax = fig.add_subplot(3,3,6)
ax.plot((Models[0].sol.W[:T_IRF]/Models[0].ss.W-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.W[:T_IRF]/Models[1].ss.W-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.W[:T_IRF]/Models[2].ss.W-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.W[:T_IRF]/Models[3].ss.W-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Wage ($W_{t}$)')

ax = fig.add_subplot(3,3,7)
ax.plot((Models[0].sol.C[:T_IRF]/Models[0].ss.C-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.C[:T_IRF]/Models[1].ss.C-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.C[:T_IRF]/Models[2].ss.C-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.C[:T_IRF]/Models[3].ss.C-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Consumption ($C_{t}$)')

ax = fig.add_subplot(3,3,8)
ax.plot((Models[0].sol.B[:T_IRF]/Models[0].ss.B-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.B[:T_IRF]/Models[1].ss.B-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.B[:T_IRF]/Models[2].ss.B-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.B[:T_IRF]/Models[3].ss.B-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Savings ($B_{t}$)')

ax = fig.add_subplot(3,3,9)
ax.plot((Models[0].sol.Bq[:T_IRF]/Models[0].ss.Bq-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.Bq[:T_IRF]/Models[1].ss.Bq-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.Bq[:T_IRF]/Models[2].ss.Bq-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.Bq[:T_IRF]/Models[3].ss.Bq-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Bequest ($B^{q}_{t}$)');

# %% [markdown]
# ## Change in Tax Rigidity

# %%
model = BabyMAKROModelClass(name='Extended') # create an instance of the model
par = model.par
ss = model.ss
sol = model.sol
model1 = model.copy()
model2 = model.copy()
model3 = model.copy()

# %%
Models = [model, model1, model2, model3] #Create list of the models
Lambdas_B = [0.0, 0.1, 0.5, 0.8] #Create list of Lambda values
    
for i in range(len(Models)):
    Models[i].par.lambda_B = Lambdas_B[i]
    Models[i].find_ss()
    Models[i].calc_jac()
    Gshock = 50
    shock_G = 0.01*Models[i].ss.G
    persistence_G = 0.80**np.arange(Gshock)
    Models[i].sol.G[:Gshock] = Models[i].ss.G + shock_G*persistence_G
    Models[i].find_IRF()
# Out:
# initial:
#    max. abs. error = 6.97e-01
#     0.00e+00 in bargaining_cond
#     6.97e-01 in Bq_match
#     3.33e-16 in FOC_capital_agency
#     2.49e-14 in FOC_K_ell
#     5.56e-01 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.97e-01
#     7.20e-06 in bargaining_cond
#     2.74e-03 in Bq_match
#     9.55e-06 in FOC_capital_agency
#     1.77e-04 in FOC_K_ell
#     2.08e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.74e-03
#     1.56e-07 in bargaining_cond
#     5.34e-05 in Bq_match
#     1.57e-07 in FOC_capital_agency
#     4.75e-06 in FOC_K_ell
#     5.45e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.45e-05
#     4.77e-09 in bargaining_cond
#     1.05e-06 in Bq_match
#     4.00e-09 in FOC_capital_agency
#     1.51e-07 in FOC_K_ell
#     1.76e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.76e-06
#     1.61e-10 in bargaining_cond
#     4.01e-08 in Bq_match
#     1.24e-10 in FOC_capital_agency
#     5.04e-09 in FOC_K_ell
#     5.78e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.78e-08
#     2.52e-12 in bargaining_cond
#     5.33e-10 in Bq_match
#     3.31e-12 in FOC_capital_agency
#     7.92e-11 in FOC_K_ell
#     9.06e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 9.06e-10
#     6.22e-14 in bargaining_cond
#     1.19e-11 in Bq_match
#     7.59e-14 in FOC_capital_agency
#     1.77e-12 in FOC_K_ell
#     1.90e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.90e-11
#     3.42e-14 in bargaining_cond
#     7.97e-12 in Bq_match
#     3.49e-14 in FOC_capital_agency
#     2.95e-13 in FOC_K_ell
#     1.29e-11 in mkt_clearing
# initial:
#    max. abs. error = 6.98e-01
#     0.00e+00 in bargaining_cond
#     6.98e-01 in Bq_match
#     3.33e-16 in FOC_capital_agency
#     2.49e-14 in FOC_K_ell
#     5.56e-01 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.98e-01
#     7.22e-06 in bargaining_cond
#     2.77e-03 in Bq_match
#     9.60e-06 in FOC_capital_agency
#     1.77e-04 in FOC_K_ell
#     2.10e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.77e-03
#     1.58e-07 in bargaining_cond
#     5.40e-05 in Bq_match
#     1.58e-07 in FOC_capital_agency
#     4.80e-06 in FOC_K_ell
#     5.51e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.51e-05
#     4.84e-09 in bargaining_cond
#     1.06e-06 in Bq_match
#     4.06e-09 in FOC_capital_agency
#     1.53e-07 in FOC_K_ell
#     1.78e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.78e-06
#     1.63e-10 in bargaining_cond
#     4.07e-08 in Bq_match
#     1.27e-10 in FOC_capital_agency
#     5.13e-09 in FOC_K_ell
#     5.88e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.88e-08
#     2.57e-12 in bargaining_cond
#     5.42e-10 in Bq_match
#     3.36e-12 in FOC_capital_agency
#     8.07e-11 in FOC_K_ell
#     9.25e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 9.25e-10
#     6.66e-14 in bargaining_cond
#     1.29e-11 in Bq_match
#     7.75e-14 in FOC_capital_agency
#     1.79e-12 in FOC_K_ell
#     2.19e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.19e-11
#     2.84e-14 in bargaining_cond
#     9.24e-12 in Bq_match
#     3.55e-14 in FOC_capital_agency
#     2.74e-13 in FOC_K_ell
#     1.15e-11 in mkt_clearing
# initial:
#    max. abs. error = 7.11e-01
#     0.00e+00 in bargaining_cond
#     7.11e-01 in Bq_match
#     3.33e-16 in FOC_capital_agency
#     2.49e-14 in FOC_K_ell
#     5.56e-01 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 7.11e-01
#     7.36e-06 in bargaining_cond
#     2.99e-03 in Bq_match
#     9.83e-06 in FOC_capital_agency
#     1.81e-04 in FOC_K_ell
#     2.20e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.99e-03
#     1.74e-07 in bargaining_cond
#     5.90e-05 in Bq_match
#     1.68e-07 in FOC_capital_agency
#     5.30e-06 in FOC_K_ell
#     6.05e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.05e-05
#     5.36e-09 in bargaining_cond
#     1.19e-06 in Bq_match
#     4.59e-09 in FOC_capital_agency
#     1.69e-07 in FOC_K_ell
#     1.97e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.97e-06
#     1.88e-10 in bargaining_cond
#     4.64e-08 in Bq_match
#     1.44e-10 in FOC_capital_agency
#     5.90e-09 in FOC_K_ell
#     6.74e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.74e-08
#     2.97e-12 in bargaining_cond
#     6.30e-10 in Bq_match
#     3.91e-12 in FOC_capital_agency
#     9.30e-11 in FOC_K_ell
#     1.07e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.07e-09
#     7.82e-14 in bargaining_cond
#     1.28e-11 in Bq_match
#     8.66e-14 in FOC_capital_agency
#     2.17e-12 in FOC_K_ell
#     2.35e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.35e-11
#     3.06e-14 in bargaining_cond
#     7.70e-12 in Bq_match
#     4.33e-14 in FOC_capital_agency
#     3.07e-13 in FOC_K_ell
#     1.17e-11 in mkt_clearing
# initial:
#    max. abs. error = 7.37e-01
#     0.00e+00 in bargaining_cond
#     7.37e-01 in Bq_match
#     3.33e-16 in FOC_capital_agency
#     2.49e-14 in FOC_K_ell
#     5.56e-01 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 7.37e-01
#     7.80e-06 in bargaining_cond
#     3.45e-03 in Bq_match
#     1.01e-05 in FOC_capital_agency
#     1.95e-04 in FOC_K_ell
#     2.40e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.45e-03
#     2.04e-07 in bargaining_cond
#     7.31e-05 in Bq_match
#     1.98e-07 in FOC_capital_agency
#     6.45e-06 in FOC_K_ell
#     7.27e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 7.31e-05
#     6.59e-09 in bargaining_cond
#     1.66e-06 in Bq_match
#     5.88e-09 in FOC_capital_agency
#     2.16e-07 in FOC_K_ell
#     2.50e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.50e-06
#     2.39e-10 in bargaining_cond
#     6.63e-08 in Bq_match
#     1.78e-10 in FOC_capital_agency
#     7.59e-09 in FOC_K_ell
#     8.74e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 8.74e-08
#     4.39e-12 in bargaining_cond
#     9.70e-10 in Bq_match
#     5.13e-12 in FOC_capital_agency
#     1.41e-10 in FOC_K_ell
#     1.59e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.59e-09
#     1.26e-13 in bargaining_cond
#     1.91e-11 in Bq_match
#     1.26e-13 in FOC_capital_agency
#     3.65e-12 in FOC_K_ell
#     4.10e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.10e-11
#     3.15e-14 in bargaining_cond
#     8.78e-12 in Bq_match
#     3.82e-14 in FOC_capital_agency
#     3.25e-13 in FOC_K_ell
#     1.27e-11 in mkt_clearing

# %%
T_IRF = 150

fig = plt.figure(figsize=(3*6,3*6/1.5))

ax = fig.add_subplot(3,3,1)
ax.plot((Models[0].sol.G[:T_IRF]/Models[0].ss.G-1)*100,label=f'Baseline: $\lambda^B$ = {Models[0].par.lambda_B}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.G[:T_IRF]/Models[1].ss.G-1)*100,label=f'$\lambda^B$ = {Models[1].par.lambda_B}')
ax.plot((Models[2].sol.G[:T_IRF]/Models[2].ss.G-1)*100,label=f'$\lambda^B$ = {Models[2].par.lambda_B}')
ax.plot((Models[3].sol.G[:T_IRF]/Models[3].ss.G-1)*100,label=f'$\lambda^B$ = {Models[3].par.lambda_B}')
ax.set_ylabel('% of s.s.')
ax.set_title('Government Spending ($G_t$)')
ax.legend(frameon=True)

ax = fig.add_subplot(3,3,2)
ax.plot((Models[0].sol.X[:T_IRF]/Models[0].ss.X-1)*100,label=f'Baseline: $\lambda$ = {Models[0].par.lambda_B}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.X[:T_IRF]/Models[1].ss.X-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_B}')
ax.plot((Models[2].sol.X[:T_IRF]/Models[2].ss.X-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_B}')
ax.plot((Models[3].sol.X[:T_IRF]/Models[3].ss.X-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_B}')
ax.set_ylabel('% of s.s.')
ax.set_title('Export ($X_t$)')

ax = fig.add_subplot(3,3,3)
ax.plot((Models[0].sol.Y[:T_IRF]/Models[0].ss.Y-1)*100,label=f'$Baseline:\lambda$ = {Models[0].par.lambda_B}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.Y[:T_IRF]/Models[1].ss.Y-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_B}')
ax.plot((Models[2].sol.Y[:T_IRF]/Models[2].ss.Y-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_B}')
ax.plot((Models[3].sol.Y[:T_IRF]/Models[3].ss.Y-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_B}')
ax.set_ylabel('% of s.s.')
ax.set_title('Production ($Y_t$)')

ax = fig.add_subplot(3,3,4)
ax.plot((Models[0].sol.K[:T_IRF]/Models[0].ss.K-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.lambda_B}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.K[:T_IRF]/Models[1].ss.K-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_B}')
ax.plot((Models[2].sol.K[:T_IRF]/Models[2].ss.K-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_B}')
ax.plot((Models[3].sol.K[:T_IRF]/Models[2].ss.K-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_B}')
ax.set_ylabel('% of s.s.')
ax.set_title('Capital ($K_t$)')

ax = fig.add_subplot(3,3,5)
ax.plot((Models[0].sol.L[:T_IRF]/Models[0].ss.L-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.lambda_B}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.L[:T_IRF]/Models[1].ss.L-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_B}')
ax.plot((Models[2].sol.L[:T_IRF]/Models[2].ss.L-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_B}')
ax.plot((Models[3].sol.L[:T_IRF]/Models[3].ss.L-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_B}')
ax.set_ylabel('% of s.s.')
ax.set_title('Employment ($L_{t}$)')

ax = fig.add_subplot(3,3,6)
ax.plot((Models[0].sol.W[:T_IRF]/Models[0].ss.W-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.lambda_B}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.W[:T_IRF]/Models[1].ss.W-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_B}')
ax.plot((Models[2].sol.W[:T_IRF]/Models[2].ss.W-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_B}')
ax.plot((Models[3].sol.W[:T_IRF]/Models[3].ss.W-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_B}')
ax.set_ylabel('% of s.s.')
ax.set_title('Wage ($W_{t}$)')

ax = fig.add_subplot(3,3,7)
ax.plot((Models[0].sol.C[:T_IRF]/Models[0].ss.C-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.lambda_B}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.C[:T_IRF]/Models[1].ss.C-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_B}')
ax.plot((Models[2].sol.C[:T_IRF]/Models[2].ss.C-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_B}')
ax.plot((Models[3].sol.C[:T_IRF]/Models[3].ss.C-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_B}')
ax.set_ylabel('% of s.s.')
ax.set_title('Consumption ($C_{t}$)')

ax = fig.add_subplot(3,3,8)
ax.plot((Models[0].sol.B[:T_IRF]/Models[0].ss.B-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.lambda_B}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.B[:T_IRF]/Models[1].ss.B-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_B}')
ax.plot((Models[2].sol.B[:T_IRF]/Models[2].ss.B-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_B}')
ax.plot((Models[3].sol.B[:T_IRF]/Models[3].ss.B-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_B}')
ax.set_ylabel('% of s.s.')
ax.set_title('Savings ($B_{t}$)')

ax = fig.add_subplot(3,3,9)
ax.plot((Models[0].sol.Bq[:T_IRF]/Models[0].ss.Bq-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.lambda_B}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.Bq[:T_IRF]/Models[1].ss.Bq-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_B}')
ax.plot((Models[2].sol.Bq[:T_IRF]/Models[2].ss.Bq-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_B}')
ax.plot((Models[3].sol.Bq[:T_IRF]/Models[3].ss.Bq-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_B}')
ax.set_ylabel('% of s.s.')
ax.set_title('Bequest ($B^{q}_{t}$)');
