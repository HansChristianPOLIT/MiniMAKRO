# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt   
plt.style.use('seaborn-whitegrid')
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

from BabyMAKROModel import BabyMAKROModelClass
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Setup

# %%
model = BabyMAKROModelClass(name='Extended')

# %%
par = model.par
ss = model.ss
sol = model.sol

# %% [markdown]
# # Find steady state and Jacobian

# %%
model.find_ss(do_print=True)
# Out:
# Labor supply and search and matching:
# ss.S = 7.44,  ss.L = 56.28,  ss.delta_L = 0.07,  ss.v = 16.52,  ss.m_v = 0.23
# Capital agency FOC:
# ss.r_K = 0.14
# Production firm pricing:
# ss.r_ell = 2.71
# Labor agency:
# ss.ell = 55.46,  ss.W = 2.65
# Government:
# ss.B_G = 150.00,  ss.G = 50.00,  ss.tau = 0.38
# Households:
# solving for household behavior: result.converged = True
# ss.C = 82.12,  ss.B = 168.84
# Production firm FOCs:
# ss.K = 553.31
# Capital accumulation equation:
# ss.I = 55.33
# Output in production firm:
# ss.Y = 227.87
# Market clearing:
# ss.C_Y = 57.48,  ss.G_Y = 45.00,  ss.I_Y = 35.97,  ss.X_Y = 89.42
# [ ss.C_M = 24.64,  ss.G_M = 5.00,  ss.I_M = 19.37,  ss.X_M = 59.61 ] = ss.M = 108.61
# ss.X = 149.03
# Bargaining:
# par.phi = 0.968

# %%
model.calc_jac(do_print=True)
# Out:
# Jacobian calculated in 36.0 secs secs

# %% [markdown]
# # Find IRF

# %%
model.set_exo_ss()

# %%
Gshock = 50
shock = 0.01*ss.G
persistence = 0.80**np.arange(Gshock)
sol.G[:Gshock] = ss.G + shock*persistence

# %%
model.set_unknowns_ss()
model.evaluate_blocks()
errors = model.get_errors(do_print=True)
# Out:
# bargaining_cond     : abs. max = 0.00e+00
# Bq_match            : abs. max = 1.65e+00
# FOC_capital_agency  : abs. max = 0.00e+00
# FOC_K_ell           : abs. max = 1.95e-14
# mkt_clearing        : abs. max = 4.50e-01

# %%
model.find_IRF()
# Out:
# initial:
#    max. abs. error = 1.65e+00
#     0.00e+00 in bargaining_cond
#     1.65e+00 in Bq_match
#     0.00e+00 in FOC_capital_agency
#     1.95e-14 in FOC_K_ell
#     4.50e-01 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.65e+00
#     2.50e-06 in bargaining_cond
#     3.53e-03 in Bq_match
#     2.13e-06 in FOC_capital_agency
#     9.28e-05 in FOC_K_ell
#     1.56e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.53e-03
#     5.43e-08 in bargaining_cond
#     1.47e-05 in Bq_match
#     4.86e-08 in FOC_capital_agency
#     1.67e-06 in FOC_K_ell
#     2.43e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.43e-05
#     1.11e-09 in bargaining_cond
#     2.46e-07 in Bq_match
#     8.41e-10 in FOC_capital_agency
#     3.58e-08 in FOC_K_ell
#     6.95e-07 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.95e-07
#     2.21e-11 in bargaining_cond
#     4.50e-09 in Bq_match
#     1.97e-11 in FOC_capital_agency
#     7.04e-10 in FOC_K_ell
#     1.22e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.22e-08
#     2.53e-13 in bargaining_cond
#     3.40e-11 in Bq_match
#     2.40e-13 in FOC_capital_agency
#     8.28e-12 in FOC_K_ell
#     1.73e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.73e-10
#     3.69e-14 in bargaining_cond
#     6.74e-12 in Bq_match
#     4.39e-14 in FOC_capital_agency
#     2.24e-13 in FOC_K_ell
#     2.19e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.19e-11
#     3.55e-14 in bargaining_cond
#     6.65e-12 in Bq_match
#     3.86e-14 in FOC_capital_agency
#     3.27e-13 in FOC_K_ell
#     2.02e-11 in mkt_clearing

# %% [markdown]
# # Figures

# %% [markdown]
# ## National accouting - quantities

# %%
model.plot_IRF(varlist=['Y','C','G','I','X','M'])

# %% [markdown]
# ## National Accouting - Prices

# %%
model.plot_IRF(varlist=['P_Y','P_C','P_G','P_I','P_X','P_F'])

# %% [markdown]
# ## Labor market

# %%
model.plot_IRF(varlist=['S','v','curlyM','m_v','m_s','delta_L','W','real_W'],abs=['m_v','m_s'])

# %% [markdown]
# ## Capital accumulation

# %%
model.plot_IRF(varlist=['K','I','r_K','P_I'],ncol=2)

# %% [markdown]
# ## Production firms

# %%
model.plot_IRF(varlist=['K','ell','Y','r_K','r_ell'],ncol=2)

# %% [markdown]
# ## Government

# %%
model.plot_IRF(varlist=['G','B_G','tau'],abs=['tau'],Y_share=['B_G'])

# %% [markdown]
# ## Households - aggregate

# %%
model.plot_IRF(varlist=['L','W','real_W','C','B','Bq'],ncol=3, T_IRF = 150)

# %%
model.plot_IRF(varlist=['C_HtM','C_R'],ncol=2)

# %% [markdown]
# ## Households - Life-cycle

# %%
model.plot_IRF_hh(varlist=['L_a','inc_a','C_a','B_a'],t0_list=[-20,-10,0,10,20])
