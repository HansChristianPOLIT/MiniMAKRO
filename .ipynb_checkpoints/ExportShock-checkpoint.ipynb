# %% [markdown]
# # Foreign Demand Shock

# %%
# %load_ext autoreload
# %autoreload 2

import time
import pickle
import numpy as np
from scipy import optimize

import matplotlib.pyplot as plt   
plt.style.use('seaborn-whitegrid')
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

from BabyMAKROModel import BabyMAKROModelClass

# %% [markdown]
# # Setup

# %%
model = BabyMAKROModelClass(name='Extended') # create an instance of the model

# %%
par = model.par
ss = model.ss
sol = model.sol

# %% [markdown]
# # Find steady state

# %%
model.find_ss(do_print=True)
# Out:
# Labor supply and search and matching:
# ss.S = 4.24,  ss.L = 57.88,  ss.delta_L = 0.04,  ss.v = 9.41,  ss.m_v = 0.23
# Capital agency FOC:
# ss.r_K = 0.14
# Production firm pricing:
# ss.r_ell = 2.71
# Labor agency:
# ss.ell = 57.41,  ss.W = 2.67
# Government:
# ss.B_G = 100.00,  ss.G = 61.82,  ss.tau = 0.42
# Households:
# solving for household behavior: result.converged = True
# ss.C = 93.66,  ss.B = 111.48
# Production firm FOCs:
# ss.K = 572.83
# Capital accumulation equation:
# ss.I = 57.28
# Output in production firm:
# ss.Y = 235.90
# Market clearing:
# ss.C_Y = 65.56,  ss.G_Y = 55.64,  ss.I_Y = 37.23,  ss.X_Y = 77.47
# [ ss.C_M = 28.10,  ss.G_M = 6.18,  ss.I_M = 20.05,  ss.X_M = 51.65 ] = ss.M = 105.98
# ss.X = 129.11
# Bargaining:
# par.phi = 0.977

# %% [markdown]
# # Find an impulse-response

# %% [markdown]
# **Calculate Jacobian:**

# %%
model.calc_jac(do_print=True)
# Out:
# Jacobian calculated in 34.6 secs secs

# %% [markdown]
# **Set exogenous variables:**

# %%
model.set_exo_ss()

# %% [markdown]
# **Introduce Shock**

# %%
Tshock = 50
shock = 0.01*ss.chi
persistence = 0.8**np.arange(Tshock)
sol.chi[:Tshock] = ss.chi + shock*persistence

Tshock = 50
shock = 0.03*ss.P_F
persistence = 0.80**np.arange(Tshock)
sol.P_F[:Tshock] = ss.P_F + shock*persistence

# %% [markdown]
# **Find IRF:**

# %%
model.find_IRF()
# Out:
# initial:
#    max. abs. error = 2.65e+00
#     0.00e+00 in bargaining_cond
#     1.43e-11 in Bq_match
#     4.44e-16 in FOC_capital_agency
#     3.38e-14 in FOC_K_ell
#     2.65e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 2.65e+00
#     2.90e-04 in bargaining_cond
#     3.43e-02 in Bq_match
#     2.28e-04 in FOC_capital_agency
#     7.61e-03 in FOC_K_ell
#     1.80e-01 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.80e-01
#     3.97e-05 in bargaining_cond
#     1.58e-03 in Bq_match
#     4.08e-05 in FOC_capital_agency
#     9.69e-04 in FOC_K_ell
#     1.38e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.38e-02
#     2.96e-06 in bargaining_cond
#     1.84e-04 in Bq_match
#     3.14e-06 in FOC_capital_agency
#     6.89e-05 in FOC_K_ell
#     1.07e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.07e-03
#     5.32e-07 in bargaining_cond
#     2.11e-05 in Bq_match
#     5.44e-07 in FOC_capital_agency
#     1.26e-05 in FOC_K_ell
#     2.05e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.05e-04
#     3.96e-08 in bargaining_cond
#     1.20e-06 in Bq_match
#     3.99e-08 in FOC_capital_agency
#     9.48e-07 in FOC_K_ell
#     1.55e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.55e-05
#     6.14e-10 in bargaining_cond
#     1.41e-07 in Bq_match
#     5.05e-10 in FOC_capital_agency
#     1.97e-08 in FOC_K_ell
#     2.34e-07 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.34e-07
#     3.08e-11 in bargaining_cond
#     7.74e-09 in Bq_match
#     2.49e-11 in FOC_capital_agency
#     1.03e-09 in FOC_K_ell
#     1.27e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.27e-08
#     1.31e-12 in bargaining_cond
#     1.43e-10 in Bq_match
#     1.22e-12 in FOC_capital_agency
#     3.22e-11 in FOC_K_ell
#     4.96e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.96e-10
#     9.46e-14 in bargaining_cond
#     8.10e-12 in Bq_match
#     1.03e-13 in FOC_capital_agency
#     2.67e-12 in FOC_K_ell
#     3.43e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.43e-11
#     3.24e-14 in bargaining_cond
#     5.37e-12 in Bq_match
#     3.71e-14 in FOC_capital_agency
#     4.51e-13 in FOC_K_ell
#     1.32e-11 in mkt_clearing

# %% [markdown]
# # Impulse Response Figures

# %% [markdown]
# ## Longview - To Check Convergence

# %%
model.plot_IRF(varlist=['X','C','Y','K'],T_IRF=par.T,ncol=2)

# %% [markdown]
# ## National accouting - Quantities

# %%
model.plot_IRF(varlist=['Y','C','G','I','X','M'])

# %% [markdown]
# ## National Accouting - Prices

# %%
model.plot_IRF(varlist=['P_Y','P_C','P_G','P_I','P_X','P_F'])

# %% [markdown]
# ## Labor market

# %%
model.plot_IRF(varlist=['S','v','curlyM','m_v','m_s','delta_L','W','real_W'],abs=['m_v','m_s'])

# %% [markdown]
# ## Capital accumulation

# %%
model.plot_IRF(varlist=['K','I','r_K','P_I'],ncol=2)

# %% [markdown]
# ## Production firms

# %%
model.plot_IRF(varlist=['K','ell','Y','r_K','r_ell'],ncol=2)

# %% [markdown]
# ## Government

# %%
model.plot_IRF(varlist=['G','B_G','tau'],abs=['tau'],Y_share=['B_G'])

# %% [markdown]
# ## Households - aggregate

# %%
model.plot_IRF(varlist=['L','inc','W','real_W','C','B','Bq'],ncol=3, T_IRF = 150)

# %%
model.plot_IRF(varlist=['C_HtM','C_R'],ncol=2, T_IRF = 150)

# %% [markdown]
# ## Households - life-cycle

# %%
model.plot_IRF_hh(varlist=['L_a','inc_a','C_a','B_a'],t0_list=[-20,-10,0,10,20])

# %% [markdown]
# # Sensitivity Analysis

# %% [markdown]
# ## Change in HtM-share

# %%
model = BabyMAKROModelClass(name='Extended') # create an instance of the model
par = model.par
ss = model.ss
sol = model.sol
model1 = model.copy()
model2 = model.copy()
model3 = model.copy()

# %%
Models = [model, model1, model2, model3] #Create list of the models
Lambdas = [0.0, 0.1, 0.25, 0.4] #Create list of Lambda values
    
for i in range(len(Models)):
    Models[i].par.Lambda = Lambdas[i]
    Models[i].find_ss()
    Models[i].calc_jac()
    Gshock = 50
    shock_chi = 0.01*Models[i].ss.chi
    persistence_chi = 0.8**np.arange(Tshock)
    Models[i].sol.chi[:Tshock] = Models[i].ss.chi + shock_chi*persistence_chi
    shock_p_f = 0.03*ss.P_F
    persistence_p_f = 0.80**np.arange(Tshock)
    Models[i].sol.P_F[:Tshock] = ss.P_F + shock_p_f*persistence_p_f
    Models[i].find_IRF()
# Out:
# initial:
#    max. abs. error = 2.62e+00
#     0.00e+00 in bargaining_cond
#     1.71e-11 in Bq_match
#     4.44e-16 in FOC_capital_agency
#     3.38e-14 in FOC_K_ell
#     2.62e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 2.62e+00
#     2.82e-04 in bargaining_cond
#     4.09e-02 in Bq_match
#     2.22e-04 in FOC_capital_agency
#     7.40e-03 in FOC_K_ell
#     1.75e-01 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 1.75e-01
#     3.79e-05 in bargaining_cond
#     1.89e-03 in Bq_match
#     3.90e-05 in FOC_capital_agency
#     9.25e-04 in FOC_K_ell
#     1.30e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.30e-02
#     2.90e-06 in bargaining_cond
#     2.04e-04 in Bq_match
#     3.07e-06 in FOC_capital_agency
#     6.76e-05 in FOC_K_ell
#     1.05e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.05e-03
#     4.93e-07 in bargaining_cond
#     2.41e-05 in Bq_match
#     5.03e-07 in FOC_capital_agency
#     1.17e-05 in FOC_K_ell
#     1.89e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.89e-04
#     3.36e-08 in bargaining_cond
#     1.28e-06 in Bq_match
#     3.38e-08 in FOC_capital_agency
#     8.04e-07 in FOC_K_ell
#     1.31e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 1.31e-05
#     5.06e-10 in bargaining_cond
#     1.56e-07 in Bq_match
#     3.85e-10 in FOC_capital_agency
#     1.63e-08 in FOC_K_ell
#     1.91e-07 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 1.91e-07
#     2.22e-11 in bargaining_cond
#     7.43e-09 in Bq_match
#     1.80e-11 in FOC_capital_agency
#     7.47e-10 in FOC_K_ell
#     9.05e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 9.05e-09
#     1.35e-12 in bargaining_cond
#     1.32e-10 in Bq_match
#     1.24e-12 in FOC_capital_agency
#     3.22e-11 in FOC_K_ell
#     5.05e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.05e-10
#     6.35e-14 in bargaining_cond
#     1.06e-11 in Bq_match
#     7.86e-14 in FOC_capital_agency
#     1.97e-12 in FOC_K_ell
#     2.28e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.28e-11
#     3.77e-14 in bargaining_cond
#     6.22e-12 in Bq_match
#     4.42e-14 in FOC_capital_agency
#     4.00e-13 in FOC_K_ell
#     1.57e-11 in mkt_clearing
# initial:
#    max. abs. error = 2.64e+00
#     0.00e+00 in bargaining_cond
#     1.76e-11 in Bq_match
#     4.44e-16 in FOC_capital_agency
#     3.38e-14 in FOC_K_ell
#     2.64e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.64e+00
#     2.86e-04 in bargaining_cond
#     3.77e-02 in Bq_match
#     2.25e-04 in FOC_capital_agency
#     7.50e-03 in FOC_K_ell
#     1.78e-01 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.78e-01
#     3.88e-05 in bargaining_cond
#     1.74e-03 in Bq_match
#     3.99e-05 in FOC_capital_agency
#     9.47e-04 in FOC_K_ell
#     1.34e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.34e-02
#     2.93e-06 in bargaining_cond
#     1.95e-04 in Bq_match
#     3.10e-06 in FOC_capital_agency
#     6.83e-05 in FOC_K_ell
#     1.06e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.06e-03
#     5.12e-07 in bargaining_cond
#     2.27e-05 in Bq_match
#     5.23e-07 in FOC_capital_agency
#     1.22e-05 in FOC_K_ell
#     1.97e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.97e-04
#     3.65e-08 in bargaining_cond
#     1.25e-06 in Bq_match
#     3.67e-08 in FOC_capital_agency
#     8.74e-07 in FOC_K_ell
#     1.42e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.42e-05
#     5.57e-10 in bargaining_cond
#     1.49e-07 in Bq_match
#     4.28e-10 in FOC_capital_agency
#     1.79e-08 in FOC_K_ell
#     2.11e-07 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.11e-07
#     2.62e-11 in bargaining_cond
#     7.66e-09 in Bq_match
#     2.13e-11 in FOC_capital_agency
#     8.81e-10 in FOC_K_ell
#     1.08e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.08e-08
#     1.34e-12 in bargaining_cond
#     1.38e-10 in Bq_match
#     1.25e-12 in FOC_capital_agency
#     3.22e-11 in FOC_K_ell
#     5.04e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.04e-10
#     9.02e-14 in bargaining_cond
#     9.45e-12 in Bq_match
#     8.70e-14 in FOC_capital_agency
#     2.43e-12 in FOC_K_ell
#     3.17e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.17e-11
#     2.93e-14 in bargaining_cond
#     5.53e-12 in Bq_match
#     4.70e-14 in FOC_capital_agency
#     5.36e-13 in FOC_K_ell
#     1.15e-11 in mkt_clearing
# initial:
#    max. abs. error = 2.65e+00
#     0.00e+00 in bargaining_cond
#     1.28e-11 in Bq_match
#     4.44e-16 in FOC_capital_agency
#     3.38e-14 in FOC_K_ell
#     2.65e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.65e+00
#     2.92e-04 in bargaining_cond
#     3.25e-02 in Bq_match
#     2.29e-04 in FOC_capital_agency
#     7.67e-03 in FOC_K_ell
#     1.82e-01 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.82e-01
#     4.02e-05 in bargaining_cond
#     1.49e-03 in Bq_match
#     4.13e-05 in FOC_capital_agency
#     9.80e-04 in FOC_K_ell
#     1.39e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.39e-02
#     2.98e-06 in bargaining_cond
#     1.78e-04 in Bq_match
#     3.15e-06 in FOC_capital_agency
#     6.91e-05 in FOC_K_ell
#     1.08e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.08e-03
#     5.43e-07 in bargaining_cond
#     2.03e-05 in Bq_match
#     5.56e-07 in FOC_capital_agency
#     1.29e-05 in FOC_K_ell
#     2.10e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.10e-04
#     4.13e-08 in bargaining_cond
#     1.17e-06 in Bq_match
#     4.16e-08 in FOC_capital_agency
#     9.87e-07 in FOC_K_ell
#     1.61e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.61e-05
#     6.44e-10 in bargaining_cond
#     1.36e-07 in Bq_match
#     6.14e-10 in FOC_capital_agency
#     2.06e-08 in FOC_K_ell
#     2.46e-07 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.46e-07
#     3.32e-11 in bargaining_cond
#     7.72e-09 in Bq_match
#     2.69e-11 in FOC_capital_agency
#     1.11e-09 in FOC_K_ell
#     1.38e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.38e-08
#     1.26e-12 in bargaining_cond
#     1.43e-10 in Bq_match
#     1.21e-12 in FOC_capital_agency
#     3.37e-11 in FOC_K_ell
#     4.74e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.74e-10
#     9.86e-14 in bargaining_cond
#     1.05e-11 in Bq_match
#     1.46e-13 in FOC_capital_agency
#     2.78e-12 in FOC_K_ell
#     4.03e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 4.03e-11
#     2.93e-14 in bargaining_cond
#     4.44e-12 in Bq_match
#     4.65e-14 in FOC_capital_agency
#     4.67e-13 in FOC_K_ell
#     1.25e-11 in mkt_clearing
# initial:
#    max. abs. error = 2.67e+00
#     0.00e+00 in bargaining_cond
#     9.55e-12 in Bq_match
#     4.44e-16 in FOC_capital_agency
#     3.38e-14 in FOC_K_ell
#     2.67e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.67e+00
#     2.99e-04 in bargaining_cond
#     2.70e-02 in Bq_match
#     2.34e-04 in FOC_capital_agency
#     7.83e-03 in FOC_K_ell
#     1.86e-01 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.86e-01
#     4.16e-05 in bargaining_cond
#     1.23e-03 in Bq_match
#     4.28e-05 in FOC_capital_agency
#     1.02e-03 in FOC_K_ell
#     1.45e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.45e-02
#     3.01e-06 in bargaining_cond
#     1.56e-04 in Bq_match
#     3.20e-06 in FOC_capital_agency
#     6.99e-05 in FOC_K_ell
#     1.10e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.10e-03
#     5.77e-07 in bargaining_cond
#     1.74e-05 in Bq_match
#     5.92e-07 in FOC_capital_agency
#     1.37e-05 in FOC_K_ell
#     2.24e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.24e-04
#     4.66e-08 in bargaining_cond
#     1.06e-06 in Bq_match
#     4.70e-08 in FOC_capital_agency
#     1.11e-06 in FOC_K_ell
#     1.83e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.83e-05
#     9.05e-10 in bargaining_cond
#     1.20e-07 in Bq_match
#     9.68e-10 in FOC_capital_agency
#     2.37e-08 in FOC_K_ell
#     3.63e-07 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.63e-07
#     4.16e-11 in bargaining_cond
#     7.42e-09 in Bq_match
#     3.37e-11 in FOC_capital_agency
#     1.39e-09 in FOC_K_ell
#     1.74e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.74e-08
#     1.25e-12 in bargaining_cond
#     1.37e-10 in Bq_match
#     1.52e-12 in FOC_capital_agency
#     3.92e-11 in FOC_K_ell
#     4.70e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.70e-10
#     1.17e-13 in bargaining_cond
#     9.13e-12 in Bq_match
#     1.59e-13 in FOC_capital_agency
#     3.52e-12 in FOC_K_ell
#     4.23e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.23e-11
#     2.93e-14 in bargaining_cond
#     3.89e-12 in Bq_match
#     4.39e-14 in FOC_capital_agency
#     4.57e-13 in FOC_K_ell
#     1.20e-11 in mkt_clearing

# %%
T_IRF = 150

fig = plt.figure(figsize=(3*6,3*6/1.5))

ax = fig.add_subplot(3,3,1)
ax.plot((Models[0].sol.chi[:T_IRF]/Models[0].ss.chi-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.chi[:T_IRF]/Models[1].ss.chi-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.chi[:T_IRF]/Models[2].ss.chi-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.chi[:T_IRF]/Models[3].ss.chi-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Foreign Demand Shifter ($\chi_t$)')
ax.legend(frameon=True)

ax = fig.add_subplot(3,3,2)
ax.plot((Models[0].sol.X[:T_IRF]/Models[0].ss.X-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.X[:T_IRF]/Models[1].ss.X-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.X[:T_IRF]/Models[2].ss.X-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.X[:T_IRF]/Models[3].ss.X-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Export ($X_t$)')

ax = fig.add_subplot(3,3,3)
ax.plot((Models[0].sol.Y[:T_IRF]/Models[0].ss.Y-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.Y[:T_IRF]/Models[1].ss.Y-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.Y[:T_IRF]/Models[2].ss.Y-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.Y[:T_IRF]/Models[3].ss.Y-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Production ($Y_t$)')

ax = fig.add_subplot(3,3,4)
ax.plot((Models[0].sol.K[:T_IRF]/Models[0].ss.K-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.K[:T_IRF]/Models[1].ss.K-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.K[:T_IRF]/Models[2].ss.K-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.K[:T_IRF]/Models[3].ss.K-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Capital ($K_t$)')

ax = fig.add_subplot(3,3,5)
ax.plot((Models[0].sol.L[:T_IRF]/Models[0].ss.L-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.L[:T_IRF]/Models[1].ss.L-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.L[:T_IRF]/Models[2].ss.L-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.L[:T_IRF]/Models[3].ss.L-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Employment ($L_t$)')

ax = fig.add_subplot(3,3,6)
ax.plot((Models[0].sol.W[:T_IRF]/Models[0].ss.W-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.W[:T_IRF]/Models[1].ss.W-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.W[:T_IRF]/Models[2].ss.W-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.W[:T_IRF]/Models[3].ss.W-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Wage ($W_{t}$)')

ax = fig.add_subplot(3,3,7)
ax.plot((Models[0].sol.C[:T_IRF]/Models[0].ss.C-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.C[:T_IRF]/Models[1].ss.C-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.C[:T_IRF]/Models[2].ss.C-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.C[:T_IRF]/Models[3].ss.C-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Consumption ($C_{t}$)')

ax = fig.add_subplot(3,3,8)
ax.plot((Models[0].sol.B[:T_IRF]/Models[0].ss.B-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.B[:T_IRF]/Models[1].ss.B-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.B[:T_IRF]/Models[2].ss.B-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.B[:T_IRF]/Models[3].ss.B-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Savings ($B_{t}$)')

ax = fig.add_subplot(3,3,9)
ax.plot((Models[0].sol.Bq[:T_IRF]/Models[0].ss.Bq-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.Bq[:T_IRF]/Models[1].ss.Bq-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.Bq[:T_IRF]/Models[2].ss.Bq-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.Bq[:T_IRF]/Models[3].ss.Bq-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Bequest ($B^{q}_{t}$)')
fig.tight_layout(pad=1.0); # spacing between subplots

# %% [markdown]
# ## Change in Export Rigidity

# %%
model = BabyMAKROModelClass(name='Extended') # create an instance of the model
par = model.par
ss = model.ss
sol = model.sol
model1 = model.copy()
model2 = model.copy()
model3 = model.copy()

# %%
Models = [model, model1, model2, model3] #Create list of the models
Lambdas_X = [0.0, 0.3, 0.5, 0.8] #Create list of Lambda values, 0.8 er jf. MAKRO documentation med Export 
    
for i in range(len(Models)):
    Models[i].par.lambda_X = Lambdas_X[i]
    Models[i].find_ss()
    Models[i].calc_jac()
    Gshock = 50
    shock_chi = 0.01*Models[i].ss.chi
    persistence_chi = 0.8**np.arange(Tshock)
    Models[i].sol.chi[:Tshock] = Models[i].ss.chi + shock_chi*persistence_chi
    shock_p_f = 0.03*ss.P_F
    persistence_p_f = 0.80**np.arange(Tshock)
    Models[i].sol.P_F[:Tshock] = ss.P_F + shock_p_f*persistence_p_f
    Models[i].find_IRF()
# Out:
# initial:
#    max. abs. error = 1.32e+01
#     0.00e+00 in bargaining_cond
#     1.43e-11 in Bq_match
#     4.44e-16 in FOC_capital_agency
#     3.38e-14 in FOC_K_ell
#     1.32e+01 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 1.32e+01
#     1.76e-03 in bargaining_cond
#     2.52e-01 in Bq_match
#     1.66e-03 in FOC_capital_agency
#     4.64e-02 in FOC_K_ell
#     1.86e+00 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.86e+00
#     5.32e-04 in bargaining_cond
#     2.68e-02 in Bq_match
#     6.08e-04 in FOC_capital_agency
#     1.26e-02 in FOC_K_ell
#     3.04e-01 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.04e-01
#     9.74e-05 in bargaining_cond
#     1.11e-02 in Bq_match
#     9.49e-05 in FOC_capital_agency
#     2.19e-03 in FOC_K_ell
#     5.98e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.98e-02
#     1.02e-04 in bargaining_cond
#     3.56e-03 in Bq_match
#     1.02e-04 in FOC_capital_agency
#     2.35e-03 in FOC_K_ell
#     6.54e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.54e-02
#     2.17e-05 in bargaining_cond
#     6.54e-04 in Bq_match
#     2.17e-05 in FOC_capital_agency
#     5.06e-04 in FOC_K_ell
#     1.40e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.40e-02
#     3.77e-06 in bargaining_cond
#     1.60e-04 in Bq_match
#     3.75e-06 in FOC_capital_agency
#     8.81e-05 in FOC_K_ell
#     2.43e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.43e-03
#     9.94e-07 in bargaining_cond
#     4.08e-05 in Bq_match
#     9.89e-07 in FOC_capital_agency
#     2.32e-05 in FOC_K_ell
#     6.42e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.42e-04
#     9.56e-09 in bargaining_cond
#     1.05e-06 in Bq_match
#     1.27e-08 in FOC_capital_agency
#     2.97e-07 in FOC_K_ell
#     7.15e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 7.15e-06
#     2.37e-09 in bargaining_cond
#     2.77e-07 in Bq_match
#     2.78e-09 in FOC_capital_agency
#     7.29e-08 in FOC_K_ell
#     1.76e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.76e-06
#     2.16e-10 in bargaining_cond
#     2.09e-08 in Bq_match
#     3.88e-10 in FOC_capital_agency
#     5.36e-09 in FOC_K_ell
#     1.39e-07 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 10
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 1.39e-07
#     4.09e-11 in bargaining_cond
#     2.56e-09 in Bq_match
#     8.02e-11 in FOC_capital_agency
#     1.16e-09 in FOC_K_ell
#     2.90e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 11
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 2.90e-08
#     7.04e-12 in bargaining_cond
#     4.61e-10 in Bq_match
#     1.21e-11 in FOC_capital_agency
#     2.08e-10 in FOC_K_ell
#     5.15e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 12
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 5.15e-09
#     7.42e-13 in bargaining_cond
#     2.82e-11 in Bq_match
#     1.30e-12 in FOC_capital_agency
#     2.18e-11 in FOC_K_ell
#     5.34e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 13
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 5.34e-10
#     1.35e-13 in bargaining_cond
#     5.73e-12 in Bq_match
#     3.21e-13 in FOC_capital_agency
#     4.37e-12 in FOC_K_ell
#     1.04e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 14
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.04e-10
#     8.44e-14 in bargaining_cond
#     4.23e-12 in Bq_match
#     1.72e-13 in FOC_capital_agency
#     2.67e-12 in FOC_K_ell
#     6.31e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 15
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.31e-11
#     3.24e-14 in bargaining_cond
#     5.84e-12 in Bq_match
#     4.20e-14 in FOC_capital_agency
#     5.72e-13 in FOC_K_ell
#     1.94e-11 in mkt_clearing
# initial:
#    max. abs. error = 9.27e+00
#     0.00e+00 in bargaining_cond
#     1.43e-11 in Bq_match
#     4.44e-16 in FOC_capital_agency
#     3.38e-14 in FOC_K_ell
#     9.27e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 9.27e+00
#     1.32e-03 in bargaining_cond
#     1.82e-01 in Bq_match
#     1.20e-03 in FOC_capital_agency
#     3.48e-02 in FOC_K_ell
#     1.19e+00 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.19e+00
#     3.54e-04 in bargaining_cond
#     1.58e-02 in Bq_match
#     3.98e-04 in FOC_capital_agency
#     8.49e-03 in FOC_K_ell
#     1.74e-01 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.74e-01
#     5.26e-05 in bargaining_cond
#     5.57e-03 in Bq_match
#     5.24e-05 in FOC_capital_agency
#     1.19e-03 in FOC_K_ell
#     2.74e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.74e-02
#     3.98e-05 in bargaining_cond
#     1.47e-03 in Bq_match
#     4.01e-05 in FOC_capital_agency
#     9.27e-04 in FOC_K_ell
#     2.19e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.19e-02
#     7.62e-06 in bargaining_cond
#     2.33e-04 in Bq_match
#     7.57e-06 in FOC_capital_agency
#     1.79e-04 in FOC_K_ell
#     4.21e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.21e-03
#     1.61e-06 in bargaining_cond
#     5.84e-05 in Bq_match
#     1.59e-06 in FOC_capital_agency
#     3.78e-05 in FOC_K_ell
#     8.89e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 8.89e-04
#     1.08e-08 in bargaining_cond
#     1.63e-06 in Bq_match
#     1.36e-08 in FOC_capital_agency
#     3.26e-07 in FOC_K_ell
#     6.49e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.49e-06
#     2.93e-09 in bargaining_cond
#     3.02e-07 in Bq_match
#     2.54e-09 in FOC_capital_agency
#     6.89e-08 in FOC_K_ell
#     1.60e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.60e-06
#     3.50e-10 in bargaining_cond
#     3.80e-08 in Bq_match
#     5.09e-10 in FOC_capital_agency
#     1.07e-08 in FOC_K_ell
#     2.07e-07 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.07e-07
#     8.78e-11 in bargaining_cond
#     9.16e-09 in Bq_match
#     8.37e-11 in FOC_capital_agency
#     2.07e-09 in FOC_K_ell
#     4.79e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 10
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.79e-08
#     7.93e-12 in bargaining_cond
#     6.78e-10 in Bq_match
#     1.39e-11 in FOC_capital_agency
#     2.32e-10 in FOC_K_ell
#     4.65e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 11
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.65e-09
#     1.53e-12 in bargaining_cond
#     1.09e-10 in Bq_match
#     2.25e-12 in FOC_capital_agency
#     4.51e-11 in FOC_K_ell
#     9.02e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 12
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 9.02e-10
#     1.46e-13 in bargaining_cond
#     7.97e-12 in Bq_match
#     2.23e-13 in FOC_capital_agency
#     3.93e-12 in FOC_K_ell
#     8.42e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 13
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 8.42e-11
#     4.88e-14 in bargaining_cond
#     4.76e-12 in Bq_match
#     8.08e-14 in FOC_capital_agency
#     1.37e-12 in FOC_K_ell
#     2.95e-11 in mkt_clearing
# initial:
#    max. abs. error = 6.62e+00
#     0.00e+00 in bargaining_cond
#     1.43e-11 in Bq_match
#     4.44e-16 in FOC_capital_agency
#     3.38e-14 in FOC_K_ell
#     6.62e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.62e+00
#     9.50e-04 in bargaining_cond
#     1.25e-01 in Bq_match
#     8.24e-04 in FOC_capital_agency
#     2.50e-02 in FOC_K_ell
#     7.48e-01 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 7.48e-01
#     2.21e-04 in bargaining_cond
#     8.48e-03 in Bq_match
#     2.43e-04 in FOC_capital_agency
#     5.33e-03 in FOC_K_ell
#     9.64e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 9.64e-02
#     2.74e-05 in bargaining_cond
#     2.63e-03 in Bq_match
#     2.79e-05 in FOC_capital_agency
#     6.22e-04 in FOC_K_ell
#     1.25e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.25e-02
#     1.46e-05 in bargaining_cond
#     5.53e-04 in Bq_match
#     1.47e-05 in FOC_capital_agency
#     3.41e-04 in FOC_K_ell
#     7.08e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 7.08e-03
#     2.38e-06 in bargaining_cond
#     7.33e-05 in Bq_match
#     2.36e-06 in FOC_capital_agency
#     5.62e-05 in FOC_K_ell
#     1.16e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 1.16e-03
#     1.14e-07 in bargaining_cond
#     1.08e-05 in Bq_match
#     1.09e-07 in FOC_capital_agency
#     2.68e-06 in FOC_K_ell
#     5.51e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.51e-05
#     5.33e-09 in bargaining_cond
#     7.61e-07 in Bq_match
#     5.21e-09 in FOC_capital_agency
#     1.24e-07 in FOC_K_ell
#     2.62e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.62e-06
#     6.44e-10 in bargaining_cond
#     5.46e-08 in Bq_match
#     5.68e-10 in FOC_capital_agency
#     1.52e-08 in FOC_K_ell
#     3.09e-07 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 3.09e-07
#     5.89e-11 in bargaining_cond
#     6.66e-09 in Bq_match
#     8.21e-11 in FOC_capital_agency
#     1.87e-09 in FOC_K_ell
#     3.11e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.11e-08
#     1.11e-11 in bargaining_cond
#     5.93e-10 in Bq_match
#     9.90e-12 in FOC_capital_agency
#     2.64e-10 in FOC_K_ell
#     5.28e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 10
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.28e-09
#     7.84e-13 in bargaining_cond
#     7.68e-11 in Bq_match
#     1.14e-12 in FOC_capital_agency
#     2.35e-11 in FOC_K_ell
#     3.94e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 11
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 3.94e-10
#     1.69e-13 in bargaining_cond
#     1.27e-11 in Bq_match
#     1.81e-13 in FOC_capital_agency
#     4.81e-12 in FOC_K_ell
#     8.25e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 12
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 8.25e-11
#     4.26e-14 in bargaining_cond
#     6.14e-12 in Bq_match
#     5.30e-14 in FOC_capital_agency
#     1.35e-12 in FOC_K_ell
#     2.03e-11 in mkt_clearing
# initial:
#    max. abs. error = 2.65e+00
#     0.00e+00 in bargaining_cond
#     1.43e-11 in Bq_match
#     4.44e-16 in FOC_capital_agency
#     3.38e-14 in FOC_K_ell
#     2.65e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.65e+00
#     2.90e-04 in bargaining_cond
#     3.43e-02 in Bq_match
#     2.28e-04 in FOC_capital_agency
#     7.61e-03 in FOC_K_ell
#     1.80e-01 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.80e-01
#     3.97e-05 in bargaining_cond
#     1.58e-03 in Bq_match
#     4.08e-05 in FOC_capital_agency
#     9.69e-04 in FOC_K_ell
#     1.38e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.38e-02
#     2.96e-06 in bargaining_cond
#     1.84e-04 in Bq_match
#     3.14e-06 in FOC_capital_agency
#     6.89e-05 in FOC_K_ell
#     1.07e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.07e-03
#     5.32e-07 in bargaining_cond
#     2.11e-05 in Bq_match
#     5.44e-07 in FOC_capital_agency
#     1.26e-05 in FOC_K_ell
#     2.05e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.05e-04
#     3.96e-08 in bargaining_cond
#     1.20e-06 in Bq_match
#     3.99e-08 in FOC_capital_agency
#     9.48e-07 in FOC_K_ell
#     1.55e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.55e-05
#     6.14e-10 in bargaining_cond
#     1.41e-07 in Bq_match
#     5.05e-10 in FOC_capital_agency
#     1.97e-08 in FOC_K_ell
#     2.34e-07 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.34e-07
#     3.08e-11 in bargaining_cond
#     7.74e-09 in Bq_match
#     2.49e-11 in FOC_capital_agency
#     1.03e-09 in FOC_K_ell
#     1.27e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.27e-08
#     1.31e-12 in bargaining_cond
#     1.43e-10 in Bq_match
#     1.22e-12 in FOC_capital_agency
#     3.22e-11 in FOC_K_ell
#     4.96e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.96e-10
#     9.46e-14 in bargaining_cond
#     8.10e-12 in Bq_match
#     1.03e-13 in FOC_capital_agency
#     2.67e-12 in FOC_K_ell
#     3.43e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.43e-11
#     3.24e-14 in bargaining_cond
#     5.37e-12 in Bq_match
#     3.71e-14 in FOC_capital_agency
#     4.51e-13 in FOC_K_ell
#     1.32e-11 in mkt_clearing

# %%
T_IRF = 150

fig = plt.figure(figsize=(3*6,3*6/1.5))

ax = fig.add_subplot(3,3,1)
ax.plot((Models[0].sol.chi[:T_IRF]/Models[0].ss.chi-1)*100,label=f'Baseline:$\lambda^X$ = {Models[0].par.lambda_X}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.chi[:T_IRF]/Models[1].ss.chi-1)*100,label=f'$\lambda^X$ = {Models[1].par.lambda_X}')
ax.plot((Models[2].sol.chi[:T_IRF]/Models[2].ss.chi-1)*100,label=f'$\lambda^X$ = {Models[2].par.lambda_X}')
ax.plot((Models[3].sol.chi[:T_IRF]/Models[3].ss.chi-1)*100,label=f'$\lambda^X$ = {Models[3].par.lambda_X}')
ax.set_ylabel('% of s.s.')
ax.set_title('Foreign Demand Shifter ($\chi_t$)')
ax.legend(frameon=True)

ax = fig.add_subplot(3,3,2)
ax.plot((Models[0].sol.X[:T_IRF]/Models[0].ss.X-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.lambda_X}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.X[:T_IRF]/Models[1].ss.X-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_X}')
ax.plot((Models[2].sol.X[:T_IRF]/Models[2].ss.X-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_X}')
ax.plot((Models[3].sol.X[:T_IRF]/Models[3].ss.X-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_X}')
ax.set_ylabel('% of s.s.')
ax.set_title('Export ($X_t$)')

ax = fig.add_subplot(3,3,3)
ax.plot((Models[0].sol.Y[:T_IRF]/Models[0].ss.Y-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.lambda_X}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.Y[:T_IRF]/Models[1].ss.Y-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_X}')
ax.plot((Models[2].sol.Y[:T_IRF]/Models[2].ss.Y-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_X}')
ax.plot((Models[3].sol.Y[:T_IRF]/Models[3].ss.Y-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_X}')
ax.set_ylabel('% of s.s.')
ax.set_title('Production ($Y_t$)')

ax = fig.add_subplot(3,3,4)
ax.plot((Models[0].sol.K[:T_IRF]/Models[0].ss.K-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.lambda_X}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.K[:T_IRF]/Models[1].ss.K-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_X}')
ax.plot((Models[2].sol.K[:T_IRF]/Models[2].ss.K-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_X}')
ax.plot((Models[3].sol.K[:T_IRF]/Models[3].ss.K-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_X}')
ax.set_ylabel('% of s.s.')
ax.set_title('Capital ($K_t$)')

ax = fig.add_subplot(3,3,5)
ax.plot((Models[0].sol.L[:T_IRF]/Models[0].ss.L-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.lambda_X}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.L[:T_IRF]/Models[1].ss.L-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_X}')
ax.plot((Models[2].sol.L[:T_IRF]/Models[2].ss.L-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_X}')
ax.plot((Models[3].sol.L[:T_IRF]/Models[3].ss.L-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_X}')
ax.set_ylabel('% of s.s.')
ax.set_title('Employment ($L_t$)')

ax = fig.add_subplot(3,3,6)
ax.plot((Models[0].sol.W[:T_IRF]/Models[0].ss.W-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.lambda_X}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.W[:T_IRF]/Models[1].ss.W-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_X}')
ax.plot((Models[2].sol.W[:T_IRF]/Models[2].ss.W-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_X}')
ax.plot((Models[3].sol.W[:T_IRF]/Models[3].ss.W-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_X}')
ax.set_ylabel('% of s.s.')
ax.set_title('Wage ($W_{t}$)')

ax = fig.add_subplot(3,3,7)
ax.plot((Models[0].sol.C[:T_IRF]/Models[0].ss.C-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.lambda_X}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.C[:T_IRF]/Models[1].ss.C-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_X}')
ax.plot((Models[2].sol.C[:T_IRF]/Models[2].ss.C-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_X}')
ax.plot((Models[3].sol.C[:T_IRF]/Models[3].ss.C-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_X}')
ax.set_ylabel('% of s.s.')
ax.set_title('Consumption ($C_{t}$)')

ax = fig.add_subplot(3,3,8)
ax.plot((Models[0].sol.B[:T_IRF]/Models[0].ss.B-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.lambda_X}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.B[:T_IRF]/Models[1].ss.B-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_X}')
ax.plot((Models[2].sol.B[:T_IRF]/Models[2].ss.B-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_X}')
ax.plot((Models[3].sol.B[:T_IRF]/Models[3].ss.B-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_X}')
ax.set_ylabel('% of s.s.')
ax.set_title('Savings ($B_{t}$)')

ax = fig.add_subplot(3,3,9)
ax.plot((Models[0].sol.Bq[:T_IRF]/Models[0].ss.Bq-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.lambda_X}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.Bq[:T_IRF]/Models[1].ss.Bq-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_X}')
ax.plot((Models[2].sol.Bq[:T_IRF]/Models[2].ss.Bq-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_X}')
ax.plot((Models[3].sol.Bq[:T_IRF]/Models[3].ss.Bq-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_X}')
ax.set_ylabel('% of s.s.')
ax.set_title('Bequest ($B^{q}_{t}$)')
fig.tight_layout(pad=1.0); # spacing between subplots
