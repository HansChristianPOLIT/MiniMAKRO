# %% [markdown]
# # Foreign Demand Shock

# %%
# %load_ext autoreload
# %autoreload 2

import time
import pickle
import numpy as np
from scipy import optimize

import matplotlib.pyplot as plt   
plt.style.use('seaborn-whitegrid')
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

from BabyMAKROModel import BabyMAKROModelClass

# %% [markdown]
# # Setup

# %%
model = BabyMAKROModelClass(name='Extended') # create an instance of the model

# %%
par = model.par
ss = model.ss
sol = model.sol

# %% [markdown]
# # Find steady state

# %%
model.find_ss(do_print=True)
# Out:
# Labor supply and search and matching:
# ss.S = 4.24,  ss.L = 57.88,  ss.delta_L = 0.04,  ss.v = 9.41,  ss.m_v = 0.23
# Capital agency FOC:
# ss.r_K = 0.14
# Production firm pricing:
# ss.r_ell = 2.71
# Labor agency:
# ss.ell = 57.51,  ss.W = 2.68
# Government:
# ss.B_G = 100.00,  ss.G = 61.82,  ss.tau = 0.42
# Households:
# solving for household behavior: result.converged = True
# ss.C = 98.26,  ss.B = 215.09
# Production firm FOCs:
# ss.K = 573.77
# Capital accumulation equation:
# ss.I = 57.38
# Output in production firm:
# ss.Y = 236.29
# Market clearing:
# ss.C_Y = 68.78,  ss.G_Y = 55.64,  ss.I_Y = 37.29,  ss.X_Y = 74.57
# [ ss.C_M = 29.48,  ss.G_M = 6.18,  ss.I_M = 20.08,  ss.X_M = 49.72 ] = ss.M = 105.46
# ss.X = 124.29
# Bargaining:
# par.phi = 0.981

# %% [markdown]
# # Find an impulse-response

# %% [markdown]
# **Calculate Jacobian:**

# %%
model.calc_jac(do_print=True)
# Out:
# Jacobian calculated in 40.7 secs secs

# %% [markdown]
# **Set exogenous variables:**

# %%
model.set_exo_ss()

# %% [markdown]
# **Introduce Shock**

# %%
Tshock = 50
shock = 0.01*ss.chi
persistence = 0.8**np.arange(Tshock)
sol.chi[:Tshock] = ss.chi + shock*persistence

Tshock = 50
shock = 0.03*ss.P_F
persistence = 0.80**np.arange(Tshock)
sol.P_F[:Tshock] = ss.P_F + shock*persistence

# %% [markdown]
# **Find IRF:**

# %%
model.find_IRF()
# Out:
# initial:
#    max. abs. error = 2.08e+00
#     0.00e+00 in bargaining_cond
#     3.75e-13 in Bq_match
#     3.33e-16 in FOC_capital_agency
#     2.49e-14 in FOC_K_ell
#     2.08e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 2.08e+00
#     2.49e-04 in bargaining_cond
#     2.86e-02 in Bq_match
#     1.81e-04 in FOC_capital_agency
#     6.43e-03 in FOC_K_ell
#     8.46e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 8.46e-02
#     3.79e-05 in bargaining_cond
#     1.48e-03 in Bq_match
#     3.40e-05 in FOC_capital_agency
#     9.22e-04 in FOC_K_ell
#     1.08e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.08e-02
#     6.73e-06 in bargaining_cond
#     3.36e-04 in Bq_match
#     6.11e-06 in FOC_capital_agency
#     1.61e-04 in FOC_K_ell
#     1.88e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.88e-03
#     7.86e-07 in bargaining_cond
#     4.31e-05 in Bq_match
#     7.11e-07 in FOC_capital_agency
#     1.88e-05 in FOC_K_ell
#     2.20e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.20e-04
#     2.04e-08 in bargaining_cond
#     1.86e-06 in Bq_match
#     1.86e-08 in FOC_capital_agency
#     4.87e-07 in FOC_K_ell
#     5.61e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.61e-06
#     6.11e-10 in bargaining_cond
#     7.71e-08 in Bq_match
#     4.95e-10 in FOC_capital_agency
#     1.45e-08 in FOC_K_ell
#     1.65e-07 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.65e-07
#     1.92e-11 in bargaining_cond
#     2.63e-09 in Bq_match
#     1.37e-11 in FOC_capital_agency
#     4.53e-10 in FOC_K_ell
#     5.18e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.18e-09
#     2.37e-12 in bargaining_cond
#     2.22e-10 in Bq_match
#     2.36e-12 in FOC_capital_agency
#     5.70e-11 in FOC_K_ell
#     6.59e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.59e-10
#     9.06e-14 in bargaining_cond
#     1.13e-11 in Bq_match
#     1.30e-13 in FOC_capital_agency
#     2.54e-12 in FOC_K_ell
#     2.48e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.48e-11
#     3.24e-14 in bargaining_cond
#     9.04e-12 in Bq_match
#     3.73e-14 in FOC_capital_agency
#     3.07e-13 in FOC_K_ell
#     1.28e-11 in mkt_clearing

# %% [markdown]
# # Impulse Response Figures

# %% [markdown]
# ## Longview - To Check Convergence

# %%
model.plot_IRF(varlist=['X','C','Y','K'],T_IRF=par.T,ncol=2)

# %% [markdown]
# ## National accouting - Quantities

# %%
model.plot_IRF(varlist=['Y','C','G','I','X','M'])

# %% [markdown]
# ## National Accouting - Prices

# %%
model.plot_IRF(varlist=['P_Y','P_C','P_G','P_I','P_X','P_F'])

# %% [markdown]
# ## Labor market

# %%
model.plot_IRF(varlist=['S','v','curlyM','m_v','m_s','delta_L','W','real_W'],abs=['m_v','m_s'])

# %% [markdown]
# ## Capital accumulation

# %%
model.plot_IRF(varlist=['K','I','r_K','P_I'],ncol=2)

# %% [markdown]
# ## Production firms

# %%
model.plot_IRF(varlist=['K','ell','Y','r_K','r_ell'],ncol=2)

# %% [markdown]
# ## Government

# %%
model.plot_IRF(varlist=['G','B_G','tau'],abs=['tau'],Y_share=['B_G'])

# %% [markdown]
# ## Households - aggregate

# %%
model.plot_IRF(varlist=['L','inc','W','real_W','C','B','Bq'],ncol=3, T_IRF = 150)

# %%
model.plot_IRF(varlist=['C_HtM','C_R'],ncol=2, T_IRF = 150)

# %% [markdown]
# ## Households - life-cycle

# %%
model.plot_IRF_hh(varlist=['L_a','inc_a','C_a','B_a'],t0_list=[-20,-10,0,10,20])

# %% [markdown]
# # Sensitivity Analysis

# %% [markdown]
# ## Change in HtM-share

# %%
model = BabyMAKROModelClass(name='Extended') # create an instance of the model
par = model.par
ss = model.ss
sol = model.sol
model1 = model.copy()
model2 = model.copy()
model3 = model.copy()

# %%
Models = [model, model1, model2, model3] #Create list of the models
Lambdas = [0.0, 0.1, 0.25, 0.4] #Create list of Lambda values
    
for i in range(len(Models)):
    Models[i].par.Lambda = Lambdas[i]
    Models[i].find_ss()
    Models[i].calc_jac()
    Gshock = 50
    shock_chi = 0.01*Models[i].ss.chi
    persistence_chi = 0.8**np.arange(Tshock)
    Models[i].sol.chi[:Tshock] = Models[i].ss.chi + shock_chi*persistence_chi
    shock_p_f = 0.03*ss.P_F
    persistence_p_f = 0.80**np.arange(Tshock)
    Models[i].sol.P_F[:Tshock] = ss.P_F + shock_p_f*persistence_p_f
    Models[i].find_IRF()
# Out:
# initial:
#    max. abs. error = 2.03e+00
#     0.00e+00 in bargaining_cond
#     3.00e-13 in Bq_match
#     3.33e-16 in FOC_capital_agency
#     2.49e-14 in FOC_K_ell
#     2.03e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.03e+00
#     2.36e-04 in bargaining_cond
#     3.52e-02 in Bq_match
#     1.73e-04 in FOC_capital_agency
#     6.10e-03 in FOC_K_ell
#     7.82e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 7.82e-02
#     3.49e-05 in bargaining_cond
#     1.82e-03 in Bq_match
#     3.14e-05 in FOC_capital_agency
#     8.49e-04 in FOC_K_ell
#     9.64e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 9.64e-03
#     5.79e-06 in bargaining_cond
#     3.85e-04 in Bq_match
#     5.28e-06 in FOC_capital_agency
#     1.39e-04 in FOC_K_ell
#     1.57e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.57e-03
#     6.25e-07 in bargaining_cond
#     4.61e-05 in Bq_match
#     5.66e-07 in FOC_capital_agency
#     1.50e-05 in FOC_K_ell
#     1.70e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.70e-04
#     1.57e-08 in bargaining_cond
#     1.90e-06 in Bq_match
#     1.44e-08 in FOC_capital_agency
#     3.74e-07 in FOC_K_ell
#     4.17e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 4.17e-06
#     3.68e-10 in bargaining_cond
#     6.90e-08 in Bq_match
#     2.81e-10 in FOC_capital_agency
#     8.75e-09 in FOC_K_ell
#     9.51e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 9.51e-08
#     1.35e-11 in bargaining_cond
#     2.54e-09 in Bq_match
#     8.97e-12 in FOC_capital_agency
#     3.18e-10 in FOC_K_ell
#     3.50e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.50e-09
#     1.81e-12 in bargaining_cond
#     2.09e-10 in Bq_match
#     1.83e-12 in FOC_capital_agency
#     4.34e-11 in FOC_K_ell
#     4.90e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.90e-10
#     8.88e-14 in bargaining_cond
#     1.40e-11 in Bq_match
#     1.12e-13 in FOC_capital_agency
#     2.08e-12 in FOC_K_ell
#     2.57e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.57e-11
#     2.93e-14 in bargaining_cond
#     1.15e-11 in Bq_match
#     3.59e-14 in FOC_capital_agency
#     4.12e-13 in FOC_K_ell
#     1.04e-11 in mkt_clearing
# initial:
#    max. abs. error = 2.05e+00
#     0.00e+00 in bargaining_cond
#     1.31e-12 in Bq_match
#     3.33e-16 in FOC_capital_agency
#     2.49e-14 in FOC_K_ell
#     2.05e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.05e+00
#     2.41e-04 in bargaining_cond
#     3.27e-02 in Bq_match
#     1.77e-04 in FOC_capital_agency
#     6.23e-03 in FOC_K_ell
#     8.07e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 8.07e-02
#     3.61e-05 in bargaining_cond
#     1.69e-03 in Bq_match
#     3.24e-05 in FOC_capital_agency
#     8.78e-04 in FOC_K_ell
#     1.01e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.01e-02
#     6.14e-06 in bargaining_cond
#     3.68e-04 in Bq_match
#     5.60e-06 in FOC_capital_agency
#     1.47e-04 in FOC_K_ell
#     1.69e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.69e-03
#     6.86e-07 in bargaining_cond
#     4.53e-05 in Bq_match
#     6.21e-07 in FOC_capital_agency
#     1.64e-05 in FOC_K_ell
#     1.88e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.88e-04
#     1.74e-08 in bargaining_cond
#     1.90e-06 in Bq_match
#     1.59e-08 in FOC_capital_agency
#     4.15e-07 in FOC_K_ell
#     4.69e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.69e-06
#     4.56e-10 in bargaining_cond
#     7.31e-08 in Bq_match
#     3.58e-10 in FOC_capital_agency
#     1.08e-08 in FOC_K_ell
#     1.20e-07 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.20e-07
#     1.55e-11 in bargaining_cond
#     2.60e-09 in Bq_match
#     1.06e-11 in FOC_capital_agency
#     3.66e-10 in FOC_K_ell
#     4.08e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.08e-09
#     2.01e-12 in bargaining_cond
#     2.18e-10 in Bq_match
#     2.00e-12 in FOC_capital_agency
#     4.82e-11 in FOC_K_ell
#     5.53e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.53e-10
#     7.55e-14 in bargaining_cond
#     9.97e-12 in Bq_match
#     1.08e-13 in FOC_capital_agency
#     2.24e-12 in FOC_K_ell
#     2.04e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.04e-11
#     2.53e-14 in bargaining_cond
#     8.90e-12 in Bq_match
#     4.57e-14 in FOC_capital_agency
#     2.75e-13 in FOC_K_ell
#     1.01e-11 in mkt_clearing
# initial:
#    max. abs. error = 2.08e+00
#     0.00e+00 in bargaining_cond
#     3.75e-13 in Bq_match
#     3.33e-16 in FOC_capital_agency
#     2.49e-14 in FOC_K_ell
#     2.08e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.08e+00
#     2.49e-04 in bargaining_cond
#     2.86e-02 in Bq_match
#     1.81e-04 in FOC_capital_agency
#     6.43e-03 in FOC_K_ell
#     8.46e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 8.46e-02
#     3.79e-05 in bargaining_cond
#     1.48e-03 in Bq_match
#     3.40e-05 in FOC_capital_agency
#     9.22e-04 in FOC_K_ell
#     1.08e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.08e-02
#     6.73e-06 in bargaining_cond
#     3.36e-04 in Bq_match
#     6.11e-06 in FOC_capital_agency
#     1.61e-04 in FOC_K_ell
#     1.88e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.88e-03
#     7.86e-07 in bargaining_cond
#     4.31e-05 in Bq_match
#     7.11e-07 in FOC_capital_agency
#     1.88e-05 in FOC_K_ell
#     2.20e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.20e-04
#     2.04e-08 in bargaining_cond
#     1.86e-06 in Bq_match
#     1.86e-08 in FOC_capital_agency
#     4.87e-07 in FOC_K_ell
#     5.61e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.61e-06
#     6.11e-10 in bargaining_cond
#     7.71e-08 in Bq_match
#     4.95e-10 in FOC_capital_agency
#     1.45e-08 in FOC_K_ell
#     1.65e-07 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.65e-07
#     1.92e-11 in bargaining_cond
#     2.63e-09 in Bq_match
#     1.37e-11 in FOC_capital_agency
#     4.53e-10 in FOC_K_ell
#     5.18e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.18e-09
#     2.37e-12 in bargaining_cond
#     2.22e-10 in Bq_match
#     2.36e-12 in FOC_capital_agency
#     5.70e-11 in FOC_K_ell
#     6.59e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.59e-10
#     9.06e-14 in bargaining_cond
#     1.13e-11 in Bq_match
#     1.30e-13 in FOC_capital_agency
#     2.54e-12 in FOC_K_ell
#     2.48e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.48e-11
#     3.24e-14 in bargaining_cond
#     9.04e-12 in Bq_match
#     3.73e-14 in FOC_capital_agency
#     3.07e-13 in FOC_K_ell
#     1.28e-11 in mkt_clearing
# initial:
#    max. abs. error = 2.11e+00
#     0.00e+00 in bargaining_cond
#     1.04e-13 in Bq_match
#     3.33e-16 in FOC_capital_agency
#     2.49e-14 in FOC_K_ell
#     2.11e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.11e+00
#     2.57e-04 in bargaining_cond
#     2.40e-02 in Bq_match
#     1.86e-04 in FOC_capital_agency
#     6.64e-03 in FOC_K_ell
#     8.86e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 8.86e-02
#     3.99e-05 in bargaining_cond
#     1.24e-03 in Bq_match
#     3.56e-05 in FOC_capital_agency
#     9.70e-04 in FOC_K_ell
#     1.16e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.16e-02
#     7.38e-06 in bargaining_cond
#     2.95e-04 in Bq_match
#     6.68e-06 in FOC_capital_agency
#     1.77e-04 in FOC_K_ell
#     2.10e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.10e-03
#     8.97e-07 in bargaining_cond
#     3.91e-05 in Bq_match
#     8.10e-07 in FOC_capital_agency
#     2.15e-05 in FOC_K_ell
#     2.56e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.56e-04
#     2.40e-08 in bargaining_cond
#     1.75e-06 in Bq_match
#     2.18e-08 in FOC_capital_agency
#     5.72e-07 in FOC_K_ell
#     6.72e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.72e-06
#     7.95e-10 in bargaining_cond
#     7.69e-08 in Bq_match
#     6.59e-10 in FOC_capital_agency
#     1.89e-08 in FOC_K_ell
#     2.20e-07 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.20e-07
#     2.38e-11 in bargaining_cond
#     2.54e-09 in Bq_match
#     1.77e-11 in FOC_capital_agency
#     5.63e-10 in FOC_K_ell
#     6.58e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.58e-09
#     2.83e-12 in bargaining_cond
#     2.26e-10 in Bq_match
#     2.77e-12 in FOC_capital_agency
#     6.75e-11 in FOC_K_ell
#     8.04e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 8.04e-10
#     1.42e-13 in bargaining_cond
#     7.14e-12 in Bq_match
#     1.67e-13 in FOC_capital_agency
#     3.32e-12 in FOC_K_ell
#     4.29e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.29e-11
#     3.02e-14 in bargaining_cond
#     6.39e-12 in Bq_match
#     3.57e-14 in FOC_capital_agency
#     3.22e-13 in FOC_K_ell
#     1.12e-11 in mkt_clearing

# %%
T_IRF = 150

fig = plt.figure(figsize=(3*6,3*6/1.5))

ax = fig.add_subplot(3,3,1)
ax.plot((Models[0].sol.chi[:T_IRF]/Models[0].ss.chi-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.chi[:T_IRF]/Models[1].ss.chi-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.chi[:T_IRF]/Models[2].ss.chi-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.chi[:T_IRF]/Models[3].ss.chi-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Foreign Demand Shifter ($\chi_t$)')
ax.legend(frameon=True)

ax = fig.add_subplot(3,3,2)
ax.plot((Models[0].sol.X[:T_IRF]/Models[0].ss.X-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.X[:T_IRF]/Models[1].ss.X-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.X[:T_IRF]/Models[2].ss.X-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.X[:T_IRF]/Models[3].ss.X-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Export ($X_t$)')

ax = fig.add_subplot(3,3,3)
ax.plot((Models[0].sol.Y[:T_IRF]/Models[0].ss.Y-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.Y[:T_IRF]/Models[1].ss.Y-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.Y[:T_IRF]/Models[2].ss.Y-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.Y[:T_IRF]/Models[3].ss.Y-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Production ($Y_t$)')

ax = fig.add_subplot(3,3,4)
ax.plot((Models[0].sol.K[:T_IRF]/Models[0].ss.K-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.K[:T_IRF]/Models[1].ss.K-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.K[:T_IRF]/Models[2].ss.K-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.K[:T_IRF]/Models[3].ss.K-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Capital ($K_t$)')

ax = fig.add_subplot(3,3,5)
ax.plot((Models[0].sol.L[:T_IRF]/Models[0].ss.L-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.L[:T_IRF]/Models[1].ss.L-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.L[:T_IRF]/Models[2].ss.L-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.L[:T_IRF]/Models[3].ss.L-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Employment ($L_t$)')

ax = fig.add_subplot(3,3,6)
ax.plot((Models[0].sol.W[:T_IRF]/Models[0].ss.W-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.W[:T_IRF]/Models[1].ss.W-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.W[:T_IRF]/Models[2].ss.W-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.W[:T_IRF]/Models[3].ss.W-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Wage ($W_{t}$)')

ax = fig.add_subplot(3,3,7)
ax.plot((Models[0].sol.C[:T_IRF]/Models[0].ss.C-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.C[:T_IRF]/Models[1].ss.C-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.C[:T_IRF]/Models[2].ss.C-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.C[:T_IRF]/Models[3].ss.C-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Consumption ($C_{t}$)')

ax = fig.add_subplot(3,3,8)
ax.plot((Models[0].sol.B[:T_IRF]/Models[0].ss.B-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.B[:T_IRF]/Models[1].ss.B-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.B[:T_IRF]/Models[2].ss.B-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.B[:T_IRF]/Models[3].ss.B-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Savings ($B_{t}$)')

ax = fig.add_subplot(3,3,9)
ax.plot((Models[0].sol.Bq[:T_IRF]/Models[0].ss.Bq-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.Bq[:T_IRF]/Models[1].ss.Bq-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.Bq[:T_IRF]/Models[2].ss.Bq-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.Bq[:T_IRF]/Models[3].ss.Bq-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Bequest ($B^{q}_{t}$)');

# %% [markdown]
# ## Change in Export Rigidity

# %%
model = BabyMAKROModelClass(name='Extended') # create an instance of the model
par = model.par
ss = model.ss
sol = model.sol
model1 = model.copy()
model2 = model.copy()
model3 = model.copy()

# %%
Models = [model, model1, model2, model3] #Create list of the models
Lambdas_X = [0.0, 0.3, 0.5, 0.8] #Create list of Lambda values, 0.8 er jf. MAKRO documentation med Export 
    
for i in range(len(Models)):
    Models[i].par.lambda_X = Lambdas_X[i]
    Models[i].find_ss()
    Models[i].calc_jac()
    Gshock = 50
    shock_chi = 0.01*Models[i].ss.chi
    persistence_chi = 0.8**np.arange(Tshock)
    Models[i].sol.chi[:Tshock] = Models[i].ss.chi + shock_chi*persistence_chi
    shock_p_f = 0.03*ss.P_F
    persistence_p_f = 0.80**np.arange(Tshock)
    Models[i].sol.P_F[:Tshock] = ss.P_F + shock_p_f*persistence_p_f
    Models[i].find_IRF()
# Out:
# initial:
#    max. abs. error = 4.16e+00
#     0.00e+00 in bargaining_cond
#     3.75e-13 in Bq_match
#     3.33e-16 in FOC_capital_agency
#     2.49e-14 in FOC_K_ell
#     4.16e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.16e+00
#     7.02e-04 in bargaining_cond
#     8.82e-02 in Bq_match
#     5.51e-04 in FOC_capital_agency
#     1.82e-02 in FOC_K_ell
#     2.80e-01 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.80e-01
#     1.79e-04 in bargaining_cond
#     6.33e-03 in Bq_match
#     1.71e-04 in FOC_capital_agency
#     4.34e-03 in FOC_K_ell
#     6.02e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.02e-02
#     5.83e-05 in bargaining_cond
#     2.53e-03 in Bq_match
#     5.53e-05 in FOC_capital_agency
#     1.39e-03 in FOC_K_ell
#     1.92e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.92e-02
#     1.29e-05 in bargaining_cond
#     6.17e-04 in Bq_match
#     1.20e-05 in FOC_capital_agency
#     3.06e-04 in FOC_K_ell
#     4.26e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.26e-03
#     7.37e-07 in bargaining_cond
#     5.93e-05 in Bq_match
#     6.94e-07 in FOC_capital_agency
#     1.75e-05 in FOC_K_ell
#     2.41e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.41e-04
#     4.65e-08 in bargaining_cond
#     4.64e-06 in Bq_match
#     3.98e-08 in FOC_capital_agency
#     1.10e-06 in FOC_K_ell
#     1.51e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.51e-05
#     1.05e-09 in bargaining_cond
#     2.01e-07 in Bq_match
#     1.12e-09 in FOC_capital_agency
#     3.29e-08 in FOC_K_ell
#     4.25e-07 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.25e-07
#     2.44e-10 in bargaining_cond
#     3.12e-08 in Bq_match
#     2.60e-10 in FOC_capital_agency
#     5.79e-09 in FOC_K_ell
#     8.02e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 8.02e-08
#     3.88e-11 in bargaining_cond
#     2.21e-09 in Bq_match
#     4.78e-11 in FOC_capital_agency
#     9.28e-10 in FOC_K_ell
#     1.30e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.30e-08
#     1.97e-12 in bargaining_cond
#     1.99e-10 in Bq_match
#     2.68e-12 in FOC_capital_agency
#     4.72e-11 in FOC_K_ell
#     6.69e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 10
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.69e-10
#     2.24e-13 in bargaining_cond
#     2.88e-11 in Bq_match
#     2.80e-13 in FOC_capital_agency
#     5.98e-12 in FOC_K_ell
#     7.89e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 11
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 7.89e-11
#     3.02e-14 in bargaining_cond
#     9.08e-12 in Bq_match
#     4.15e-14 in FOC_capital_agency
#     1.26e-12 in FOC_K_ell
#     1.23e-11 in mkt_clearing
# initial:
#    max. abs. error = 2.91e+00
#     0.00e+00 in bargaining_cond
#     3.75e-13 in Bq_match
#     3.33e-16 in FOC_capital_agency
#     2.49e-14 in FOC_K_ell
#     2.91e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.91e+00
#     4.21e-04 in bargaining_cond
#     5.01e-02 in Bq_match
#     3.17e-04 in FOC_capital_agency
#     1.09e-02 in FOC_K_ell
#     1.53e-01 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 1.53e-01
#     8.34e-05 in bargaining_cond
#     3.12e-03 in Bq_match
#     7.69e-05 in FOC_capital_agency
#     2.03e-03 in FOC_K_ell
#     2.55e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.55e-02
#     2.00e-05 in bargaining_cond
#     9.41e-04 in Bq_match
#     1.86e-05 in FOC_capital_agency
#     4.80e-04 in FOC_K_ell
#     6.01e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 6.01e-03
#     3.27e-06 in bargaining_cond
#     1.69e-04 in Bq_match
#     2.99e-06 in FOC_capital_agency
#     7.80e-05 in FOC_K_ell
#     9.81e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 9.81e-04
#     1.21e-07 in bargaining_cond
#     1.06e-05 in Bq_match
#     1.12e-07 in FOC_capital_agency
#     2.89e-06 in FOC_K_ell
#     3.59e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 3.59e-05
#     5.40e-09 in bargaining_cond
#     6.19e-07 in Bq_match
#     4.48e-09 in FOC_capital_agency
#     1.28e-07 in FOC_K_ell
#     1.58e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.58e-06
#     1.19e-10 in bargaining_cond
#     2.29e-08 in Bq_match
#     1.16e-10 in FOC_capital_agency
#     3.22e-09 in FOC_K_ell
#     3.66e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 3.66e-08
#     2.56e-11 in bargaining_cond
#     2.74e-09 in Bq_match
#     2.64e-11 in FOC_capital_agency
#     6.12e-10 in FOC_K_ell
#     7.68e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 7.68e-09
#     2.20e-12 in bargaining_cond
#     9.23e-11 in Bq_match
#     2.75e-12 in FOC_capital_agency
#     5.32e-11 in FOC_K_ell
#     6.73e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.73e-10
#     9.77e-14 in bargaining_cond
#     1.01e-11 in Bq_match
#     1.42e-13 in FOC_capital_agency
#     2.27e-12 in FOC_K_ell
#     3.08e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 10
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.08e-11
#     3.11e-14 in bargaining_cond
#     7.93e-12 in Bq_match
#     3.36e-14 in FOC_capital_agency
#     4.58e-13 in FOC_K_ell
#     1.19e-11 in mkt_clearing
# initial:
#    max. abs. error = 2.08e+00
#     0.00e+00 in bargaining_cond
#     3.75e-13 in Bq_match
#     3.33e-16 in FOC_capital_agency
#     2.49e-14 in FOC_K_ell
#     2.08e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.08e+00
#     2.49e-04 in bargaining_cond
#     2.86e-02 in Bq_match
#     1.81e-04 in FOC_capital_agency
#     6.43e-03 in FOC_K_ell
#     8.46e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 8.46e-02
#     3.79e-05 in bargaining_cond
#     1.48e-03 in Bq_match
#     3.40e-05 in FOC_capital_agency
#     9.22e-04 in FOC_K_ell
#     1.08e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.08e-02
#     6.73e-06 in bargaining_cond
#     3.36e-04 in Bq_match
#     6.11e-06 in FOC_capital_agency
#     1.61e-04 in FOC_K_ell
#     1.88e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.88e-03
#     7.86e-07 in bargaining_cond
#     4.31e-05 in Bq_match
#     7.11e-07 in FOC_capital_agency
#     1.88e-05 in FOC_K_ell
#     2.20e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.20e-04
#     2.04e-08 in bargaining_cond
#     1.86e-06 in Bq_match
#     1.86e-08 in FOC_capital_agency
#     4.87e-07 in FOC_K_ell
#     5.61e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.61e-06
#     6.11e-10 in bargaining_cond
#     7.71e-08 in Bq_match
#     4.95e-10 in FOC_capital_agency
#     1.45e-08 in FOC_K_ell
#     1.65e-07 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.65e-07
#     1.92e-11 in bargaining_cond
#     2.63e-09 in Bq_match
#     1.37e-11 in FOC_capital_agency
#     4.53e-10 in FOC_K_ell
#     5.18e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.18e-09
#     2.37e-12 in bargaining_cond
#     2.22e-10 in Bq_match
#     2.36e-12 in FOC_capital_agency
#     5.70e-11 in FOC_K_ell
#     6.59e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.59e-10
#     9.06e-14 in bargaining_cond
#     1.13e-11 in Bq_match
#     1.30e-13 in FOC_capital_agency
#     2.54e-12 in FOC_K_ell
#     2.48e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.48e-11
#     3.24e-14 in bargaining_cond
#     9.04e-12 in Bq_match
#     3.73e-14 in FOC_capital_agency
#     3.07e-13 in FOC_K_ell
#     1.28e-11 in mkt_clearing
# initial:
#    max. abs. error = 8.32e-01
#     0.00e+00 in bargaining_cond
#     3.75e-13 in Bq_match
#     3.33e-16 in FOC_capital_agency
#     2.49e-14 in FOC_K_ell
#     8.32e-01 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 8.32e-01
#     5.06e-05 in bargaining_cond
#     5.50e-03 in Bq_match
#     3.49e-05 in FOC_capital_agency
#     1.29e-03 in FOC_K_ell
#     1.54e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.54e-02
#     3.48e-06 in bargaining_cond
#     1.54e-04 in Bq_match
#     2.96e-06 in FOC_capital_agency
#     8.46e-05 in FOC_K_ell
#     8.80e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 8.80e-04
#     2.56e-07 in bargaining_cond
#     1.43e-05 in Bq_match
#     2.24e-07 in FOC_capital_agency
#     6.16e-06 in FOC_K_ell
#     6.36e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.36e-05
#     1.03e-08 in bargaining_cond
#     6.40e-07 in Bq_match
#     9.11e-09 in FOC_capital_agency
#     2.47e-07 in FOC_K_ell
#     2.56e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.56e-06
#     1.50e-10 in bargaining_cond
#     1.21e-08 in Bq_match
#     1.30e-10 in FOC_capital_agency
#     3.59e-09 in FOC_K_ell
#     3.64e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.64e-08
#     9.29e-13 in bargaining_cond
#     1.59e-10 in Bq_match
#     7.34e-13 in FOC_capital_agency
#     2.23e-11 in FOC_K_ell
#     2.18e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.18e-10
#     3.11e-14 in bargaining_cond
#     8.10e-12 in Bq_match
#     3.77e-14 in FOC_capital_agency
#     6.27e-13 in FOC_K_ell
#     1.01e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.01e-11
#     2.75e-14 in bargaining_cond
#     1.00e-11 in Bq_match
#     4.41e-14 in FOC_capital_agency
#     3.23e-13 in FOC_K_ell
#     1.01e-11 in mkt_clearing

# %%
T_IRF = 150

fig = plt.figure(figsize=(3*6,3*6/1.5))

ax = fig.add_subplot(3,3,1)
ax.plot((Models[0].sol.chi[:T_IRF]/Models[0].ss.chi-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.lambda_X}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.chi[:T_IRF]/Models[1].ss.chi-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_X}')
ax.plot((Models[2].sol.chi[:T_IRF]/Models[2].ss.chi-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_X}')
ax.plot((Models[3].sol.chi[:T_IRF]/Models[3].ss.chi-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_X}')
ax.set_ylabel('% of s.s.')
ax.set_title('Foreign Demand Shifter ($\chi_t$)')
ax.legend(frameon=True)

ax = fig.add_subplot(3,3,2)
ax.plot((Models[0].sol.X[:T_IRF]/Models[0].ss.X-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.lambda_X}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.X[:T_IRF]/Models[1].ss.X-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_X}')
ax.plot((Models[2].sol.X[:T_IRF]/Models[2].ss.X-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_X}')
ax.plot((Models[3].sol.X[:T_IRF]/Models[3].ss.X-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_X}')
ax.set_ylabel('% of s.s.')
ax.set_title('Export ($X_t$)')

ax = fig.add_subplot(3,3,3)
ax.plot((Models[0].sol.Y[:T_IRF]/Models[0].ss.Y-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.lambda_X}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.Y[:T_IRF]/Models[1].ss.Y-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_X}')
ax.plot((Models[2].sol.Y[:T_IRF]/Models[2].ss.Y-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_X}')
ax.plot((Models[3].sol.Y[:T_IRF]/Models[3].ss.Y-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_X}')
ax.set_ylabel('% of s.s.')
ax.set_title('Production ($Y_t$)')

ax = fig.add_subplot(3,3,4)
ax.plot((Models[0].sol.K[:T_IRF]/Models[0].ss.K-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.lambda_X}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.K[:T_IRF]/Models[1].ss.K-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_X}')
ax.plot((Models[2].sol.K[:T_IRF]/Models[2].ss.K-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_X}')
ax.plot((Models[3].sol.K[:T_IRF]/Models[3].ss.K-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_X}')
ax.set_ylabel('% of s.s.')
ax.set_title('Capital ($K_t$)')

ax = fig.add_subplot(3,3,5)
ax.plot((Models[0].sol.L[:T_IRF]/Models[0].ss.L-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.lambda_X}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.L[:T_IRF]/Models[1].ss.L-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_X}')
ax.plot((Models[2].sol.L[:T_IRF]/Models[2].ss.L-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_X}')
ax.plot((Models[3].sol.L[:T_IRF]/Models[3].ss.L-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_X}')
ax.set_ylabel('% of s.s.')
ax.set_title('Employment ($L_t$)')

ax = fig.add_subplot(3,3,6)
ax.plot((Models[0].sol.W[:T_IRF]/Models[0].ss.W-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.lambda_X}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.W[:T_IRF]/Models[1].ss.W-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_X}')
ax.plot((Models[2].sol.W[:T_IRF]/Models[2].ss.W-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_X}')
ax.plot((Models[3].sol.W[:T_IRF]/Models[3].ss.W-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_X}')
ax.set_ylabel('% of s.s.')
ax.set_title('Wage ($W_{t}$)')

ax = fig.add_subplot(3,3,7)
ax.plot((Models[0].sol.C[:T_IRF]/Models[0].ss.C-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.lambda_X}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.C[:T_IRF]/Models[1].ss.C-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_X}')
ax.plot((Models[2].sol.C[:T_IRF]/Models[2].ss.C-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_X}')
ax.plot((Models[3].sol.C[:T_IRF]/Models[3].ss.C-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_X}')
ax.set_ylabel('% of s.s.')
ax.set_title('Consumption ($C_{t}$)')

ax = fig.add_subplot(3,3,8)
ax.plot((Models[0].sol.B[:T_IRF]/Models[0].ss.B-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.lambda_X}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.B[:T_IRF]/Models[1].ss.B-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_X}')
ax.plot((Models[2].sol.B[:T_IRF]/Models[2].ss.B-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_X}')
ax.plot((Models[3].sol.B[:T_IRF]/Models[3].ss.B-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_X}')
ax.set_ylabel('% of s.s.')
ax.set_title('Savings ($B_{t}$)')

ax = fig.add_subplot(3,3,9)
ax.plot((Models[0].sol.Bq[:T_IRF]/Models[0].ss.Bq-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.lambda_X}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.Bq[:T_IRF]/Models[1].ss.Bq-1)*100,label=f'$\lambda$ = {Models[1].par.lambda_X}')
ax.plot((Models[2].sol.Bq[:T_IRF]/Models[2].ss.Bq-1)*100,label=f'$\lambda$ = {Models[2].par.lambda_X}')
ax.plot((Models[3].sol.Bq[:T_IRF]/Models[3].ss.Bq-1)*100,label=f'$\lambda$ = {Models[3].par.lambda_X}')
ax.set_ylabel('% of s.s.')
ax.set_title('Bequest ($B^{q}_{t}$)');
