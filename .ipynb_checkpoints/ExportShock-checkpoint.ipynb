# %% [markdown]
# # Foreign Demand Shock

# %%
# %load_ext autoreload
# %autoreload 2

import time
import pickle
import numpy as np
from scipy import optimize

import matplotlib.pyplot as plt   
plt.style.use('seaborn-whitegrid')
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

from BabyMAKROModel import BabyMAKROModelClass
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Setup

# %%
model = BabyMAKROModelClass(name='Extended') # create an instance of the model

# %%
par = model.par
ss = model.ss
sol = model.sol

# %% [markdown]
# # Find steady state

# %%
model.find_ss(do_print=True)
# Out:
# Labor supply and search and matching:
# ss.S = 7.44,  ss.L = 56.28,  ss.delta_L = 0.07,  ss.v = 16.52,  ss.m_v = 0.23
# Capital agency FOC:
# ss.r_K = 0.14
# Production firm pricing:
# ss.r_ell = 2.71
# Labor agency:
# ss.ell = 55.46,  ss.W = 2.65
# Government:
# ss.B_G = 150.00,  ss.G = 50.00,  ss.tau = 0.38
# Households:
# solving for household behavior: result.converged = True
# ss.C = 82.12,  ss.B = 168.84
# Production firm FOCs:
# ss.K = 553.31
# Capital accumulation equation:
# ss.I = 55.33
# Output in production firm:
# ss.Y = 227.87
# Market clearing:
# ss.C_Y = 57.48,  ss.G_Y = 45.00,  ss.I_Y = 35.97,  ss.X_Y = 89.42
# [ ss.C_M = 24.64,  ss.G_M = 5.00,  ss.I_M = 19.37,  ss.X_M = 59.61 ] = ss.M = 108.61
# ss.X = 149.03
# Bargaining:
# par.phi = 0.968

# %% [markdown]
# # Find an impulse-response

# %% [markdown]
# **Calculate Jacobian:**

# %%
model.calc_jac(do_print=True)
# Out:
# Jacobian calculated in 16.9 secs secs

# %% [markdown]
# **Set exogenous variables:**

# %%
Tshock = 50
shock = 0.01*ss.chi
persistence = 0.8**np.arange(Tshock)
sol.chi[:Tshock] = ss.chi + shock*persistence

Tshock = 50
shock = 0.03*ss.P_F
persistence = 0.80**np.arange(Tshock)
sol.P_F[:Tshock] = ss.P_F + shock*persistence

# %%
model.set_unknowns_ss()
model.evaluate_blocks()
errors = model.get_errors(do_print=True)
# Out:
# bargaining_cond     : abs. max = 0.00e+00
# Bq_match            : abs. max = 1.17e+00
# FOC_capital_agency  : abs. max = 0.00e+00
# FOC_K_ell           : abs. max = 1.95e-14
# mkt_clearing        : abs. max = 2.49e+00

# %% [markdown]
# **Find IRF:**

# %%
model.find_IRF()
# Out:
# initial:
#    max. abs. error = 2.49e+00
#     0.00e+00 in bargaining_cond
#     1.17e+00 in Bq_match
#     0.00e+00 in FOC_capital_agency
#     1.95e-14 in FOC_K_ell
#     2.49e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.49e+00
#     2.47e-04 in bargaining_cond
#     1.68e-02 in Bq_match
#     1.78e-04 in FOC_capital_agency
#     6.10e-03 in FOC_K_ell
#     8.62e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 8.62e-02
#     3.09e-05 in bargaining_cond
#     7.96e-04 in Bq_match
#     2.74e-05 in FOC_capital_agency
#     7.06e-04 in FOC_K_ell
#     8.48e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 8.48e-03
#     4.21e-06 in bargaining_cond
#     1.34e-04 in Bq_match
#     3.86e-06 in FOC_capital_agency
#     9.47e-05 in FOC_K_ell
#     1.14e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.14e-03
#     2.20e-07 in bargaining_cond
#     8.29e-06 in Bq_match
#     2.05e-07 in FOC_capital_agency
#     4.93e-06 in FOC_K_ell
#     6.01e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.01e-05
#     5.08e-09 in bargaining_cond
#     2.62e-07 in Bq_match
#     4.56e-09 in FOC_capital_agency
#     1.14e-07 in FOC_K_ell
#     1.35e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.35e-06
#     4.64e-11 in bargaining_cond
#     2.87e-09 in Bq_match
#     4.73e-11 in FOC_capital_agency
#     1.02e-09 in FOC_K_ell
#     1.31e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.31e-08
#     4.70e-12 in bargaining_cond
#     2.34e-10 in Bq_match
#     4.24e-12 in FOC_capital_agency
#     1.04e-10 in FOC_K_ell
#     1.27e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.27e-09
#     2.31e-13 in bargaining_cond
#     1.37e-11 in Bq_match
#     2.16e-13 in FOC_capital_agency
#     5.03e-12 in FOC_K_ell
#     6.36e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.36e-11
#     3.11e-14 in bargaining_cond
#     6.44e-12 in Bq_match
#     4.79e-14 in FOC_capital_agency
#     2.65e-13 in FOC_K_ell
#     1.15e-11 in mkt_clearing

# %% [markdown]
# # Figures

# %% [markdown]
# ## National accouting - quantities

# %%
model.plot_IRF(varlist=['Y','C','G','I','X','M'])

# %% [markdown]
# ## National Accouting - Prices

# %%
model.plot_IRF(varlist=['P_Y','P_C','P_G','P_I','P_X','P_F'])

# %% [markdown]
# ## Labor market

# %%
model.plot_IRF(varlist=['S','v','curlyM','m_v','m_s','delta_L','W','real_W'],abs=['m_v','m_s'])

# %% [markdown]
# ## Capital accumulation

# %%
model.plot_IRF(varlist=['K','I','r_K','P_I'],ncol=2)

# %% [markdown]
# ## Production firms

# %%
model.plot_IRF(varlist=['K','ell','Y','r_K','r_ell'],ncol=2)

# %% [markdown]
# ## Government

# %%
model.plot_IRF(varlist=['G','B_G','tau'],abs=['tau'],Y_share=['B_G'])

# %% [markdown]
# ## Households - aggregate

# %%
model.plot_IRF(varlist=['L','inc','W','real_W','real_r_hh','C','B','Bq'],ncol=3, T_IRF = 150,abs=['real_r_hh'])

# %%
model.plot_IRF(varlist=['C_HtM','C_R'],ncol=2)

# %% [markdown]
# ## Households - life-cycle

# %%
model.plot_IRF_hh(varlist=['L_a','inc_a','C_a','B_a'],t0_list=[-20,-10,0,10,20])
