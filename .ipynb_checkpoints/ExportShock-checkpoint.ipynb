# %%
# %load_ext autoreload
# %autoreload 2

import time
import pickle
import numpy as np
from scipy import optimize

import matplotlib.pyplot as plt   
plt.style.use('seaborn-whitegrid')
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

from BabyMAKROModel import BabyMAKROModelClass

# %% [markdown]
# # Setup

# %%
model = BabyMAKROModelClass(name='Extended') # create an instance of the model

# %%
par = model.par
ss = model.ss
sol = model.sol

# %% [markdown]
# # Find steady state

# %%
model.find_ss(do_print=True)
# Out:
# Labor supply and search and matching:
# ss.S = 7.44,  ss.L = 56.28,  ss.delta_L = 0.07,  ss.v = 16.52,  ss.m_v = 0.23
# Capital agency FOC:
# ss.r_K = 0.14
# Production firm pricing:
# ss.r_ell = 2.71
# Labor agency:
# ss.ell = 55.87,  ss.W = 2.68
# Government:
# ss.B_G = 150.00,  ss.G = 50.00,  ss.tau = 0.37
# Households:
# solving for household behavior: result.converged = True
# ss.C = 91.20,  ss.B = 216.42
# Production firm FOCs:
# ss.K = 557.43
# Capital accumulation equation:
# ss.I = 55.74
# Output in production firm:
# ss.Y = 229.56
# Market clearing:
# ss.C_Y = 63.84,  ss.G_Y = 45.00,  ss.I_Y = 36.23,  ss.X_Y = 84.49
# [ ss.C_M = 27.36,  ss.G_M = 5.00,  ss.I_M = 19.51,  ss.X_M = 56.32 ] = ss.M = 108.20
# ss.X = 140.81
# Bargaining:
# par.phi = 0.984

# %% [markdown]
# **Household behavior:**

# %%
fig = plt.figure(figsize=(3*6,3*6/2.5))

ax = fig.add_subplot(2,4,1)
ax.plot(model.par.delta_L_a*100)
ax.set_ylabel('%')
ax.set_title('$\delta^L_a$')

ax = fig.add_subplot(2,4,2)
ax.plot(model.ss.S_a)
ax.set_title('$S_a$')

ax = fig.add_subplot(2,4,3)
ax.plot(model.ss.L_a)
ax.set_title('$L_a$')

ax = fig.add_subplot(2,4,4)
ax.plot(model.ss.L_ubar_a)
ax.set_title(r'$L\underbar_a$')

ax = fig.add_subplot(2,4,5)
ax.plot(model.ss.B_a)
ax.set_ylabel('')
ax.set_title('$B_a$')

ax = fig.add_subplot(2,4,6)
ax.plot(model.ss.C_a)
ax.set_ylabel('')
ax.set_title('$C_a$')

ax = fig.add_subplot(2,4,7)
ax.plot(model.ss.C_R_a)
ax.set_ylabel('')
ax.set_title('$C^R_a$')

ax = fig.add_subplot(2,4,8)
ax.plot(model.ss.C_HtM_a)
ax.set_ylabel('')
ax.set_title('$C^{HtM}_a$');

# %% [markdown]
# # Speed and error tests

# %%
model.set_exo_ss()
model.set_unknowns_ss()

# %% [markdown]
# **Python evaluation:**

# %%
# %time model.evaluate_blocks(py=True)
# Out:
# CPU times: user 1.97 s, sys: 44.2 ms, total: 2.01 s
# Wall time: 2.14 s

# %% [markdown]
# **Check errors:**

# %%
errors = model.get_errors(do_print=True)
# Out:
# bargaining_cond     : abs. max = 0.00e+00
# Bq_match            : abs. max = 3.64e+01
# FOC_capital_agency  : abs. max = 0.00e+00
# FOC_K_ell           : abs. max = 7.11e-15
# mkt_clearing        : abs. max = 4.70e+00

# %% [markdown]
# **First numba evaluation:**

# %%
# %time model.evaluate_blocks()
# Out:
# CPU times: user 19.4 s, sys: 357 ms, total: 19.8 s
# Wall time: 20 s

# %% [markdown]
# **Time:**

# %%
# %timeit model.evaluate_blocks()
# %timeit model.get_errors()
# Out:
# 6.56 ms ± 445 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 24.8 µs ± 2.77 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %timeit model.evaluate_blocks(py=True)
# Out:
# 180 ms ± 8.62 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# # Find an impulse-response

# %% [markdown]
# **Calculate Jacobian:**

# %%
model.calc_jac(do_print=True)
# Out:
# Jacobian calculated in 15.6 secs secs

# %% [markdown]
# **Set exogenous variables:**

# %%
Tshock = 50
shock = 0.01*ss.chi
persistence = 0.8**np.arange(Tshock)
sol.chi[:Tshock] = ss.chi + shock*persistence

Tshock = 50
shock = 0.03*ss.P_F
persistence = 0.80**np.arange(Tshock)
sol.P_F[:Tshock] = ss.P_F + shock*persistence

# %%
model.set_unknowns_ss()
model.evaluate_blocks()
errors = model.get_errors(do_print=True)
# Out:
# bargaining_cond     : abs. max = 0.00e+00
# Bq_match            : abs. max = 3.64e+01
# FOC_capital_agency  : abs. max = 0.00e+00
# FOC_K_ell           : abs. max = 8.88e-15
# mkt_clearing        : abs. max = 1.05e+01

# %% [markdown]
# **Find IRF:**

# %%
model.find_IRF()
# Out:
# initial:
#    max. abs. error = 3.64e+01
#     0.00e+00 in bargaining_cond
#     3.64e+01 in Bq_match
#     0.00e+00 in FOC_capital_agency
#     8.88e-15 in FOC_K_ell
#     1.05e+01 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 3.64e+01
#     1.48e-02 in bargaining_cond
#     2.51e+00 in Bq_match
#     9.55e-03 in FOC_capital_agency
#     3.15e-01 in FOC_K_ell
#     4.72e+00 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.72e+00
#     8.91e-03 in bargaining_cond
#     1.07e+00 in Bq_match
#     6.17e-03 in FOC_capital_agency
#     1.75e-01 in FOC_K_ell
#     2.61e+00 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.61e+00
#     2.46e-03 in bargaining_cond
#     3.18e-01 in Bq_match
#     1.61e-03 in FOC_capital_agency
#     5.22e-02 in FOC_K_ell
#     7.20e-01 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 7.20e-01
#     4.24e-04 in bargaining_cond
#     5.82e-02 in Bq_match
#     2.41e-04 in FOC_capital_agency
#     8.49e-03 in FOC_K_ell
#     1.26e-01 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.26e-01
#     2.66e-05 in bargaining_cond
#     2.91e-03 in Bq_match
#     2.31e-05 in FOC_capital_agency
#     6.20e-04 in FOC_K_ell
#     9.71e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 9.71e-03
#     1.64e-05 in bargaining_cond
#     3.50e-04 in Bq_match
#     2.79e-05 in FOC_capital_agency
#     4.03e-04 in FOC_K_ell
#     6.10e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.10e-03
#     1.68e-05 in bargaining_cond
#     3.76e-04 in Bq_match
#     2.48e-05 in FOC_capital_agency
#     3.99e-04 in FOC_K_ell
#     6.12e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.12e-03
#     1.06e-05 in bargaining_cond
#     2.69e-04 in Bq_match
#     1.50e-05 in FOC_capital_agency
#     2.50e-04 in FOC_K_ell
#     3.82e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.82e-03
#     1.75e-06 in bargaining_cond
#     4.03e-05 in Bq_match
#     2.56e-06 in FOC_capital_agency
#     4.15e-05 in FOC_K_ell
#     6.36e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.36e-04
#     4.27e-07 in bargaining_cond
#     9.52e-06 in Bq_match
#     6.43e-07 in FOC_capital_agency
#     1.02e-05 in FOC_K_ell
#     1.56e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 10
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.56e-04
#     5.16e-09 in bargaining_cond
#     2.33e-07 in Bq_match
#     7.45e-09 in FOC_capital_agency
#     1.11e-07 in FOC_K_ell
#     1.71e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 11
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.71e-06
#     6.75e-09 in bargaining_cond
#     1.03e-07 in Bq_match
#     1.31e-08 in FOC_capital_agency
#     1.66e-07 in FOC_K_ell
#     2.55e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 12
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.55e-06
#     3.21e-09 in bargaining_cond
#     4.90e-08 in Bq_match
#     6.09e-09 in FOC_capital_agency
#     7.89e-08 in FOC_K_ell
#     1.21e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 13
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.21e-06
#     4.44e-11 in bargaining_cond
#     8.92e-10 in Bq_match
#     8.56e-11 in FOC_capital_agency
#     1.10e-09 in FOC_K_ell
#     1.76e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 14
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.76e-08
#     9.60e-12 in bargaining_cond
#     3.13e-10 in Bq_match
#     1.93e-11 in FOC_capital_agency
#     2.29e-10 in FOC_K_ell
#     3.66e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 15
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.66e-09
#     1.45e-12 in bargaining_cond
#     3.87e-11 in Bq_match
#     3.06e-12 in FOC_capital_agency
#     3.61e-11 in FOC_K_ell
#     5.83e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 16
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.83e-10
#     5.30e-13 in bargaining_cond
#     1.42e-11 in Bq_match
#     9.19e-13 in FOC_capital_agency
#     1.24e-11 in FOC_K_ell
#     1.94e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 17
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.94e-10
#     9.06e-14 in bargaining_cond
#     7.28e-12 in Bq_match
#     1.71e-13 in FOC_capital_agency
#     1.95e-12 in FOC_K_ell
#     3.46e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 18
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.46e-11
#     6.66e-14 in bargaining_cond
#     8.55e-12 in Bq_match
#     1.34e-13 in FOC_capital_agency
#     1.73e-12 in FOC_K_ell
#     2.65e-11 in mkt_clearing

# %% [markdown]
# # Figures

# %% [markdown]
# ## National accouting - quantities

# %%
model.plot_IRF(varlist=['Y','C','G','I','X','M'])

# %% [markdown]
# ## National Accouting - Prices

# %%
model.plot_IRF(varlist=['P_Y','P_C','P_G','P_I','P_X','P_F'])

# %% [markdown]
# ## Labor market

# %%
model.plot_IRF(varlist=['S','v','curlyM','m_v','m_s','delta_L','W','real_W'],abs=['m_v','m_s'])

# %% [markdown]
# ## Capital accumulation

# %%
model.plot_IRF(varlist=['K','I','r_K','P_I'],ncol=2)

# %% [markdown]
# ## Production firms

# %%
model.plot_IRF(varlist=['K','ell','Y','r_K','r_ell'],ncol=2)

# %% [markdown]
# ## Government

# %%
model.plot_IRF(varlist=['G','B_G','tau'],abs=['tau'],Y_share=['B_G'])

# %% [markdown]
# ## Households - aggregate

# %%
model.plot_IRF(varlist=['L','inc','W','real_W','real_r_hh','C','B','Bq'],ncol=3, T_IRF = 150,abs=['real_r_hh'])

# %%
model.plot_IRF(varlist=['C_HtM','C_R'],ncol=2)

# %% [markdown]
# ## Households - life-cycle

# %%
model.plot_IRF_hh(varlist=['L_a','inc_a','C_a','B_a'],t0_list=[-20,-10,0,10,20])
