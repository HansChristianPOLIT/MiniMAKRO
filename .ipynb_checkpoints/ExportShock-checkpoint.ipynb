# %% [markdown]
# # Foreign Demand Shock

# %%
# %load_ext autoreload
# %autoreload 2

import time
import pickle
import numpy as np
from scipy import optimize

import matplotlib.pyplot as plt   
plt.style.use('seaborn-whitegrid')
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

from BabyMAKROModel import BabyMAKROModelClass

# %% [markdown]
# # Setup

# %%
model = BabyMAKROModelClass(name='Extended') # create an instance of the model

# %%
par = model.par
ss = model.ss
sol = model.sol

# %% [markdown]
# # Find steady state

# %%
model.find_ss(do_print=True)
# Out:
# Labor supply and search and matching:
# ss.S = 4.24,  ss.L = 57.88,  ss.delta_L = 0.04,  ss.v = 9.41,  ss.m_v = 0.23
# Capital agency FOC:
# ss.r_K = 0.14
# Production firm pricing:
# ss.r_ell = 2.71
# Labor agency:
# ss.ell = 57.51,  ss.W = 2.68
# Government:
# ss.B_G = 100.00,  ss.G = 61.82,  ss.tau = 0.42
# Households:
# solving for household behavior: result.converged = True
# ss.C = 79.33,  ss.B = 161.32
# Production firm FOCs:
# ss.K = 573.77
# Capital accumulation equation:
# ss.I = 57.38
# Output in production firm:
# ss.Y = 236.29
# Market clearing:
# ss.C_Y = 55.53,  ss.G_Y = 55.64,  ss.I_Y = 37.29,  ss.X_Y = 87.83
# [ ss.C_M = 23.80,  ss.G_M = 6.18,  ss.I_M = 20.08,  ss.X_M = 58.55 ] = ss.M = 108.61
# ss.X = 146.38
# Bargaining:
# par.phi = 0.981

# %% [markdown]
# # Find an impulse-response

# %% [markdown]
# **Calculate Jacobian:**

# %%
model.calc_jac(do_print=True)
# Out:
# Jacobian calculated in 39.0 secs secs

# %% [markdown]
# **Set exogenous variables:**

# %%
model.set_exo_ss()

# %% [markdown]
# **Introduce Shock**

# %%
Tshock = 50
shock = 0.01*ss.chi
persistence = 0.8**np.arange(Tshock)
sol.chi[:Tshock] = ss.chi + shock*persistence

Tshock = 50
shock = 0.03*ss.P_F
persistence = 0.80**np.arange(Tshock)
sol.P_F[:Tshock] = ss.P_F + shock*persistence

# %%
model.set_unknowns_ss()
model.evaluate_blocks()
errors = model.get_errors(do_print=True)
# Out:
# bargaining_cond     : abs. max = 0.00e+00
# Bq_match            : abs. max = 1.13e+00
# FOC_capital_agency  : abs. max = 3.33e-16
# FOC_K_ell           : abs. max = 2.49e-14
# mkt_clearing        : abs. max = 2.45e+00

# %% [markdown]
# **Find IRF:**

# %%
model.find_IRF()
# Out:
# initial:
#    max. abs. error = 2.45e+00
#     0.00e+00 in bargaining_cond
#     1.13e+00 in Bq_match
#     3.33e-16 in FOC_capital_agency
#     2.49e-14 in FOC_K_ell
#     2.45e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.45e+00
#     2.69e-04 in bargaining_cond
#     3.03e-02 in Bq_match
#     2.24e-04 in FOC_capital_agency
#     7.03e-03 in FOC_K_ell
#     9.66e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 9.66e-02
#     3.68e-05 in bargaining_cond
#     1.61e-03 in Bq_match
#     3.93e-05 in FOC_capital_agency
#     8.93e-04 in FOC_K_ell
#     1.08e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.08e-02
#     8.10e-06 in bargaining_cond
#     2.21e-04 in Bq_match
#     8.28e-06 in FOC_capital_agency
#     1.94e-04 in FOC_K_ell
#     2.32e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.32e-03
#     9.16e-07 in bargaining_cond
#     3.40e-05 in Bq_match
#     8.85e-07 in FOC_capital_agency
#     2.19e-05 in FOC_K_ell
#     2.62e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.62e-04
#     1.47e-07 in bargaining_cond
#     4.37e-06 in Bq_match
#     1.43e-07 in FOC_capital_agency
#     3.51e-06 in FOC_K_ell
#     4.22e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.22e-05
#     1.42e-09 in bargaining_cond
#     1.57e-07 in Bq_match
#     1.58e-09 in FOC_capital_agency
#     3.37e-08 in FOC_K_ell
#     4.08e-07 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.08e-07
#     5.03e-11 in bargaining_cond
#     7.89e-09 in Bq_match
#     5.20e-11 in FOC_capital_agency
#     1.55e-09 in FOC_K_ell
#     1.68e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.68e-08
#     2.79e-12 in bargaining_cond
#     3.17e-10 in Bq_match
#     3.86e-12 in FOC_capital_agency
#     8.35e-11 in FOC_K_ell
#     9.28e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 9.28e-10
#     5.33e-13 in bargaining_cond
#     2.56e-11 in Bq_match
#     6.18e-13 in FOC_capital_agency
#     1.27e-11 in FOC_K_ell
#     1.56e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.56e-10
#     2.93e-14 in bargaining_cond
#     6.27e-12 in Bq_match
#     3.61e-14 in FOC_capital_agency
#     6.54e-13 in FOC_K_ell
#     1.09e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 10
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.09e-11
#     2.66e-14 in bargaining_cond
#     6.40e-12 in Bq_match
#     3.57e-14 in FOC_capital_agency
#     2.63e-13 in FOC_K_ell
#     9.95e-12 in mkt_clearing

# %% [markdown]
# # Impulse Response Figures

# %% [markdown]
# ## Longview - To Check Convergence

# %%
model.plot_IRF(varlist=['X','C','Y'],T_IRF=par.T,ncol=2)

# %% [markdown]
# ## National accouting - Quantities

# %%
model.plot_IRF(varlist=['Y','C','G','I','X','M'])

# %% [markdown]
# ## National Accouting - Prices

# %%
model.plot_IRF(varlist=['P_Y','P_C','P_G','P_I','P_X','P_F'])

# %% [markdown]
# ## Labor market

# %%
model.plot_IRF(varlist=['S','v','curlyM','m_v','m_s','delta_L','W','real_W'],abs=['m_v','m_s'])

# %% [markdown]
# ## Capital accumulation

# %%
model.plot_IRF(varlist=['K','I','r_K','P_I'],ncol=2)

# %% [markdown]
# ## Production firms

# %%
model.plot_IRF(varlist=['K','ell','Y','r_K','r_ell'],ncol=2)

# %% [markdown]
# ## Government

# %%
model.plot_IRF(varlist=['G','B_G','tau'],abs=['tau'],Y_share=['B_G'])

# %% [markdown]
# ## Households - aggregate

# %%
model.plot_IRF(varlist=['L','inc','W','real_W','C','B','Bq'],ncol=3, T_IRF = 150)

# %%
model.plot_IRF(varlist=['C_HtM','C_R'],ncol=2)

# %% [markdown]
# ## Households - life-cycle

# %%
model.plot_IRF_hh(varlist=['L_a','inc_a','C_a','B_a'],t0_list=[-20,-10,0,10,20])

# %% [markdown]
# # Sensitivity Analysis

# %% [markdown]
# ## Change in HtM-share

# %%
model = BabyMAKROModelClass(name='Extended') # create an instance of the model
par = model.par
ss = model.ss
sol = model.sol
model1 = model.copy()
model2 = model.copy()
model3 = model.copy()

# %%
Models = [model, model1, model2, model3] #Create list of the models
Lambdas = [0.0, 0.1, 0.25, 0.4] #Create list of Lambda values
    
for i in range(len(Models)):
    Models[i].par.Lambda = Lambdas[i]
    Models[i].find_ss()
    Models[i].calc_jac()
    Gshock = 50
    shock_chi = 0.01*Models[i].ss.chi
    persistence_chi = 0.8**np.arange(Tshock)
    Models[i].sol.chi[:Tshock] = Models[i].ss.chi + shock_chi*persistence_chi
    shock_p_f = 0.03*ss.P_F
    persistence_p_f = 0.80**np.arange(Tshock)
    Models[i].sol.P_F[:Tshock] = ss.P_F + shock_p_f*persistence_p_f
    Models[i].find_IRF()
# Out:
# initial:
#    max. abs. error = 2.03e+00
#     0.00e+00 in bargaining_cond
#     4.32e-13 in Bq_match
#     3.33e-16 in FOC_capital_agency
#     2.49e-14 in FOC_K_ell
#     2.03e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 2.03e+00
#     2.37e-04 in bargaining_cond
#     3.56e-02 in Bq_match
#     1.75e-04 in FOC_capital_agency
#     6.14e-03 in FOC_K_ell
#     7.84e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 7.84e-02
#     3.51e-05 in bargaining_cond
#     1.83e-03 in Bq_match
#     3.17e-05 in FOC_capital_agency
#     8.54e-04 in FOC_K_ell
#     9.69e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 9.69e-03
#     5.86e-06 in bargaining_cond
#     3.86e-04 in Bq_match
#     5.36e-06 in FOC_capital_agency
#     1.41e-04 in FOC_K_ell
#     1.58e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.58e-03
#     6.39e-07 in bargaining_cond
#     4.65e-05 in Bq_match
#     5.79e-07 in FOC_capital_agency
#     1.53e-05 in FOC_K_ell
#     1.73e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.73e-04
#     1.60e-08 in bargaining_cond
#     1.96e-06 in Bq_match
#     1.47e-08 in FOC_capital_agency
#     3.82e-07 in FOC_K_ell
#     4.24e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.24e-06
#     3.72e-10 in bargaining_cond
#     7.14e-08 in Bq_match
#     2.83e-10 in FOC_capital_agency
#     8.83e-09 in FOC_K_ell
#     9.54e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 9.54e-08
#     1.39e-11 in bargaining_cond
#     2.66e-09 in Bq_match
#     9.18e-12 in FOC_capital_agency
#     3.28e-10 in FOC_K_ell
#     3.57e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.57e-09
#     1.95e-12 in bargaining_cond
#     2.21e-10 in Bq_match
#     1.96e-12 in FOC_capital_agency
#     4.63e-11 in FOC_K_ell
#     5.26e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.26e-10
#     1.08e-13 in bargaining_cond
#     1.46e-11 in Bq_match
#     1.39e-13 in FOC_capital_agency
#     2.68e-12 in FOC_K_ell
#     3.01e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.01e-11
#     3.77e-14 in bargaining_cond
#     1.33e-11 in Bq_match
#     3.55e-14 in FOC_capital_agency
#     3.23e-13 in FOC_K_ell
#     1.36e-11 in mkt_clearing
# initial:
#    max. abs. error = 2.23e+00
#     0.00e+00 in bargaining_cond
#     7.81e-01 in Bq_match
#     3.33e-16 in FOC_capital_agency
#     2.49e-14 in FOC_K_ell
#     2.23e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.23e+00
#     2.37e-04 in bargaining_cond
#     3.57e-02 in Bq_match
#     1.92e-04 in FOC_capital_agency
#     6.19e-03 in FOC_K_ell
#     8.26e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 8.26e-02
#     3.17e-05 in bargaining_cond
#     1.47e-03 in Bq_match
#     3.25e-05 in FOC_capital_agency
#     7.72e-04 in FOC_K_ell
#     9.06e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 9.06e-03
#     6.15e-06 in bargaining_cond
#     2.55e-04 in Bq_match
#     6.13e-06 in FOC_capital_agency
#     1.47e-04 in FOC_K_ell
#     1.71e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.71e-03
#     6.73e-07 in bargaining_cond
#     3.29e-05 in Bq_match
#     6.43e-07 in FOC_capital_agency
#     1.61e-05 in FOC_K_ell
#     1.87e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.87e-04
#     4.72e-08 in bargaining_cond
#     1.96e-06 in Bq_match
#     4.54e-08 in FOC_capital_agency
#     1.13e-06 in FOC_K_ell
#     1.32e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.32e-05
#     1.74e-09 in bargaining_cond
#     1.08e-07 in Bq_match
#     1.80e-09 in FOC_capital_agency
#     4.16e-08 in FOC_K_ell
#     4.87e-07 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.87e-07
#     3.57e-11 in bargaining_cond
#     7.36e-09 in Bq_match
#     2.91e-11 in FOC_capital_agency
#     8.85e-10 in FOC_K_ell
#     9.60e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 9.60e-09
#     1.46e-12 in bargaining_cond
#     1.93e-10 in Bq_match
#     2.13e-12 in FOC_capital_agency
#     3.53e-11 in FOC_K_ell
#     4.24e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.24e-10
#     1.95e-13 in bargaining_cond
#     1.32e-11 in Bq_match
#     2.38e-13 in FOC_capital_agency
#     4.76e-12 in FOC_K_ell
#     5.46e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.46e-11
#     3.38e-14 in bargaining_cond
#     1.00e-11 in Bq_match
#     3.92e-14 in FOC_capital_agency
#     3.98e-13 in FOC_K_ell
#     1.32e-11 in mkt_clearing
# initial:
#    max. abs. error = 2.45e+00
#     0.00e+00 in bargaining_cond
#     1.13e+00 in Bq_match
#     3.33e-16 in FOC_capital_agency
#     2.49e-14 in FOC_K_ell
#     2.45e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.45e+00
#     2.69e-04 in bargaining_cond
#     3.03e-02 in Bq_match
#     2.24e-04 in FOC_capital_agency
#     7.03e-03 in FOC_K_ell
#     9.66e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 9.66e-02
#     3.68e-05 in bargaining_cond
#     1.61e-03 in Bq_match
#     3.93e-05 in FOC_capital_agency
#     8.93e-04 in FOC_K_ell
#     1.08e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.08e-02
#     8.10e-06 in bargaining_cond
#     2.21e-04 in Bq_match
#     8.28e-06 in FOC_capital_agency
#     1.94e-04 in FOC_K_ell
#     2.32e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.32e-03
#     9.16e-07 in bargaining_cond
#     3.40e-05 in Bq_match
#     8.85e-07 in FOC_capital_agency
#     2.19e-05 in FOC_K_ell
#     2.62e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.62e-04
#     1.47e-07 in bargaining_cond
#     4.37e-06 in Bq_match
#     1.43e-07 in FOC_capital_agency
#     3.51e-06 in FOC_K_ell
#     4.22e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.22e-05
#     1.42e-09 in bargaining_cond
#     1.57e-07 in Bq_match
#     1.58e-09 in FOC_capital_agency
#     3.37e-08 in FOC_K_ell
#     4.08e-07 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.08e-07
#     5.03e-11 in bargaining_cond
#     7.89e-09 in Bq_match
#     5.20e-11 in FOC_capital_agency
#     1.55e-09 in FOC_K_ell
#     1.68e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.68e-08
#     2.79e-12 in bargaining_cond
#     3.17e-10 in Bq_match
#     3.86e-12 in FOC_capital_agency
#     8.35e-11 in FOC_K_ell
#     9.28e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 9.28e-10
#     5.33e-13 in bargaining_cond
#     2.56e-11 in Bq_match
#     6.18e-13 in FOC_capital_agency
#     1.27e-11 in FOC_K_ell
#     1.56e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.56e-10
#     2.93e-14 in bargaining_cond
#     6.27e-12 in Bq_match
#     3.61e-14 in FOC_capital_agency
#     6.54e-13 in FOC_K_ell
#     1.09e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 10
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.09e-11
#     2.66e-14 in bargaining_cond
#     6.40e-12 in Bq_match
#     3.57e-14 in FOC_capital_agency
#     2.63e-13 in FOC_K_ell
#     9.95e-12 in mkt_clearing
# initial:
#    max. abs. error = 2.59e+00
#     0.00e+00 in bargaining_cond
#     9.21e-01 in Bq_match
#     3.33e-16 in FOC_capital_agency
#     2.49e-14 in FOC_K_ell
#     2.59e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.59e+00
#     3.14e-04 in bargaining_cond
#     2.12e-02 in Bq_match
#     2.53e-04 in FOC_capital_agency
#     8.20e-03 in FOC_K_ell
#     1.14e-01 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.2 secs
#    max. abs. error = 1.14e-01
#     4.79e-05 in bargaining_cond
#     1.09e-03 in Bq_match
#     4.92e-05 in FOC_capital_agency
#     1.16e-03 in FOC_K_ell
#     1.43e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.43e-02
#     1.14e-05 in bargaining_cond
#     2.08e-04 in Bq_match
#     1.13e-05 in FOC_capital_agency
#     2.73e-04 in FOC_K_ell
#     3.33e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.33e-03
#     1.42e-06 in bargaining_cond
#     3.04e-05 in Bq_match
#     1.36e-06 in FOC_capital_agency
#     3.40e-05 in FOC_K_ell
#     4.16e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.16e-04
#     1.18e-07 in bargaining_cond
#     2.19e-06 in Bq_match
#     1.14e-07 in FOC_capital_agency
#     2.83e-06 in FOC_K_ell
#     3.49e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.49e-05
#     4.97e-09 in bargaining_cond
#     1.34e-07 in Bq_match
#     5.10e-09 in FOC_capital_agency
#     1.18e-07 in FOC_K_ell
#     1.46e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.46e-06
#     1.45e-10 in bargaining_cond
#     1.11e-08 in Bq_match
#     1.23e-10 in FOC_capital_agency
#     3.44e-09 in FOC_K_ell
#     4.15e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.15e-08
#     5.61e-12 in bargaining_cond
#     3.30e-10 in Bq_match
#     8.09e-12 in FOC_capital_agency
#     1.35e-10 in FOC_K_ell
#     1.71e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.71e-09
#     8.78e-13 in bargaining_cond
#     2.21e-11 in Bq_match
#     1.04e-12 in FOC_capital_agency
#     2.10e-11 in FOC_K_ell
#     2.62e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.62e-10
#     5.24e-14 in bargaining_cond
#     4.87e-12 in Bq_match
#     5.35e-14 in FOC_capital_agency
#     1.06e-12 in FOC_K_ell
#     1.81e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 10
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.81e-11
#     2.49e-14 in bargaining_cond
#     3.96e-12 in Bq_match
#     3.33e-14 in FOC_capital_agency
#     3.98e-13 in FOC_K_ell
#     9.35e-12 in mkt_clearing

# %%
T_IRF = 150

fig = plt.figure(figsize=(3*6,3*6/1.5))

ax = fig.add_subplot(3,3,1)
ax.plot((Models[0].sol.chi[:T_IRF]/Models[0].ss.chi-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.chi[:T_IRF]/Models[1].ss.chi-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.chi[:T_IRF]/Models[2].ss.chi-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Foreign Demand Shifter ($\chi_t$)')
ax.legend(frameon=True)

ax = fig.add_subplot(3,3,2)
ax.plot((Models[0].sol.X[:T_IRF]/Models[0].ss.X-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.X[:T_IRF]/Models[1].ss.X-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.X[:T_IRF]/Models[2].ss.X-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.X[:T_IRF]/Models[3].ss.X-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Export ($X_t$)')

ax = fig.add_subplot(3,3,3)
ax.plot((Models[0].sol.Y[:T_IRF]/Models[0].ss.Y-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.Y[:T_IRF]/Models[1].ss.Y-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.Y[:T_IRF]/Models[2].ss.Y-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.Y[:T_IRF]/Models[3].ss.Y-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Production ($Y_t$)')

ax = fig.add_subplot(3,3,4)
ax.plot((Models[0].sol.K[:T_IRF]/Models[0].ss.K-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.K[:T_IRF]/Models[1].ss.K-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.K[:T_IRF]/Models[2].ss.K-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.K[:T_IRF]/Models[3].ss.K-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Capital ($K_t$)')

ax = fig.add_subplot(3,3,5)
ax.plot((Models[0].sol.L[:T_IRF]/Models[0].ss.L-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.L[:T_IRF]/Models[1].ss.L-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.L[:T_IRF]/Models[2].ss.L-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.L[:T_IRF]/Models[3].ss.L-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Employment ($L_t$)')

ax = fig.add_subplot(3,3,6)
ax.plot((Models[0].sol.W[:T_IRF]/Models[0].ss.W-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.W[:T_IRF]/Models[1].ss.W-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.W[:T_IRF]/Models[2].ss.W-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.W[:T_IRF]/Models[3].ss.W-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Wage ($W_{t}$)')

ax = fig.add_subplot(3,3,7)
ax.plot((Models[0].sol.C[:T_IRF]/Models[0].ss.C-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.C[:T_IRF]/Models[1].ss.C-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.C[:T_IRF]/Models[2].ss.C-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.C[:T_IRF]/Models[3].ss.C-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Consumption ($C_{t}$)')

ax = fig.add_subplot(3,3,8)
ax.plot((Models[0].sol.B[:T_IRF]/Models[0].ss.B-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.B[:T_IRF]/Models[1].ss.B-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.B[:T_IRF]/Models[2].ss.B-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.B[:T_IRF]/Models[3].ss.B-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Savings ($B_{t}$)')

ax = fig.add_subplot(3,3,9)
ax.plot((Models[0].sol.Bq[:T_IRF]/Models[0].ss.Bq-1)*100,label=f'Baseline:$\lambda$ = {Models[0].par.Lambda}', color = 'k', linestyle = '--')
ax.plot((Models[1].sol.Bq[:T_IRF]/Models[1].ss.Bq-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.Bq[:T_IRF]/Models[2].ss.Bq-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.plot((Models[3].sol.Bq[:T_IRF]/Models[3].ss.Bq-1)*100,label=f'$\lambda$ = {Models[3].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Bequest ($B^{q}_{t}$)');
