# %%
# %load_ext autoreload
# %autoreload 2

import time
import pickle
import numpy as np
from scipy import optimize

import matplotlib.pyplot as plt   
plt.style.use('seaborn-whitegrid')
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

from BabyMAKROModel import BabyMAKROModelClass
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Setup

# %%
model = BabyMAKROModelClass(name='Extended') # create an instance of the model

# %%
par = model.par
ss = model.ss
sol = model.sol

# %% [markdown]
# # Find steady state

# %%
model.find_ss(do_print=True)
# Out:
# Labor supply and search and matching:
# ss.S = 7.44,  ss.L = 56.28,  ss.delta_L = 0.07,  ss.v = 16.52,  ss.m_v = 0.23
# Capital agency FOC:
# ss.r_K = 0.14
# Production firm pricing:
# ss.r_ell = 2.71
# Labor agency:
# ss.ell = 55.87,  ss.W = 2.68
# Government:
# ss.B_G = 150.00,  ss.G = 50.00,  ss.tau = 0.37
# Households:
# solving for household behavior: result.converged = True
# ss.C = 91.23,  ss.B = 249.03
# Production firm FOCs:
# ss.K = 557.43
# Capital accumulation equation:
# ss.I = 55.74
# Output in production firm:
# ss.Y = 229.56
# Market clearing:
# ss.C_Y = 63.86,  ss.G_Y = 35.00,  ss.I_Y = 36.23,  ss.X_Y = 94.47
# [ ss.C_M = 27.37,  ss.G_M = 15.00,  ss.I_M = 19.51,  ss.X_M = 62.98 ] = ss.M = 124.86
# ss.X = 157.45
# Bargaining:
# par.phi = 0.984

# %% [markdown]
# **Household behavior:**

# %%
fig = plt.figure(figsize=(3*6,3*6/2.5))

ax = fig.add_subplot(2,4,1)
ax.plot(model.par.delta_L_a*100)
ax.set_ylabel('%')
ax.set_title('$\delta^L_a$')

ax = fig.add_subplot(2,4,2)
ax.plot(model.ss.S_a)
ax.set_title('$S_a$')

ax = fig.add_subplot(2,4,3)
ax.plot(model.ss.L_a)
ax.set_title('$L_a$')

ax = fig.add_subplot(2,4,4)
ax.plot(model.ss.L_ubar_a)
ax.set_title(r'$L\underbar_a$')

ax = fig.add_subplot(2,4,5)
ax.plot(model.ss.B_a)
ax.set_ylabel('')
ax.set_title('$B_a$')

ax = fig.add_subplot(2,4,6)
ax.plot(model.ss.C_a)
ax.set_ylabel('')
ax.set_title('$C_a$')

ax = fig.add_subplot(2,4,7)
ax.plot(model.ss.C_R)
ax.set_ylabel('')
ax.set_title('$C^R_a$')

ax = fig.add_subplot(2,4,8)
ax.plot(model.ss.C_HtM)
ax.set_ylabel('')
ax.set_title('$C^{HtM}_a$');

# %% [markdown]
# # Speed and error tests

# %%
model.set_exo_ss()
model.set_unknowns_ss()

# %% [markdown]
# **Python evaluation:**

# %%
# %time model.evaluate_blocks(py=True)
# Out:
# CPU times: user 1.82 s, sys: 17.3 ms, total: 1.83 s
# Wall time: 1.84 s

# %% [markdown]
# **Check errors:**

# %%
errors = model.get_errors(do_print=True)
# Out:
# bargaining_cond     : abs. max = 0.00e+00
# Bq_match            : abs. max = 4.39e+01
# FOC_capital_agency  : abs. max = 0.00e+00
# FOC_K_ell           : abs. max = 7.11e-15
# mkt_clearing        : abs. max = 4.70e+00

# %% [markdown]
# **First numba evaluation:**

# %%
# %time model.evaluate_blocks()
# Out:
# CPU times: user 18 s, sys: 327 ms, total: 18.4 s
# Wall time: 18.8 s

# %% [markdown]
# **Time:**

# %%
# %timeit model.evaluate_blocks()
# %timeit model.get_errors()
# Out:
# 5.29 ms ± 147 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 22.5 µs ± 3.31 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %timeit model.evaluate_blocks(py=True)
# Out:
# 214 ms ± 10.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# # Find an impulse-response

# %% [markdown]
# **Calculate Jacobian:**

# %%
model.calc_jac(do_print=True)
# Out:
# Jacobian calculated in 14.9 secs secs

# %% [markdown]
# **Set exogenous variables:**

# %%
Tshock = 50
shock = 0.01*ss.chi
persistence = 0.8**np.arange(Tshock)
sol.chi[:Tshock] = ss.chi + shock*persistence

Tshock = 50
shock = 0.03*ss.P_F
persistence = 0.80**np.arange(Tshock)
sol.P_F[:Tshock] = ss.P_F + shock*persistence

# %%
model.set_unknowns_ss()
model.evaluate_blocks()
errors = model.get_errors(do_print=True)
# Out:
# bargaining_cond     : abs. max = 0.00e+00
# Bq_match            : abs. max = 4.39e+01
# FOC_capital_agency  : abs. max = 0.00e+00
# FOC_K_ell           : abs. max = 8.88e-15
# mkt_clearing        : abs. max = 9.97e+00

# %% [markdown]
# **Find IRF:**

# %%
model.find_IRF()
# Out:
# initial:
#    max. abs. error = 4.39e+01
#     0.00e+00 in bargaining_cond
#     4.39e+01 in Bq_match
#     0.00e+00 in FOC_capital_agency
#     8.88e-15 in FOC_K_ell
#     9.97e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.39e+01
#     1.38e-02 in bargaining_cond
#     2.44e+00 in Bq_match
#     6.03e-03 in FOC_capital_agency
#     2.31e-01 in FOC_K_ell
#     3.34e+00 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.34e+00
#     7.32e-03 in bargaining_cond
#     8.68e-01 in Bq_match
#     3.08e-03 in FOC_capital_agency
#     1.10e-01 in FOC_K_ell
#     1.70e+00 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.70e+00
#     1.55e-03 in bargaining_cond
#     1.92e-01 in Bq_match
#     6.68e-04 in FOC_capital_agency
#     2.48e-02 in FOC_K_ell
#     3.59e-01 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.59e-01
#     2.02e-04 in bargaining_cond
#     2.10e-02 in Bq_match
#     9.57e-05 in FOC_capital_agency
#     3.19e-03 in FOC_K_ell
#     4.91e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.91e-02
#     3.24e-05 in bargaining_cond
#     1.93e-03 in Bq_match
#     2.07e-05 in FOC_capital_agency
#     5.69e-04 in FOC_K_ell
#     8.53e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 8.53e-03
#     1.34e-05 in bargaining_cond
#     6.07e-04 in Bq_match
#     1.05e-05 in FOC_capital_agency
#     2.39e-04 in FOC_K_ell
#     3.70e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.70e-03
#     2.83e-06 in bargaining_cond
#     7.00e-05 in Bq_match
#     2.90e-06 in FOC_capital_agency
#     5.31e-05 in FOC_K_ell
#     8.15e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 8.15e-04
#     1.13e-06 in bargaining_cond
#     2.09e-05 in Bq_match
#     1.30e-06 in FOC_capital_agency
#     2.16e-05 in FOC_K_ell
#     3.34e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.34e-04
#     3.11e-07 in bargaining_cond
#     5.81e-06 in Bq_match
#     3.69e-07 in FOC_capital_agency
#     5.94e-06 in FOC_K_ell
#     9.15e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 9.15e-05
#     1.03e-08 in bargaining_cond
#     2.74e-07 in Bq_match
#     1.45e-08 in FOC_capital_agency
#     2.02e-07 in FOC_K_ell
#     3.21e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 10
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.21e-06
#     8.88e-09 in bargaining_cond
#     1.26e-07 in Bq_match
#     1.47e-08 in FOC_capital_agency
#     1.77e-07 in FOC_K_ell
#     2.73e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 11
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.73e-06
#     3.92e-09 in bargaining_cond
#     5.28e-08 in Bq_match
#     5.84e-09 in FOC_capital_agency
#     7.68e-08 in FOC_K_ell
#     1.19e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 12
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.19e-06
#     7.38e-11 in bargaining_cond
#     1.17e-09 in Bq_match
#     9.41e-11 in FOC_capital_agency
#     1.43e-09 in FOC_K_ell
#     2.22e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 13
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.22e-08
#     1.24e-11 in bargaining_cond
#     3.33e-10 in Bq_match
#     1.08e-11 in FOC_capital_agency
#     2.34e-10 in FOC_K_ell
#     3.60e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 14
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 3.60e-09
#     3.70e-12 in bargaining_cond
#     4.60e-11 in Bq_match
#     6.14e-12 in FOC_capital_agency
#     7.13e-11 in FOC_K_ell
#     1.12e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 15
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.12e-09
#     5.47e-13 in bargaining_cond
#     1.85e-11 in Bq_match
#     6.99e-13 in FOC_capital_agency
#     1.02e-11 in FOC_K_ell
#     1.64e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 16
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.64e-10
#     2.66e-13 in bargaining_cond
#     8.32e-12 in Bq_match
#     2.81e-13 in FOC_capital_agency
#     5.25e-12 in FOC_K_ell
#     7.80e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 17
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 7.80e-11
#     1.90e-13 in bargaining_cond
#     9.38e-12 in Bq_match
#     2.73e-13 in FOC_capital_agency
#     3.83e-12 in FOC_K_ell
#     5.78e-11 in mkt_clearing

# %% [markdown]
# # Figures

# %% [markdown]
# ## National accouting - quantities

# %%
model.plot_IRF(varlist=['Y','C','G','I','X','M'])

# %% [markdown]
# ## National Accouting - Prices

# %%
model.plot_IRF(varlist=['P_Y','P_C','P_G','P_I','P_X','P_F'])

# %% [markdown]
# ## Labor market

# %%
model.plot_IRF(varlist=['S','v','curlyM','m_v','m_s','delta_L','W','real_W'],abs=['m_v','m_s'])

# %% [markdown]
# ## Capital accumulation

# %%
model.plot_IRF(varlist=['K','I','r_K','P_I'],ncol=2)

# %% [markdown]
# ## Production firms

# %%
model.plot_IRF(varlist=['K','ell','Y','r_K','r_ell'],ncol=2)

# %% [markdown]
# ## Government

# %%
model.plot_IRF(varlist=['G','B_G','tau'],abs=['tau'],Y_share=['B_G'])

# %% [markdown]
# ## Households - aggregate

# %%
model.plot_IRF(varlist=['L','W','real_W','C','B','Bq'],ncol=3, T_IRF = 150)
