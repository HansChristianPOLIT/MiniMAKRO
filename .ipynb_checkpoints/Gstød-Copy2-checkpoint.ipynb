# %%
# %load_ext autoreload
# %autoreload 2

import time
import pickle
import numpy as np
from scipy import optimize

import matplotlib.pyplot as plt   
plt.style.use('seaborn-whitegrid')
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

from BabyMAKROModel import BabyMAKROModelClass

# %% [markdown]
# # Setup

# %%
model = BabyMAKROModelClass(name='Extended') # create an instance of the model

# %%
par = model.par
ss = model.ss
sol = model.sol

# %% [markdown]
# # Find steady state

# %%
model.find_ss(do_print=True)
# Out:
# Labor supply and search and matching:
# ss.S = 7.44,  ss.L = 56.28,  ss.delta_L = 0.07,  ss.v = 16.52,  ss.m_v = 0.23
# Capital agency FOC:
# ss.r_K = 0.14
# Production firm pricing:
# ss.r_ell = 2.71
# Labor agency:
# ss.ell = 55.87,  ss.w = 2.68
# Government:
# ss.B_G = 0.10,  ss.G = 0.00,  ss.tau = 0.00
# Households:
# solving for household behavior: result.converged = True
# ss.C = 169.40,  ss.B = 464.96
# Production firm FOCs:
# ss.K = 557.43
# Capital accumulation equation:
# ss.I = 55.74
# Output in production firm:
# ss.Y = 229.56
# Market clearing:
# ss.C_Y = 118.58,  ss.G_Y = 0.00,  ss.I_Y = 36.23,  ss.X_Y = 74.75
# [ ss.C_M = 50.82,  ss.G_M = 0.00,  ss.I_M = 19.51,  ss.X_M = 49.83 ] = ss.M = 120.16
# ss.X = 124.58
# Bargaining:
# par.phi = 0.988

# %% [markdown]
# **Household behavior:**

# %%
fig = plt.figure(figsize=(3*6,3*6/2.5))

ax = fig.add_subplot(2,4,1)
ax.plot(model.par.delta_L_a*100)
ax.set_ylabel('%')
ax.set_title('$\delta^L_a$')

ax = fig.add_subplot(2,4,2)
ax.plot(model.ss.S_a)
ax.set_title('$S_a$')

ax = fig.add_subplot(2,4,3)
ax.plot(model.ss.L_a)
ax.set_title('$L_a$')

ax = fig.add_subplot(2,4,4)
ax.plot(model.ss.L_ubar_a)
ax.set_title(r'$L\underbar_a$')

ax = fig.add_subplot(2,4,5)
ax.plot(model.ss.B_a)
ax.set_ylabel('')
ax.set_title('$B_a$')

ax = fig.add_subplot(2,4,6)
ax.plot(model.ss.C_a)
ax.set_ylabel('')
ax.set_title('$C_a$')

ax = fig.add_subplot(2,4,7)
ax.plot(model.ss.C_R)
ax.set_ylabel('')
ax.set_title('$C^R_a$')

ax = fig.add_subplot(2,4,8)
ax.plot(model.ss.C_HTM)
ax.set_ylabel('')
ax.set_title('$C^{HTM}_a$');

# %% [markdown]
# # Speed and error tests

# %%
model.set_exo_ss()
model.set_unknowns_ss()

# %% [markdown]
# **Python evaluation:**

# %%
# %time model.evaluate_blocks(py=True)
# Out:
# CPU times: total: 1.84 s
# Wall time: 1.86 s

# %% [markdown]
# **Check errors:**

# %%
errors = model.get_errors(do_print=True)
# Out:
# bargaining_cond     : abs. max = 0.00e+00
# Bq_match            : abs. max = 3.40e-02
# FOC_capital_agency  : abs. max = 0.00e+00
# FOC_K_ell           : abs. max = 7.11e-15
# mkt_clearing        : abs. max = 2.84e-14

# %% [markdown]
# **First numba evaluation:**

# %%
# %time model.evaluate_blocks()
# Out:
# CPU times: total: 17.7 s
# Wall time: 18.2 s

# %% [markdown]
# **Time:**

# %%
# %timeit model.evaluate_blocks()
# %timeit model.get_errors()
# Out:
# 3.74 ms ± 30.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 17.5 µs ± 319 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit model.evaluate_blocks(py=True)
# Out:
# 210 ms ± 3.41 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# # Find an impulse-response

# %% [markdown]
# **Calculate Jacobian:**

# %%
model.calc_jac(do_print=True)
# Out:
# Jacobian calculated in 10.4 secs secs

# %% [markdown]
# Only needs to be calculated once.

# %% [markdown]
# **Set exogenous variables:**

# %%
model.set_exo_ss()

# %% [markdown]
# Here we shock export demand:

# %%
Tshock = 50
shock = 0.01*ss.G
persistence = 0.8**np.arange(Tshock)
sol.chi[:Tshock] = ss.G + shock*persistence

# %% [markdown]
# Check errors when guessing at steady state -> excess demand

# %%
model.set_unknowns_ss()
model.evaluate_blocks()
errors = model.get_errors(do_print=True)
# Out:
# bargaining_cond     : abs. max = 0.00e+00
# Bq_match            : abs. max = 3.40e-02
# FOC_capital_agency  : abs. max = 0.00e+00
# FOC_K_ell           : abs. max = 8.88e-15
# mkt_clearing        : abs. max = 7.47e+01

# %% [markdown]
# **Find IRF:**

# %%
model.find_IRF()
# Out:
# initial:
#    max. abs. error = 7.47e+01
#     0.00e+00 in bargaining_cond
#     3.40e-02 in Bq_match
#     0.00e+00 in FOC_capital_agency
#     8.88e-15 in FOC_K_ell
#     7.47e+01 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 7.47e+01
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 7
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 8
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 9
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 10
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 11
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 12
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 13
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 14
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 15
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 16
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 17
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 18
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 19
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 20
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 21
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 22
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 23
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 24
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 25
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 26
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 27
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 28
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 29
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 30
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 31
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 32
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 33
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 34
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 35
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 36
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 37
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 38
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 39
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 40
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 41
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 42
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 43
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 44
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 45
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 46
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 47
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 48
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 49
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 50
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 51
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 52
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 53
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 54
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 55
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 56
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 57
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 58
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 59
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 60
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 61
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 62
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 63
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 64
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 65
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 66
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 67
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 68
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 69
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 70
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 71
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 72
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 73
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 74
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 75
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 76
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 77
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 78
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 79
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 80
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 81
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 82
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 83
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 84
#  solve: t1-t0 = 0.2 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 85
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 86
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 87
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 88
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 89
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 90
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 91
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 92
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 93
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 94
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 95
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 96
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 97
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 98
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 99
#  solve: t1-t0 = 0.1 secs
#    max. abs. error =      nan
#          nan in bargaining_cond
#          nan in Bq_match
#          nan in FOC_capital_agency
#          nan in FOC_K_ell
#          nan in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 model.find_IRF()
#
# File ~\Desktop\6. semester\Bachelor\Programmering\ExtendedBabyMAKRO\BabyMAKROModel.py:389, in BabyMAKROModelClass.find_IRF(self, ini)
#     386     return self.get_errors()
#     388 # c. solver
# --> 389 broyden_solver(obj,x0,self.jac,tol=1e-10,maxiter=100,do_print=True,model=self)
#
# File ~\Desktop\6. semester\Bachelor\Programmering\ExtendedBabyMAKRO\broyden_solver.py:64, in broyden_solver(f, x0, jac, tol, maxiter, do_print, model)
#      60     if do_print: print(f' update_jac: {t1-t0 = :.1f} secs')
#      62 else:
# ---> 64     raise ValueError(f'no convergence after {maxiter} iterations')
#
# ValueError: no convergence after 100 iterations

# %% [markdown]
# **Plot:**

# %%
T_IRF = 500

fig = plt.figure(figsize=(3*6,3*6/1.5))

ax = fig.add_subplot(4,4,1)
ax.plot((sol.chi[:T_IRF]/ss.chi-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Export demand, $\chi_t$')

ax = fig.add_subplot(4,4,2)
ax.plot((sol.Y[:T_IRF]/ss.Y-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Production, $Y_t$')

ax = fig.add_subplot(4,4,3)
ax.plot((sol.X[:T_IRF]/(ss.X)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Export, $X_t$')

ax = fig.add_subplot(4,4,4)
ax.plot((sol.M[:T_IRF]/(ss.M)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Import, $M_t$')

ax = fig.add_subplot(4,4,5)
ax.plot((sol.L[:T_IRF]/ss.L-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Employment, $L_t$')

ax = fig.add_subplot(4,4,6)
ax.plot((sol.ell[:T_IRF]/(ss.ell)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$\ell_t$')

ax = fig.add_subplot(4,4,7)
ax.plot((sol.w[:T_IRF]/(ss.w)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$w_t$')

ax = fig.add_subplot(4,4,8)
ax.plot((sol.r_ell[:T_IRF]/(ss.r_ell)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$r^{\ell}_t$')

ax = fig.add_subplot(4,4,9)
ax.plot((sol.m_s[:T_IRF]/(ss.m_s)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$m_s$')

ax = fig.add_subplot(4,4,10)
ax.plot((sol.S[:T_IRF]/(ss.S)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$S_t$')

ax = fig.add_subplot(4,4,11)
ax.plot((sol.v[:T_IRF]/(ss.v)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$v_t$')

ax = fig.add_subplot(4,4,12)
ax.plot((sol.K[:T_IRF]/ss.K-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Capital, $K_t$')

ax = fig.add_subplot(4,4,13)
ax.plot((sol.I[:T_IRF]/(ss.I)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Investments, $I^R_t$')

ax = fig.add_subplot(4,4,14)
ax.plot((sol.C[:T_IRF]/ss.C-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Consumption, $C_t$')

ax = fig.add_subplot(4,4,15)
ax.plot((sol.Bq[:T_IRF]/(ss.Bq)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('Inheritance, $B^q_t$')

ax = fig.add_subplot(4,4,16)
ax.plot((sol.B[:T_IRF]/(ss.B)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('End-of-period savings, $B^R_t$');

print('Note: resultater')

# %%
Periods = [0,1,20,40,80,100]

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(2,2,1)
for t in Periods:
    L_a = np.zeros(par.A)
    for a in range(par.A):
        L_a[a] = sol.L_a[a,t+a]
    ax.plot(L_a-ss.L_a,label=f'{t = }')
ax.set_ylabel('% of s.s.')
ax.set_title('$L_{a,t}$')

ax = fig.add_subplot(2,2,2)
for t in Periods:
    S_a = np.zeros(par.A)
    for a in range(par.A):
        S_a[a] = sol.S_a[a,t+a]
    ax.plot(S_a-ss.S_a,label=f'{t = }')
ax.set_ylabel('% of s.s.')
ax.set_title('$S_{a,t}$')

ax = fig.add_subplot(2,2,3)
for t in Periods:
    C_a = np.zeros(par.A)
    for a in range(par.A):
        C_a[a] = sol.C_a[a,t+a]
    ax.plot(C_a-ss.C_a,label=f'{t = }')
ax.set_ylabel('% of s.s.')
ax.set_title('$C_{a,t}$')

ax = fig.add_subplot(2,2,4)
for t in Periods:
    B_a = np.zeros(par.A)
    for a in range(par.A):
        B_a[a] = sol.B_a[a,t+a]
    ax.plot(B_a-ss.B_a,label=f'{t = }')
ax.legend(frameon=True)
ax.set_ylabel('% of s.s.')
ax.set_title('$B_{a,t}$');

# %%
fig = plt.figure(figsize=(12,8))

ax = fig.add_subplot(2,2,1)
ax.plot((sol.P_Y[:T_IRF]/ss.P_Y-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$P^Y_t$')

ax = fig.add_subplot(2,2,2)
ax.plot((sol.P_C[:T_IRF]/ss.P_C-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$P^C_t$')

ax = fig.add_subplot(2,2,3)
ax.plot((sol.P_I[:T_IRF]/(ss.P_I)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$P^I_t$')

ax = fig.add_subplot(2,2,4)
ax.plot((sol.P_X[:T_IRF]/(ss.P_X)-1)*100)
ax.set_ylabel('% of s.s.')
ax.set_title('$P^X_t$');

# %% [markdown]
# # Comparison

# %%
model_copy = model.copy()
model_copy.par.Lambda = 0.01
model_copy.find_ss(0.50)
model_copy.calc_jac(do_print=True)

# %%
Tshock = 50
shock = 0.01*ss.G
persistence = 0.8**np.arange(Tshock)
model_copy.sol.G[:Tshock] = model_copy.ss.G + shock*persistence

# %%
model_copy.find_IRF()

# %%
T_IRF = 500

fig = plt.figure(figsize=(3*6,3*6/1.5))

ax = fig.add_subplot(3,4,1)
ax.plot((sol.G[:T_IRF]/ss.G-1)*100)
ax.plot((model_copy.sol.G[:T_IRF]/model_copy.ss.G-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title(' (the shock-variable), $\G_t$')
ax.legend(frameon=True)

ax = fig.add_subplot(3,4,2)
ax.plot((sol.Y[:T_IRF]/ss.Y-1)*100)
ax.plot((model_copy.sol.Y[:T_IRF]/model_copy.ss.Y-1)*100,label='alt')
ax.set_ylabel('% of s.s.')
ax.set_title('Production, $Y_t$')
